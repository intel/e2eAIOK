# %% [markdown]
# # Auto Feature engineering for AWS product review

# %% [markdown]
# ## 1. Load Datasets

# %%
import pandas as pd
dir_path = "/home/vmagent/app/recdp/dataset/all_amazon_reviews"
train_data = pd.read_table(f"{dir_path}/amazon_reviews_us_Books_v1_00.tsv",on_bad_lines='skip')
# Out:
# /tmp/ipykernel_8092/3965994723.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_table(f"{dir_path}/amazon_reviews_us_Books_v1_00.tsv",on_bad_lines='skip')

# %%
train_data
# Out:
#          marketplace  customer_id       review_id  product_id  product_parent  \
# 0                 US     25933450   RJOVP071AVAJO  0439873800        84656342
# 1                 US      1801372  R1ORGBETCDW3AI  1623953553       729938122
# 2                 US      5782091   R7TNRFQAOUTX5  142151981X       678139048
# 3                 US     32715830  R2GANXKDIFZ6OI  014241543X       712432151
# 4                 US     14005703  R2NYB6C3R8LVN6  1604600527       800572372
# ...              ...          ...             ...         ...             ...
# 10236845          US     52004451  R2OUP8UJV6LEVO  B003ZX1EQS       381270854
# 10236846          US     36099005  R34K82WIMNWJBL  0786652918        14254333
# 10236847          US     38081951  R3JHG8BPWJVN6S  1608981215       331746774
# 10236848          US     53040283  R3EOQVV7MU668R  0670023418       184956679
# 10236849          US     17586627  R1C55R35N6YVX4  1475142110        43473317
#
# ...

# %% [markdown]
# ## 2. Data Profile for pipeline
