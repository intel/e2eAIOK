# %%
import pandas as pd
from utils import Timer
import os

def clean_df(df, label = 'reply'):
    df['tweet_timestamp'] = pd.to_datetime(df['tweet_timestamp'],unit='s')
    df['engaging_user_account_creation'] = pd.to_datetime(df['engaging_user_account_creation'],unit='s')
    df['engaged_with_user_account_creation'] = pd.to_datetime(df['engaged_with_user_account_creation'],unit='s')
    
    if label == 'reply':
        df['reply'] = df['reply_timestamp'].apply(lambda x: 1 if x>0 else 0).astype('int32')
    if label == 'retweet':
        df['retweet'] = df['retweet_timestamp'].apply(lambda x: 1 if x>0 else 0).astype('int32')
    if label == 'comment':
        df['comment'] = df['retweet_with_comment_timestamp'].apply(lambda x: 1 if x>0 else 0).astype('int32')
    if label == 'like':
        df['like'] = df['like_timestamp'].apply(lambda x: 1 if x>0 else 0).astype('int32')
    df = df.drop(columns=['reply_timestamp', 'retweet_timestamp', 'retweet_with_comment_timestamp','like_timestamp'])
    if 'tokens' in df.columns:
        df = df.drop(columns=['tokens'])
    return df

def apply_bert_decode(df):
    from transformers import BertTokenizer
    os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
    tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
    df["tweet"] = df["text_tokens"].progress_apply(lambda x: tokenizer.decode([int(n) for n in x.split('\t')]))
    df = df.drop(columns=['text_tokens'])
    return df

# %%
import pandas as pd
from utils import Timer
from tqdm import tqdm

tqdm.pandas()

with Timer(f"Load train"):
    train_data = pd.read_parquet("twitterrecsys.train.parquet")
    train_data = train_data[:100000]
with Timer(f"clean data"):
    train_data = clean_df(train_data)
with Timer(f"apply_bert_decode"):
    train_data = apply_bert_decode(train_data)
train_data.dtypes
# Out:
# Load train took 18.520480221137404 sec
# clean data took 0.7230387460440397 sec
# 100%|██████████| 100000/100000 [00:09<00:00, 10884.84it/s]
# apply_bert_decode took 29.55636406969279 sec
# hashtags                                      object
# tweet_id                                      object
# present_media                                 object
# present_links                                 object
# present_domains                               object
# tweet_type                                    object
# language                                      object
# tweet_timestamp                       datetime64[ns]
# engaged_with_user_id                          object
# engaged_with_user_follower_count               int64
# engaged_with_user_following_count              int64
# engaged_with_user_is_verified                   bool
# engaged_with_user_account_creation    datetime64[ns]
# engaging_user_id                              object
# engaging_user_follower_count                   int64
# enaging_user_following_count                   int64
# enaging_user_is_verified                        bool
# engaging_user_account_creation        datetime64[ns]
# engagee_follows_engager                         bool
# reply                                          int32
# tweet                                         object
# dtype: object

# %%
train_data
# Out:
#                                                 hashtags  \
# 0                                                   None
# 1                       B6EC77A29C34939B81DCC38ECA00DB32
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 99995                                               None
# 99996  43B37225C841C6DB6E7D340EAFBA569C\t25A2367EE2D9...
# 99997                                               None
# 99998                                               None
# 99999                   B96A690CE6C1D3EA55EB455D9C0FD6B0
#
#                                tweet_id present_media  \
# 0      E6D175543122CE8F508E17015E6610B2          None
# 1      E35CD173274FE6434E7477F182C2DA39          None
# 2      7BB9A31FDE6868C1A1E17EA678FBF6C5           GIF
# 3      D1989E07D803476B6025D13C8BCB6DD3          None
# 4      B1ACDCB66DF98D4B2A94ED433FFC3E07          None
# ...                                 ...           ...
# 99995  4A281F8D5D7048CC2DE676B8DF16A938          None
# 99996  7323EC68C992E122956D453E38D06365         Photo
# 99997  7B69BB8CE8DE95C772F3BB7F4417124E          None
# 99998  C1683A7DD8F440B00C4BE51FF3969FDD          None
# 99999  95592002327565600973A02343172609          None
#
#                           present_links                   present_domains  \
# 0                                  None                              None
# 1      B412A1F69290A59CB5FE8C8F70B5F6BD  743332A23E1F15FA1F221F77D44DF7AC
# 2      EDC6B9477A034FA8DF1D38701E90F6B7  37F6EF8038F7A0B9A07DF964E16EB09A
# 3                                  None                              None
# 4      E0C58892A48BE04BE8E7DD1088503156  8463A92AE38304444558059B409BCCF2
# ...                                 ...                               ...
# 99995                              None                              None
# 99996                              None                              None
# 99997                              None                              None
# 99998                              None                              None
# 99999                              None                              None
#
#       tweet_type                          language     tweet_timestamp  \
# 0          Quote  488B32D24BD4BB44172EB981C1BCA6FA 2021-02-12 08:17:52
# 1       TopLevel  488B32D24BD4BB44172EB981C1BCA6FA 2021-02-07 04:37:11
# 2        Retweet  E7F038DE3EAD397AEC9193686C911677 2021-02-24 05:33:58
# 3       TopLevel  D922D8FEA3EFAD3200455120B75BCEB8 2021-02-11 00:45:03
# 4       TopLevel  7D11A7AA105DAB4D6799AF863369DB9C 2021-02-16 06:18:21
# ...          ...                               ...                 ...
# 99995    Retweet  E7F038DE3EAD397AEC9193686C911677 2021-02-15 04:57:20
# 99996    Retweet  E7F038DE3EAD397AEC9193686C911677 2021-02-15 09:13:19
# 99997   TopLevel  9A78FC330083E72BE0DD1EA92656F3B5 2021-02-06 16:18:13
# 99998    Retweet  488B32D24BD4BB44172EB981C1BCA6FA 2021-02-19 02:38:21
# 99999   TopLevel  B8B04128918BBF54E2E178BFF1ABA833 2021-02-19 02:33:14
#
#                    engaged_with_user_id  engaged_with_user_follower_count  \
# 0      010E1103060789CF8CB5B95427B44964                             95017
# 1      9F68E2B5E896BF8E1A2B06E1985329B2                              3529
# 2      0CAEDCD7503E40E1E5BFF2AD112863F4                              3247
# 3      557051DEF71B797E0C6BB4DC7D04D037                              1775
# 4      83A7E60363FD6E4B3F8E17534A259C39                             30163
# ...                                 ...                               ...
# 99995  A86315F66180AC40AD58AD56187B06C0                              1310
# 99996  561EEECDC817A9A3D63B083D028AC20B                               267
# 99997  BA747E2DB84357A0872A197BB7C753CC                               364
# 99998  9C9B5E585778D1D3063B994E35376CEE                            761283
# 99999  47D1B8724E8D08A8F42093701D797497                            485954
#
#        ...  engaged_with_user_is_verified  engaged_with_user_account_creation  \
# 0      ...                          False                 2016-01-28 12:27:19
# 1      ...                          False                 2015-03-03 13:28:45
# 2      ...                          False                 2018-09-02 07:10:55
# 3      ...                          False                 2010-12-11 16:10:50
# 4      ...                          False                 2010-03-11 20:32:17
# ...    ...                            ...                                 ...
# 99995  ...                          False                 2013-01-09 01:59:11
# 99996  ...                          False                 2018-04-25 21:25:01
# 99997  ...                          False                 2020-11-26 15:48:25
# 99998  ...                          False                 2010-01-06 22:39:39
# 99999  ...                           True                 2010-07-25 00:43:32
#
#                        engaging_user_id engaging_user_follower_count  \
# 0      D6074FA4F0C1AC715199E4F1426599F4                          940
# 1      C0E8BA6661C2E8CEA7C64B769D597C04                           24
# 2      DF19EEA536FF691AC78603CCE666AF2E                         1575
# 3      912421CD187259420CDA7E1484C34044                         3812
# 4      DB7670068F282465150E04547AADA78B                          587
# ...                                 ...                          ...
# 99995  D8A3518F18025BCB10E9A7663638E25E                          330
# 99996  B39F029D04D00B8CC9C8883E66D73442                          849
# 99997  705B940153E60523DC0AD9DAED5A906B                          319
# 99998  1D6A7DB39B73727120B10EF7027659FE                          212
# 99999  875EB017E17C8D88A29C51735F387278                           75
#
#        enaging_user_following_count  enaging_user_is_verified  \
# 0                              1066                     False
# 1                               350                     False
# 2                               369                     False
# 3                              4629                     False
# 4                               229                     False
# ...                             ...                       ...
# 99995                           364                     False
# 99996                           789                     False
# 99997                           336                     False
# 99998                           126                     False
# 99999                            86                     False
#
#        engaging_user_account_creation engagee_follows_engager  reply  \
# 0                 2010-11-14 16:50:00                   False      0
# 1                 2011-01-12 02:15:49                   False      0
# 2                 2019-11-12 01:36:57                    True      0
# 3                 2010-01-27 20:00:13                    True      0
# 4                 2019-06-09 14:55:47                   False      0
# ...                               ...                     ...    ...
# 99995             2014-02-03 13:35:36                    True      0
# 99996             2018-12-25 17:20:35                    True      0
# 99997             2020-03-09 20:13:27                    True      0
# 99998             2017-08-25 12:44:17                   False      0
# 99999             2015-05-12 15:41:23                   False      0
#
#                                                    tweet
# 0             [CLS] Straight from the horse mouth. [SEP]
# 1      [CLS] We can, we must, # DefundThePolice ¶ ¶ h...
# 2      [CLS] RT @ ixkaito : イラレのブレンドかな 。 https : / / ...
# 3             [CLS] @ lzcrowder Lololololol we die [SEP]
# 4      [CLS] Eindelijk komt de discussie over de neve...
# ...                                                  ...
# 99995  [CLS] RT @ oscarnoyukue : 殺 人 鬼 フレディとジェイソンがデュエ...
# 99996  [CLS] RT @ hikakin : BTSの 握 手 会 [UNK] ¶ ¶ # BT...
# 99997  [CLS] الى كل من يتابعني................... الم...
# 99998  [CLS] RT @ SheriffClarke : Yeah, why not? A DC...
# 99999  [CLS] Pra variar eu não entendi a prova, não e...
#
# [100000 rows x 21 columns]

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

model = TabularPredictor(label="reply")
predictor = model.fit(train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20221201_233617/"
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (100000 samples, 88.56 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20221201_233617/"
# AutoGluon Version:  0.6.0
# Python Version:     3.8.10
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Nov 8 23:39:32 UTC 2018
# Train Data Rows:    100000
# Train Data Columns: 20
# Label Column: reply
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    280543.94 MB
# 	Train Data (Original)  Memory Usage: 88.16 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['tweet']
# 			CountVectorizer fit with vocabulary size = 6394
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])         : 3 | ['engaged_with_user_is_verified', 'enaging_user_is_verified', 'engagee_follows_engager']
# 		('datetime', [])     : 3 | ['tweet_timestamp', 'engaged_with_user_account_creation', 'engaging_user_account_creation']
# 		('int', [])          : 4 | ['engaged_with_user_follower_count', 'engaged_with_user_following_count', 'engaging_user_follower_count', 'enaging_user_following_count']
# 		('object', [])       : 9 | ['hashtags', 'tweet_id', 'present_media', 'present_links', 'present_domains', ...]
# 		('object', ['text']) : 1 | ['tweet']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :    9 | ['hashtags', 'tweet_id', 'present_media', 'present_links', 'present_domains', ...]
# 		('category', ['text_as_category'])  :    1 | ['tweet']
# 		('int', [])                         :    4 | ['engaged_with_user_follower_count', 'engaged_with_user_following_count', 'engaging_user_follower_count', 'enaging_user_following_count']
# 		('int', ['binned', 'text_special']) :   27 | ['tweet.char_count', 'tweet.word_count', 'tweet.capital_ratio', 'tweet.lower_ratio', 'tweet.digit_ratio', ...]
# 		('int', ['bool'])                   :    3 | ['engaged_with_user_is_verified', 'enaging_user_is_verified', 'engagee_follows_engager']
# 		('int', ['datetime_as_int'])        :   13 | ['tweet_timestamp', 'tweet_timestamp.day', 'tweet_timestamp.dayofweek', 'engaged_with_user_account_creation', 'engaged_with_user_account_creation.year', ...]
# 		('int', ['text_ngram'])             : 6394 | ['__nlp__.00', '__nlp__.00 unk', '__nlp__.000', '__nlp__.01', '__nlp__.02', ...]
# 	39.5s = Fit runtime
# 	20 features in original data used to generate 6451 features in processed data.
# 	Train Data (Processed) Memory Usage: 1297.11 MB (0.5% of available memory)
# Data preprocessing and feature engineering runtime = 42.42s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.025, Train Rows: 97500, Val Rows: 2500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.9724	 = Validation score   (accuracy)
# 	8.72s	 = Training   runtime
# 	31.94s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.9704	 = Validation score   (accuracy)
# 	8.76s	 = Training   runtime
# 	31.08s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.9728	 = Validation score   (accuracy)
# 	13.94s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.9728	 = Validation score   (accuracy)
# 	13.73s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.9728	 = Validation score   (accuracy)
# 	54.02s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.9728	 = Validation score   (accuracy)
# 	40.14s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.9728	 = Validation score   (accuracy)
# 	8.65s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.9724	 = Validation score   (accuracy)
# 	65.56s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.9724	 = Validation score   (accuracy)
# 	52.85s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 7: early stopping
# 	0.9732	 = Validation score   (accuracy)
# 	149.89s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.9732	 = Validation score   (accuracy)
# 	15.47s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.9728	 = Validation score   (accuracy)
# 	102.27s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.9728	 = Validation score   (accuracy)
# 	14.27s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.9732	 = Validation score   (accuracy)
# 	0.74s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 670.99s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20221201_233617/")

# %%
with Timer(f"Load train"):
    schema = ["text_tokens", "hashtags", "tweet_id", "present_media", "present_links", "present_domains", "tweet_type",
            "language", "tweet_timestamp", "engaged_with_user_id", "engaged_with_user_follower_count", "engaged_with_user_following_count",
            "engaged_with_user_is_verified", "engaged_with_user_account_creation", "engaging_user_id", "engaging_user_follower_count",
            "enaging_user_following_count", "enaging_user_is_verified", "engaging_user_account_creation", "engagee_follows_engager",
            "reply_timestamp", "retweet_timestamp", "retweet_with_comment_timestamp", "like_timestamp"]
    
    test_data = pd.read_csv("twitterrecsys.valid.csv", sep='\x01', names = schema, header=None, nrows=10000)
    
with Timer("clean data"):
    test_data = clean_df(test_data)
    
with Timer(f"apply_bert_decode"):
    test_data = apply_bert_decode(test_data)
    
test_data
# Out:
# Load train took 0.05262972880154848 sec
# clean data took 0.0075564198195934296 sec
# 100%|██████████| 10000/10000 [00:00<00:00, 10211.38it/s]
# apply_bert_decode took 21.34463684493676 sec
#                                                                                                                                                                                                                                                                                                                                                 hashtags  \
# 0                                                                                                                                                                                                                                                                                                                                                    NaN
# 1                                                                                                                                                                                                                                                                                                                                                    NaN
# 2     90C52DDF506D1C98EE678E84C08C36AB\tCD8639BABE547D9B9BBBB8E962450E2B\t6F84D430D26397EF87A1DC2A7717E75F\t03176616480890152CF7583112DBBD87\t062B238B5042E31C6FD1468742975CDF\t78D6EF9ED489837B54DC07B2F7FFFB21\t16E89E56FDFA9CC96F1F39EFF822F0A3\t6DAEFDE99D17E5D7DF550AFE89432DBE\tE743B8FCBF73E688676EAB7DCA4AD5AB\tF6E3CABCCEAEFCC3030256CE4620875F
# 3                                                                                                                                                                                                                 D704B4128E35F9BC995E701523676542\tCFD3AF9039C66BB22F7463A6C901225B\t7791383E39A388C0E5915549805FB527\t1C795E14677C7DBF412738236634F599
# 4                                                                                                                                                                                                                                                                                                                                                    NaN
# ...                                                                                                                                                                                                                                                                                                                                                  ...
# 9995                                                                                                                                                                                                                                                                                                                                                 NaN
# 9996                                                                                                                                                                                                                                                                                                                                                 NaN
# 9997                                                                                                                                                                                                                                                                                                                                                 NaN
# 9998                                                                                                                                                                                                                                                5DF4827AA8F4AA4168CAC78DC7821AA4\tEA2DBD95359DD6F403EE42CDAAFEE1E9\t6C9C78DC9BD194777258B17B8EDA3AF6
# 9999                                                                                                                                                                                                                                                                                                                    58C1238C9A200A25EE26FBDBBDFD6C43
#
#                               tweet_id present_media  \
# 0     0C8E7372269942BB173EED7C0A72DA09           NaN
# 1     858720854891DFED04A5B91758049833         Photo
# 2     1988AA4069C46F57990B6983FBD427A6           NaN
# 3     89C86150124016236B7D4A286B041210           NaN
# 4     971197A8E595128D8BAF8F3F9D20CFF3  Photo\tPhoto
# ...                                ...           ...
# 9995  2227FE4B3B1D59BE04F11FBCE146E96B           NaN
# 9996  4CD4E99F32B693D7127185B99BBC16EC           NaN
# 9997  076F276223FEE8B65A8394000DDE1FF8         Photo
# 9998  E48DD62AF5F4970DFC1D8F9080DCC55C           NaN
# 9999  C7F765DBE6FDB53D733D30030E0C3803           NaN
#
#                          present_links                   present_domains  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2     D249E94F6D37A7D5E37185E02C94CDFF  9EFF000CDB18B710CDDB43EE1D8C300B
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 9995                               NaN                               NaN
# 9996                               NaN                               NaN
# 9997                               NaN                               NaN
# 9998                               NaN                               NaN
# 9999                               NaN                               NaN
#
#      tweet_type                          language     tweet_timestamp  \
# 0         Quote  488B32D24BD4BB44172EB981C1BCA6FA 2021-02-28 14:49:42
# 1      TopLevel  313ECD3A1E5BB07406E4249475C2D6D6 2021-02-26 10:30:36
# 2       Retweet  E7F038DE3EAD397AEC9193686C911677 2021-03-01 17:02:33
# 3       Retweet  E7F038DE3EAD397AEC9193686C911677 2021-03-02 19:55:32
# 4      TopLevel  488B32D24BD4BB44172EB981C1BCA6FA 2021-03-01 00:38:33
# ...         ...                               ...                 ...
# 9995   TopLevel  488B32D24BD4BB44172EB981C1BCA6FA 2021-02-28 22:11:16
# 9996    Retweet  488B32D24BD4BB44172EB981C1BCA6FA 2021-03-03 01:44:43
# 9997    Retweet  E7F038DE3EAD397AEC9193686C911677 2021-03-02 21:00:48
# 9998   TopLevel  5B6973BEB05212E396F3F2DC6A31B71C 2021-03-03 11:37:57
# 9999    Retweet  E7F038DE3EAD397AEC9193686C911677 2021-03-03 02:13:34
#
#                   engaged_with_user_id  engaged_with_user_follower_count  ...  \
# 0     8B7BB615A39DF112B0037E960C27F220                               956  ...
# 1     74B09D5BC3FCE5CC4DEE34BF049A0EE5                              8723  ...
# 2     316C2BE47E445DA930E56C12F3AF31C5                             86709  ...
# 3     C19FC40FBF0AA0BAC4797BD47483349B                              2445  ...
# 4     46846BF25E56F8BA11C0AE36ED31B28F                             20672  ...
# ...                                ...                               ...  ...
# 9995  2969768AB934329E3F77C6BF9389D2EC                              6682  ...
# 9996  7C5CA5A790B34D58C92A6B1D66A5C29C                             53055  ...
# 9997  5BF5EB3CB78D855670FE5E823FD09C19                             18422  ...
# 9998  8BBCDE5904602037AB3863910C5E724B                              8644  ...
# 9999  9168AE235F16527DD53285F96FC5095A                               644  ...
#
#       engaged_with_user_is_verified  engaged_with_user_account_creation  \
# 0                             False                 2020-08-02 17:13:46
# 1                             False                 2020-02-13 18:36:45
# 2                             False                 2009-06-15 03:32:36
# 3                             False                 2015-11-14 05:15:25
# 4                             False                 2019-09-19 22:02:19
# ...                             ...                                 ...
# 9995                          False                 2020-05-25 22:12:02
# 9996                          False                 2007-07-08 01:47:26
# 9997                          False                 2017-10-28 13:06:19
# 9998                          False                 2020-03-02 22:16:41
# 9999                          False                 2016-08-13 08:39:26
#
#                       engaging_user_id engaging_user_follower_count  \
# 0     3044AFDB7E977FB7F62D49C5C97794B7                         1128
# 1     23ACD97ACEF57BF6416670BE1133A664                           72
# 2     99F829F88A12BF8B92EDF11A10B6533C                          130
# 3     A3A7B6D928FAD730BA9967B53EA7CC28                          234
# 4     BA94D75FC03B42F88CAE61485E075960                            8
# ...                                ...                          ...
# 9995  5DAD7F04EF963C9AA67A2301A8B82D81                          359
# 9996  01449F871D9C25CD15A99A5BA7080B32                         1036
# 9997  604AE4955F348F51DC45B3186DB5AE6E                          259
# 9998  C094354FC31B6759C0FCC2EA886A0A11                          342
# 9999  C7FEA5CDB1DF3CBDCE286EB6FC76BC44                          855
#
#       enaging_user_following_count  enaging_user_is_verified  \
# 0                             4028                     False
# 1                              115                     False
# 2                              638                     False
# 3                              640                     False
# 4                              208                     False
# ...                            ...                       ...
# 9995                           413                     False
# 9996                          2195                     False
# 9997                           913                     False
# 9998                           370                     False
# 9999                          1072                     False
#
#       engaging_user_account_creation engagee_follows_engager  reply  \
# 0                2014-12-28 10:37:53                   False      0
# 1                2020-09-14 04:40:07                   False      0
# 2                2009-11-01 11:58:13                   False      0
# 3                2020-09-10 08:10:09                   False      0
# 4                2018-07-29 15:59:42                   False      0
# ...                              ...                     ...    ...
# 9995             2020-06-01 11:52:22                    True      0
# 9996             2011-03-12 16:31:57                   False      0
# 9997             2019-05-04 12:53:41                    True      0
# 9998             2020-05-11 19:44:37                    True      0
# 9999             2009-12-26 02:54:32                    True      0
#
#                                                                                                                                                                                                                                                                                                                                         tweet
# 0     [CLS] Tbh, anyone who thinks this way is not considered [UNK] progressive [UNK] & amp ; I reserve the deepest contempt & amp ; disgust for them. I consider them regressive for ignoring the evidence of their own eyes & amp ; an unthinking fool for ignoring science. ¶ ¶ Call it my red line. I don [UNK] t like male cheats. [SEP]
# 1                                                                                                                                                                                                                                                                                                  [CLS] https : / / t. co / jLrINby1Ux [SEP]
# 2                                                                                                                 [CLS] RT @ hanryu _ pia : # 韓 流 ぴあ 3 月 号 （ 2 / 22 発 売 ） 表 紙 # テギョン （ # 2PM ） # 옥택연 ¶ ¶ [UNK] 特 典 付 き 本 誌 のショップ 一 覧 はこちら ¶ https : / / t. co / DDOiF0Raip ¶ ¶ # ソンシギョン # AB6IX # SOOHYUN # HOON （ # UKISS ） # ON [UNK] [SEP]
# 3                                                                                                     [CLS] RT @ TomAndJerry _ JP : ／ ¶ # トムジェリ 仲 良 しチャレンジ [UNK] ¶ # 7 日 目 ¶ ＼ ¶ ¶ いつものケンカで # トムとジェリー が ¶ 世 界 が 注 目 するウェディングを 台 無 [UNK] ¶ でも 《 まさかの 友 情 》 で 奇 跡 を 起 こす [UNK] ¶ 『 # 映 画 トムジェリ 』 3 / 19 公 開 [UNK] ¶ ¶ [UNK] ¶ [UNK] [UNK] [SEP]
# 4                                                                                                                                                                                                                                              [CLS] EVERYONE WITH THEIR COWBOY SKINS AND CONNOR IS JUST https : / / t. co / TpiCfdzRe2 [SEP]
# ...                                                                                                                                                                                                                                                                                                                                       ...
# 9995                                                                                                                                                                                                                                                [CLS] As a player would you rather win the World Cup or the Champions League? [UNK] [SEP]
# 9996                                                                                                                                                                          [CLS] RT @ ericgeller : DOJ making some kind of national security cyber announcement tomorrow. These announcements are usually about charges. https [UNK] [SEP]
# 9997                                                                                                                                                                                                              [CLS] RT @ ikirito _ YOTSUBA : みんなおはよう!! [UNK] ¶ ¶ 今 日 もがんばろね♪ ¶ ¶ おはリプ ＆ いいね 待 ってます!! https : / / t. co / Y5VsC4xyCe [SEP]
# 9998                                                                                                                                                                        [CLS] برای کمک به کادر درمان آزمون دکتری رو به تعویق بندازید. ¶ # کرونا ¶ # تعويق _ آزمون _ دکتری1400 _ وزارت _ علوم ¶ # جلوگیری _ از _ پیک _ چهارم _ کرونا [SEP]
# 9999                                                                                                                                                                                               [CLS] RT @ chaosbalance _ : # 報 道 ステーション みてるが [UNK] ¶ ¶ 河 野 大 臣 はっきり 言 ったよね 、 、 ¶ ¶ 医 療 従 事 者 で 安 全 性 を 確 認 すると ¶ ¶ やはりそうだったのか 、 、 、 [SEP]
#
# [10000 rows x 21 columns]

# %%
from sklearn.metrics import log_loss, average_precision_score
import numpy as np
def compute_AP(pred, gt):
    return average_precision_score(gt, pred)
def compute_rce_fast(pred, gt):
    cross_entropy = log_loss(gt, pred)
    yt = np.mean(gt)     
    strawman_cross_entropy = -(yt*np.log(yt) + (1 - yt)*np.log(1 - yt))
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

pred = predictor.predict(test_data)

# %%
compute_AP(pred = pred.to_numpy(), gt=test_data['reply'].to_numpy())
# Out:
# 0.0215

# %%
compute_rce_fast(pred = pred.to_numpy(), gt=test_data['reply'].to_numpy())
# Out:
# -618.5820598652679

# %%
predictor.features('transformed')
# Out:
# ['engaged_with_user_follower_count',
#  'engaged_with_user_following_count',
#  'engaged_with_user_is_verified',
#  'engaging_user_follower_count',
#  'enaging_user_following_count',
#  'enaging_user_is_verified',
#  'engagee_follows_engager',
#  'hashtags',
#  'tweet_id',
#  'present_media',
#  'present_links',
#  'present_domains',
#  'tweet_type',
#  'language',
#  'engaged_with_user_id',
#  'engaging_user_id',
#  'tweet',
#  'tweet_timestamp',
#  'tweet_timestamp.day',
#  'tweet_timestamp.dayofweek',
#  'engaged_with_user_account_creation',
#  'engaged_with_user_account_creation.year',
#  'engaged_with_user_account_creation.month',
#  'engaged_with_user_account_creation.day',
#  'engaged_with_user_account_creation.dayofweek',
#  'engaging_user_account_creation',
#  'engaging_user_account_creation.year',
#  'engaging_user_account_creation.month',
#  'engaging_user_account_creation.day',
#  'engaging_user_account_creation.dayofweek',
#  'tweet.char_count',
#  'tweet.word_count',
#  'tweet.capital_ratio',
#  'tweet.lower_ratio',
#  'tweet.digit_ratio',
#  'tweet.special_ratio',
#  'tweet.symbol_count.!',
#  'tweet.symbol_ratio.!',
#  'tweet.symbol_count.?',
#  'tweet.symbol_ratio.?',
#  'tweet.symbol_count.@',
#  'tweet.symbol_ratio.@',
#  'tweet.symbol_count.&',
#  'tweet.symbol_ratio.&',
#  'tweet.symbol_count.#',
#  'tweet.symbol_ratio.#',
#  'tweet.symbol_count..',
#  'tweet.symbol_ratio..',
#  'tweet.symbol_count.:',
#  'tweet.symbol_ratio.:',
#  'tweet.symbol_ratio. ',
#  'tweet.symbol_count./',
#  'tweet.symbol_ratio./',
#  'tweet.symbol_count.;',
#  'tweet.symbol_ratio.;',
#  'tweet.symbol_count.-',
#  'tweet.symbol_ratio.-',
#  '__nlp__.00',
#  '__nlp__.00 unk',
#  '__nlp__.000',
#  '__nlp__.01',
#  '__nlp__.02',
#  '__nlp__.03',
#  '__nlp__.04',
#  '__nlp__.05',
#  '__nlp__.07',
#  '__nlp__.08',
#  '__nlp__.09',
#  '__nlp__.10',
#  '__nlp__.10 unk',
#  '__nlp__.100',
#  '__nlp__.100 000',
#  '__nlp__.1000',
#  '__nlp__.11',
#  '__nlp__.11 unk',
#  '__nlp__.12',
#  '__nlp__.120',
#  '__nlp__.127',
#  '__nlp__.13',
#  '__nlp__.14',
#  '__nlp__.15',
#  '__nlp__.150',
#  '__nlp__.16',
#  '__nlp__.17',
#  '__nlp__.18',
#  '__nlp__.18 00',
#  '__nlp__.19',
#  '__nlp__.19 https',
#  '__nlp__.19 https co',
#  '__nlp__.19 vaccine',
#  '__nlp__.1m',
#  '__nlp__.1st',
#  '__nlp__.20',
#  '__nlp__.20 00',
#  '__nlp__.200',
#  '__nlp__.2000',
#  '__nlp__.2012',
#  '__nlp__.2013',
#  '__nlp__.2014',
#  '__nlp__.2015',
#  '__nlp__.2016',
#  '__nlp__.2017',
#  '__nlp__.2018',
#  '__nlp__.2019',
#  '__nlp__.2020',
#  '__nlp__.2021',
#  '__nlp__.2021 01',
#  '__nlp__.2021 02',
#  '__nlp__.2021 https',
#  '__nlp__.2021 https co',
#  '__nlp__.2021 sep',
#  '__nlp__.2021 unk',
#  '__nlp__.2022',
#  '__nlp__.21',
#  '__nlp__.21 00',
#  '__nlp__.21 unk',
#  '__nlp__.210131',
#  '__nlp__.22',
#  '__nlp__.23',
#  '__nlp__.23 59まで',
#  '__nlp__.24',
#  '__nlp__.24 hours',
#  '__nlp__.25',
#  '__nlp__.26',
#  '__nlp__.27',
#  '__nlp__.28',
#  '__nlp__.29',
#  '__nlp__.2nd',
#  '__nlp__.30',
#  '__nlp__.30 unk',
#  '__nlp__.300',
#  '__nlp__.30th',
#  '__nlp__.31',
#  '__nlp__.32',
#  '__nlp__.33',
#  '__nlp__.34',
#  '__nlp__.35',
#  '__nlp__.36',
#  '__nlp__.37',
#  '__nlp__.38',
#  '__nlp__.39',
#  '__nlp__.3d',
#  '__nlp__.3rd',
#  '__nlp__.40',
#  '__nlp__.400',
#  '__nlp__.41',
#  '__nlp__.42',
#  '__nlp__.43',
#  '__nlp__.44',
#  '__nlp__.45',
#  '__nlp__.46',
#  '__nlp__.47',
#  '__nlp__.48',
#  '__nlp__.4th',
#  '__nlp__.50',
#  '__nlp__.500',
#  '__nlp__.51',
#  '__nlp__.52',
#  '__nlp__.53',
#  '__nlp__.54',
#  '__nlp__.55',
#  '__nlp__.56',
#  '__nlp__.57',
#  '__nlp__.59',
#  '__nlp__.59まで',
#  '__nlp__.60',
#  '__nlp__.600',
#  '__nlp__.64',
#  '__nlp__.65',
#  '__nlp__.66',
#  '__nlp__.69',
#  '__nlp__.6pm',
#  '__nlp__.6th',
#  '__nlp__.70',
#  '__nlp__.700',
#  '__nlp__.75',
#  '__nlp__.77',
#  '__nlp__.7th',
#  '__nlp__.80',
#  '__nlp__.800',
#  '__nlp__.81',
#  '__nlp__.8pm',
#  '__nlp__.90',
#  '__nlp__.95',
#  '__nlp__.99',
#  '__nlp__.aaron',
#  '__nlp__.ab',
#  '__nlp__.ability',
#  '__nlp__.able',
#  '__nlp__.able to',
#  '__nlp__.about',
#  '__nlp__.about how',
#  '__nlp__.about it',
#  '__nlp__.about my',
#  '__nlp__.about the',
#  '__nlp__.about this',
#  '__nlp__.about to',
#  '__nlp__.about unk',
#  '__nlp__.about what',
#  '__nlp__.about you',
#  '__nlp__.above',
#  '__nlp__.absolute',
#  '__nlp__.absolutely',
#  '__nlp__.abuse',
#  '__nlp__.acaba',
#  '__nlp__.acaba de',
#  '__nlp__.acabou',
#  '__nlp__.accept',
#  '__nlp__.access',
#  '__nlp__.access to',
#  '__nlp__.according',
#  '__nlp__.according to',
#  '__nlp__.account',
#  '__nlp__.accounts',
#  '__nlp__.acha',
#  '__nlp__.achieve',
#  '__nlp__.acho',
#  '__nlp__.acho que',
#  '__nlp__.across',
#  '__nlp__.across the',
#  '__nlp__.act',
#  '__nlp__.acting',
#  '__nlp__.action',
#  '__nlp__.actions',
#  '__nlp__.active',
#  '__nlp__.actor',
#  '__nlp__.actorvijay',
#  '__nlp__.actual',
#  '__nlp__.actually',
#  '__nlp__.acuerdo',
#  '__nlp__.acá',
#  '__nlp__.ad',
#  '__nlp__.ada',
#  '__nlp__.adam',
#  '__nlp__.add',
#  '__nlp__.added',
#  '__nlp__.address',
#  '__nlp__.admin',
#  '__nlp__.administration',
#  '__nlp__.adult',
#  '__nlp__.advice',
#  '__nlp__.af',
#  '__nlp__.africa',
#  '__nlp__.african',
#  '__nlp__.after',
#  '__nlp__.after the',
#  '__nlp__.afternoon',
#  '__nlp__.again',
#  '__nlp__.again https',
#  '__nlp__.again https co',
#  '__nlp__.again sep',
#  '__nlp__.again unk',
#  '__nlp__.against',
#  '__nlp__.against the',
#  '__nlp__.age',
#  '__nlp__.agenda',
#  '__nlp__.ago',
#  '__nlp__.ago today',
#  '__nlp__.agora',
#  '__nlp__.agree',
#  '__nlp__.agreed',
#  '__nlp__.agreement',
#  '__nlp__.ah',
#  '__nlp__.ahead',
#  '__nlp__.ahead of',
#  '__nlp__.ahora',
#  '__nlp__.ahí',
#  '__nlp__.ai',
#  '__nlp__.ain',
#  '__nlp__.ain unk',
#  '__nlp__.ainda',
#  '__nlp__.air',
#  '__nlp__.aja',
#  '__nlp__.ak',
#  '__nlp__.akan',
#  '__nlp__.ako',
#  '__nlp__.aku',
#  '__nlp__.al',
#  '__nlp__.album',
#  '__nlp__.ale',
#  '__nlp__.alert',
#  '__nlp__.alex',
#  '__nlp__.algo',
#  '__nlp__.alguien',
#  '__nlp__.alguien que',
#  '__nlp__.alguna',
#  '__nlp__.algunos',
#  '__nlp__.alguém',
#  '__nlp__.algún',
#  '__nlp__.ali',
#  '__nlp__.alive',
#  '__nlp__.all',
#  '__nlp__.all are',
#  '__nlp__.all day',
#  '__nlp__.all in',
#  '__nlp__.all my',
#  '__nlp__.all of',
#  '__nlp__.all of the',
#  '__nlp__.all over',
#  '__nlp__.all sep',
#  '__nlp__.all that',
#  '__nlp__.all the',
#  '__nlp__.all time',
#  '__nlp__.all unk',
#  '__nlp__.all unk sep',
#  '__nlp__.all you',
#  '__nlp__.allah',
#  '__nlp__.alle',
#  '__nlp__.allow',
#  '__nlp__.allowed',
#  '__nlp__.allowed to',
#  '__nlp__.almost',
#  '__nlp__.alone',
#  '__nlp__.along',
#  '__nlp__.along with',
#  '__nlp__.already',
#  '__nlp__.als',
#  '__nlp__.also',
#  '__nlp__.alto',
#  '__nlp__.always',
#  '__nlp__.am',
#  '__nlp__.am so',
#  '__nlp__.ama',
#  '__nlp__.amanhã',
#  '__nlp__.amazing',
#  '__nlp__.amazon',
#  '__nlp__.amb',
#  '__nlp__.amc',
#  '__nlp__.america',
#  '__nlp__.american',
#  '__nlp__.americans',
#  '__nlp__.amiga',
#  '__nlp__.amigo',
#  '__nlp__.amigos',
#  '__nlp__.amo',
#  '__nlp__.among',
#  '__nlp__.amor',
#  '__nlp__.amor de',
#  '__nlp__.amount',
#  '__nlp__.amount of',
#  '__nlp__.amp',
#  '__nlp__.amp rt',
#  '__nlp__.amp the',
#  '__nlp__.amp unk',
#  '__nlp__.an',
#  '__nlp__.an hour',
#  '__nlp__.an unk',
#  '__nlp__.an unk sep',
#  '__nlp__.ana',
#  '__nlp__.anche',
#  '__nlp__.and',
#  '__nlp__.and all',
#  '__nlp__.and be',
#  '__nlp__.and can',
#  '__nlp__.and don',
#  '__nlp__.and for',
#  '__nlp__.and get',
#  '__nlp__.and have',
#  '__nlp__.and he',
#  '__nlp__.and her',
#  '__nlp__.and his',
#  '__nlp__.and how',
#  '__nlp__.and if',
#  '__nlp__.and is',
#  '__nlp__.and it',
#  '__nlp__.and it unk',
#  '__nlp__.and just',
#  '__nlp__.and make',
#  '__nlp__.and more',
#  '__nlp__.and my',
#  '__nlp__.and no',
#  '__nlp__.and not',
#  '__nlp__.and now',
#  '__nlp__.and other',
#  '__nlp__.and people',
#  '__nlp__.and she',
#  '__nlp__.and so',
#  '__nlp__.and that',
#  '__nlp__.and the',
#  '__nlp__.and their',
#  '__nlp__.and then',
#  '__nlp__.and they',
#  '__nlp__.and this',
#  '__nlp__.and to',
#  '__nlp__.and unk',
#  '__nlp__.and unk sep',
#  '__nlp__.and was',
#  '__nlp__.and we',
#  '__nlp__.and what',
#  '__nlp__.and will',
#  '__nlp__.and you',
#  '__nlp__.and your',
#  '__nlp__.anda',
#  '__nlp__.ang',
#  '__nlp__.angel',
#  '__nlp__.angry',
#  '__nlp__.animal',
#  '__nlp__.anime',
#  '__nlp__.anniversary',
#  '__nlp__.announce',
#  '__nlp__.announced',
#  '__nlp__.announcement',
#  '__nlp__.ano',
#  '__nlp__.anos',
#  '__nlp__.another',
#  '__nlp__.ans',
#  '__nlp__.answer',
#  '__nlp__.ante',
#  '__nlp__.antes',
#  '__nlp__.antes de',
#  '__nlp__.anti',
#  '__nlp__.antonio',
#  '__nlp__.any',
#  '__nlp__.any of',
#  '__nlp__.anymore',
#  '__nlp__.anyone',
#  '__nlp__.anything',
#  '__nlp__.anyway',
#  '__nlp__.ao',
#  '__nlp__.ao vivo',
#  '__nlp__.aoc',
#  '__nlp__.aos',
#  '__nlp__.ap',
#  '__nlp__.apa',
#  '__nlp__.apenas',
#  '__nlp__.apex',
#  '__nlp__.app',
#  '__nlp__.apparently',
#  '__nlp__.apple',
#  '__nlp__.apply',
#  '__nlp__.appreciate',
#  '__nlp__.appreciated',
#  '__nlp__.april',
#  '__nlp__.après',
#  '__nlp__.após',
#  '__nlp__.aq',
#  '__nlp__.aqui',
#  '__nlp__.aquí',
#  '__nlp__.ar',
#  '__nlp__.arcrebiano',
#  '__nlp__.are',
#  '__nlp__.are all',
#  '__nlp__.are going',
#  '__nlp__.are going to',
#  '__nlp__.are in',
#  '__nlp__.are just',
#  '__nlp__.are not',
#  '__nlp__.are now',
#  '__nlp__.are so',
#  '__nlp__.are still',
#  '__nlp__.are the',
#  '__nlp__.are unk',
#  '__nlp__.are we',
#  '__nlp__.are you',
#  '__nlp__.area',
#  '__nlp__.areas',
#  '__nlp__.aren',
#  '__nlp__.aren unk',
#  '__nlp__.argentina',
#  '__nlp__.argument',
#  '__nlp__.arkadaşlar',
#  '__nlp__.army',
#  '__nlp__.around',
#  '__nlp__.around the',
#  '__nlp__.around the world',
#  '__nlp__.arrest',
#  '__nlp__.arrested',
#  '__nlp__.arrived',
#  '__nlp__.arsenal',
#  '__nlp__.art',
#  '__nlp__.arte',
#  '__nlp__.arthur',
#  '__nlp__.article',
#  '__nlp__.artist',
#  '__nlp__.artists',
#  '__nlp__.artık',
#  '__nlp__.as',
#  '__nlp__.as an',
#  '__nlp__.as he',
#  '__nlp__.as it',
#  '__nlp__.as of',
#  '__nlp__.as pessoas',
#  '__nlp__.as the',
#  '__nlp__.as they',
#  '__nlp__.as unk',
#  '__nlp__.as we',
#  '__nlp__.as well',
#  '__nlp__.as well as',
#  '__nlp__.as you',
#  '__nlp__.asi',
#  '__nlp__.ask',
#  '__nlp__.asked',
#  '__nlp__.asking',
#  '__nlp__.asking for',
#  '__nlp__.asks',
#  '__nlp__.ass',
#  '__nlp__.assim',
#  '__nlp__.assistir',
#  '__nlp__.astrazeneca',
#  '__nlp__.astro',
#  '__nlp__.así',
#  '__nlp__.at',
#  '__nlp__.at all',
#  '__nlp__.at home',
#  '__nlp__.at https',
#  '__nlp__.at https co',
#  '__nlp__.at least',
#  '__nlp__.at me',
#  '__nlp__.at my',
#  '__nlp__.at the',
#  '__nlp__.at the end',
#  '__nlp__.at this',
#  '__nlp__.at unk',
#  '__nlp__.atau',
#  '__nlp__.ate',
#  '__nlp__.ateez',
#  '__nlp__.atención',
#  '__nlp__.atrás',
#  '__nlp__.attack',
#  '__nlp__.attack on',
#  '__nlp__.attempt',
#  '__nlp__.attention',
#  '__nlp__.até',
#  '__nlp__.au',
#  '__nlp__.auch',
#  '__nlp__.auf',
#  '__nlp__.aunque',
#  '__nlp__.aus',
#  '__nlp__.australia',
#  '__nlp__.auto',
#  '__nlp__.automatically',
#  '__nlp__.aux',
#  '__nlp__.av',
#  '__nlp__.available',
#  '__nlp__.avec',
#  '__nlp__.average',
#  '__nlp__.avoid',
#  '__nlp__.award',
#  '__nlp__.awards',
#  '__nlp__.away',
#  '__nlp__.away from',
#  '__nlp__.awesome',
#  '__nlp__.ay',
#  '__nlp__.ayer',
#  '__nlp__.ayuda',
#  '__nlp__.az',
#  '__nlp__.aí',
#  '__nlp__.año',
#  '__nlp__.años',
#  '__nlp__.años de',
#  '__nlp__.aún',
#  '__nlp__.ba',
#  '__nlp__.babies',
#  '__nlp__.baby',
#  '__nlp__.back',
#  '__nlp__.back in',
#  '__nlp__.back on',
#  '__nlp__.back sep',
#  '__nlp__.back to',
#  '__nlp__.back unk',
#  '__nlp__.bad',
#  '__nlp__.bag',
#  '__nlp__.bajo',
#  '__nlp__.bak',
#  '__nlp__.balance',
#  '__nlp__.ball',
#  '__nlp__.bambam',
#  '__nlp__.bambam1a',
#  '__nlp__.ban',
#  '__nlp__.bana',
#  '__nlp__.band',
#  '__nlp__.bang',
#  '__nlp__.banget',
#  '__nlp__.bank',
#  '__nlp__.banned',
#  '__nlp__.bar',
#  '__nlp__.barcelona',
#  '__nlp__.baru',
#  '__nlp__.base',
#  '__nlp__.baseball',
#  '__nlp__.based',
#  '__nlp__.based on',
#  '__nlp__.basketball',
#  '__nlp__.battle',
#  '__nlp__.bay',
#  '__nlp__.başkanı',
#  '__nlp__.başladı',
#  '__nlp__.bb',
#  '__nlp__.bbb',
#  '__nlp__.bbb21',
#  '__nlp__.bbb21 https',
#  '__nlp__.bbb21 https co',
#  '__nlp__.bbb21 sep',
#  '__nlp__.bbc',
#  '__nlp__.bbrightvc',
#  '__nlp__.bc',
#  '__nlp__.be',
#  '__nlp__.be able',
#  '__nlp__.be able to',
#  '__nlp__.be an',
#  '__nlp__.be back',
#  '__nlp__.be in',
#  '__nlp__.be like',
#  '__nlp__.be my',
#  '__nlp__.be on',
#  '__nlp__.be sep',
#  '__nlp__.be so',
#  '__nlp__.be the',
#  '__nlp__.be unk',
#  '__nlp__.be unk sep',
#  '__nlp__.beach',
#  '__nlp__.bear',
#  '__nlp__.beat',
#  '__nlp__.beautiful',
#  '__nlp__.beauty',
#  '__nlp__.became',
#  '__nlp__.because',
#  '__nlp__.because he',
#  '__nlp__.because it',
#  '__nlp__.because of',
#  '__nlp__.because they',
#  '__nlp__.because you',
#  '__nlp__.become',
#  '__nlp__.becomes',
#  '__nlp__.becoming',
#  '__nlp__.bed',
#  '__nlp__.been',
#  '__nlp__.been in',
#  '__nlp__.before',
#  '__nlp__.before the',
#  '__nlp__.begin',
#  '__nlp__.beginning',
#  '__nlp__.begins',
#  '__nlp__.behind',
#  '__nlp__.behind the',
#  '__nlp__.bei',
#  '__nlp__.being',
#  '__nlp__.being the',
#  '__nlp__.believe',
#  '__nlp__.believe in',
#  '__nlp__.below',
#  '__nlp__.bem',
#  '__nlp__.ben',
#  '__nlp__.beni',
#  '__nlp__.benim',
#  '__nlp__.bernie',
#  '__nlp__.best',
#  '__nlp__.bet',
#  '__nlp__.better',
#  '__nlp__.better sep',
#  '__nlp__.better than',
#  '__nlp__.between',
#  '__nlp__.beyond',
#  '__nlp__.beşiktaş',
#  '__nlp__.bi',
#  '__nlp__.biden',
#  '__nlp__.biden administration',
#  '__nlp__.biden unk',
#  '__nlp__.bien',
#  '__nlp__.big',
#  '__nlp__.bigger',
#  '__nlp__.biggest',
#  '__nlp__.bighit',
#  '__nlp__.bil',
#  '__nlp__.bile',
#  '__nlp__.bill',
#  '__nlp__.billboard',
#  '__nlp__.billion',
#  '__nlp__.bills',
#  '__nlp__.bin',
#  '__nlp__.bir',
#  '__nlp__.biri',
#  '__nlp__.birlikte',
#  '__nlp__.birthday',
#  '__nlp__.birthday to',
#  '__nlp__.birthday unk',
#  '__nlp__.bisa',
#  '__nlp__.bit',
#  '__nlp__.bit of',
#  '__nlp__.bitch',
#  '__nlp__.bitcoin',
#  '__nlp__.biz',
#  '__nlp__.bizi',
#  '__nlp__.bizim',
#  '__nlp__.bjp',
#  '__nlp__.black',
#  '__nlp__.black history',
#  '__nlp__.black history month',
#  '__nlp__.blackhistorymonth',
#  '__nlp__.blackpink',
#  '__nlp__.blackpink https',
#  '__nlp__.blackpink https co',
#  '__nlp__.blame',
#  '__nlp__.blessed',
#  '__nlp__.block',
#  '__nlp__.blog',
#  '__nlp__.blood',
#  '__nlp__.blue',
#  '__nlp__.boa',
#  '__nlp__.board',
#  '__nlp__.bobby',
#  '__nlp__.boca',
#  '__nlp__.body',
#  '__nlp__.boleh',
#  '__nlp__.bolsonaro',
#  '__nlp__.bom',
#  '__nlp__.bom dia',
#  '__nlp__.bon',
#  '__nlp__.boninho',
#  '__nlp__.bonito',
#  '__nlp__.book',
#  '__nlp__.books',
#  '__nlp__.bora',
#  '__nlp__.border',
#  '__nlp__.born',
#  '__nlp__.boss',
#  '__nlp__.both',
#  '__nlp__.bought',
#  '__nlp__.bout',
#  '__nlp__.bowl',
#  '__nlp__.box',
#  '__nlp__.boy',
#  '__nlp__.boyfriend',
#  '__nlp__.boys',
#  '__nlp__.boğaziçi',
#  '__nlp__.br',
#  '__nlp__.brady',
#  '__nlp__.brain',
#  '__nlp__.brand',
#  '__nlp__.brasil',
#  '__nlp__.brasileiro',
#  '__nlp__.break',
#  '__nlp__.breakfast',
#  '__nlp__.breaking',
#  '__nlp__.breaks',
#  '__nlp__.brexit',
#  '__nlp__.brian',
#  '__nlp__.briefing',
#  '__nlp__.brilliant',
#  '__nlp__.bring',
#  '__nlp__.bringing',
#  '__nlp__.brings',
#  '__nlp__.british',
#  '__nlp__.bro',
#  '__nlp__.broke',
#  '__nlp__.broken',
#  '__nlp__.brother',
#  '__nlp__.brought',
#  '__nlp__.brown',
#  '__nlp__.bruno',
#  '__nlp__.btc',
#  '__nlp__.bts',
#  '__nlp__.bts bts',
#  '__nlp__.bts bts twt',
#  '__nlp__.bts twt',
#  '__nlp__.bts twt https',
#  '__nlp__.bts 방탄소년단',
#  '__nlp__.bts 방탄소년단 bts',
#  '__nlp__.btw',
#  '__nlp__.bu',
#  '__nlp__.buat',
#  '__nlp__.budget',
#  '__nlp__.buen',
#  '__nlp__.buena',
#  '__nlp__.buenas',
#  '__nlp__.buenas noches',
#  '__nlp__.bueno',
#  '__nlp__.buenos',
#  '__nlp__.buenos días',
#  '__nlp__.bugün',
#  '__nlp__.build',
#  '__nlp__.building',
#  '__nlp__.built',
#  '__nlp__.bunch',
#  '__nlp__.bunch of',
#  '__nlp__.bunny',
#  '__nlp__.bunu',
#  '__nlp__.business',
#  '__nlp__.businesses',
#  '__nlp__.busy',
#  '__nlp__.but',
#  '__nlp__.but also',
#  '__nlp__.but don',
#  '__nlp__.but he',
#  '__nlp__.but it',
#  '__nlp__.but it unk',
#  '__nlp__.but not',
#  '__nlp__.but the',
#  '__nlp__.but they',
#  '__nlp__.but this',
#  '__nlp__.but unk',
#  '__nlp__.but we',
#  '__nlp__.but you',
#  '__nlp__.buy',
#  '__nlp__.buying',
#  '__nlp__.by',
#  '__nlp__.by https',
#  '__nlp__.by https co',
#  '__nlp__.by the',
#  '__nlp__.bye',
#  '__nlp__.böyle',
#  '__nlp__.büyük',
#  '__nlp__.ca',
#  '__nlp__.cabeça',
#  '__nlp__.cada',
#  '__nlp__.cada vez',
#  '__nlp__.caio',
#  '__nlp__.cake',
#  '__nlp__.california',
#  '__nlp__.call',
#  '__nlp__.call me',
#  '__nlp__.called',
#  '__nlp__.calling',
#  '__nlp__.calls',
#  '__nlp__.cam',
#  '__nlp__.cama',
#  '__nlp__.cambio',
#  '__nlp__.came',
#  '__nlp__.camera',
#  '__nlp__.camino',
#  '__nlp__.camp',
#  '__nlp__.campaign',
#  '__nlp__.campaña',
#  '__nlp__.campo',
#  '__nlp__.can',
#  '__nlp__.can be',
#  '__nlp__.can do',
#  '__nlp__.can get',
#  '__nlp__.can have',
#  '__nlp__.can see',
#  '__nlp__.can unk',
#  '__nlp__.can unk believe',
#  '__nlp__.can unk wait',
#  '__nlp__.can wait',
#  '__nlp__.can we',
#  '__nlp__.can you',
#  '__nlp__.canada',
#  '__nlp__.canal',
#  '__nlp__.cancel',
#  '__nlp__.cancer',
#  '__nlp__.cannot',
#  '__nlp__.cant',
#  '__nlp__.cap',
#  '__nlp__.capital',
#  '__nlp__.capitol',
#  '__nlp__.captain',
#  '__nlp__.car',
#  '__nlp__.cara',
#  '__nlp__.cara de',
#  '__nlp__.caralho',
#  '__nlp__.card',
#  '__nlp__.cards',
#  '__nlp__.care',
#  '__nlp__.care about',
#  '__nlp__.care of',
#  '__nlp__.career',
#  '__nlp__.cargo',
#  '__nlp__.carla',
#  '__nlp__.carlos',
#  '__nlp__.casa',
#  '__nlp__.case',
#  '__nlp__.cases',
#  '__nlp__.cash',
#  '__nlp__.casi',
#  '__nlp__.caso',
#  '__nlp__.casos',
#  '__nlp__.cast',
#  '__nlp__.cat',
#  '__nlp__.catch',
#  '__nlp__.cats',
#  '__nlp__.caught',
#  '__nlp__.causa',
#  '__nlp__.cause',
#  '__nlp__.cc',
#  '__nlp__.ce',
#  '__nlp__.ce soir',
#  '__nlp__.celebrate',
#  '__nlp__.celebrating',
#  '__nlp__.celebrity',
#  '__nlp__.center',
#  '__nlp__.central',
#  '__nlp__.centre',
#  '__nlp__.centro',
#  '__nlp__.century',
#  '__nlp__.ceo',
#  '__nlp__.cerca',
#  '__nlp__.certain',
#  '__nlp__.certo',
#  '__nlp__.ces',
#  '__nlp__.cet',
#  '__nlp__.cette',
#  '__nlp__.chair',
#  '__nlp__.challenge',
#  '__nlp__.challenges',
#  '__nlp__.champion',
#  '__nlp__.champions',
#  '__nlp__.championship',
#  '__nlp__.chan',
#  '__nlp__.chance',
#  '__nlp__.chance to',
#  '__nlp__.chance to win',
#  '__nlp__.change',
#  '__nlp__.changed',
#  '__nlp__.changes',
#  '__nlp__.changing',
#  '__nlp__.channel',
#  '__nlp__.chapter',
#  '__nlp__.character',
#  '__nlp__.characters',
#  '__nlp__.charge',
#  '__nlp__.chart',
#  '__nlp__.chat',
#  '__nlp__.che',
#  '__nlp__.check',
#  '__nlp__.check it',
#  '__nlp__.check out',
#  '__nlp__.checked',
#  '__nlp__.checks',
#  '__nlp__.chega',
#  '__nlp__.chelsea',
#  '__nlp__.chi',
#  '__nlp__.chicken',
#  '__nlp__.chief',
#  '__nlp__.chiefs',
#  '__nlp__.child',
#  '__nlp__.children',
#  '__nlp__.chile',
#  '__nlp__.chill',
#  '__nlp__.china',
#  '__nlp__.chinese',
#  '__nlp__.choice',
#  '__nlp__.choose',
#  '__nlp__.chorando',
#  '__nlp__.chris',
#  '__nlp__.christian',
#  '__nlp__.ci',
#  '__nlp__.cima',
#  '__nlp__.city',
#  '__nlp__.ciudad',
#  '__nlp__.civil',
#  '__nlp__.claim',
#  '__nlp__.claims',
#  '__nlp__.claro',
#  '__nlp__.class',
#  '__nlp__.classic',
#  '__nlp__.clean',
#  '__nlp__.clear',
#  '__nlp__.clearly',
#  '__nlp__.click',
#  '__nlp__.climate',
#  '__nlp__.climate change',
#  '__nlp__.clip',
#  '__nlp__.close',
#  '__nlp__.close to',
#  '__nlp__.closed',
#  '__nlp__.cls 10',
#  '__nlp__.cls 20',
#  '__nlp__.cls 2021',
#  '__nlp__.cls 24',
#  '__nlp__.cls after',
#  '__nlp__.cls ah',
#  '__nlp__.cls ahora',
#  '__nlp__.cls ai',
#  '__nlp__.cls all',
#  '__nlp__.cls also',
#  '__nlp__.cls am',
#  '__nlp__.cls an',
#  '__nlp__.cls and',
#  '__nlp__.cls another',
#  '__nlp__.cls anyone',
#  '__nlp__.cls are',
#  '__nlp__.cls are you',
#  '__nlp__.cls as',
#  '__nlp__.cls at',
#  '__nlp__.cls ben',
#  '__nlp__.cls biden',
#  '__nlp__.cls big',
#  '__nlp__.cls bir',
#  '__nlp__.cls bom',
#  '__nlp__.cls bom dia',
#  '__nlp__.cls breaking',
#  '__nlp__.cls bts',
#  '__nlp__.cls bu',
#  '__nlp__.cls can',
#  '__nlp__.cls can unk',
#  '__nlp__.cls check',
#  '__nlp__.cls como',
#  '__nlp__.cls con',
#  '__nlp__.cls congratulations',
#  '__nlp__.cls cuando',
#  '__nlp__.cls de',
#  '__nlp__.cls dear',
#  '__nlp__.cls did',
#  '__nlp__.cls do',
#  '__nlp__.cls do you',
#  '__nlp__.cls don',
#  '__nlp__.cls don unk',
#  '__nlp__.cls el',
#  '__nlp__.cls en',
#  '__nlp__.cls es',
#  ...]

# %%
predictor.feature_importance(test_data, feature_stage='transformed')
# Out:
# Computing feature importance via permutation shuffling for 6451 features using 5000 rows with 5 shuffle sets...
# 	5124.57s	= Expected runtime (1024.91s per shuffle set)
# 	5657.87s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                     importance    stddev   p_value  n  \
# engagee_follows_engager                0.00008  0.000110  0.088904  5
# engaged_with_user_follower_count       0.00000  0.000000  0.500000  5
# __nlp__.solo                           0.00000  0.000000  0.500000  5
# __nlp__.sometimes                      0.00000  0.000000  0.500000  5
# __nlp__.something                      0.00000  0.000000  0.500000  5
# ...                                        ...       ...       ... ..
# tweet.symbol_count.:                  -0.00004  0.000089  0.813050  5
# tweet_type                            -0.00004  0.000089  0.813050  5
# engaged_with_user_id                  -0.00008  0.000110  0.911096  5
# engaging_user_account_creation.day    -0.00012  0.000110  0.964758  5
# engaging_user_follower_count          -0.00012  0.000110  0.964758  5
#
#                                     p99_high   p99_low
# engagee_follows_engager             0.000306 -0.000146
# engaged_with_user_follower_count    0.000000  0.000000
# __nlp__.solo                        0.000000  0.000000
# __nlp__.sometimes                   0.000000  0.000000
# __nlp__.something                   0.000000  0.000000
# ...                                      ...       ...
# tweet.symbol_count.:                0.000144 -0.000224
# tweet_type                          0.000144 -0.000224
# engaged_with_user_id                0.000146 -0.000306
# engaging_user_account_creation.day  0.000106 -0.000346
# engaging_user_follower_count        0.000106 -0.000346
#
# [6451 rows x 6 columns]
