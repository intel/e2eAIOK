# %%
import pandas as pd

dir_path = "/home/vmagent/app/recdp/dataset/outbrain_raw/sampled"
#dir_path = "/home/vmagent/app/recdp/dataset/outbrain_raw/orig"

file_list = {
    'clicks': "clicks_train.csv",
    'documents_categories': "documents_categories.csv",
    'documents_entities': "documents_entities.csv",
    'documents_meta': "documents_meta.csv",
    'documents_topics': "documents_topics.csv",
    'events': "events.csv",
    'page_views': "page_views_sample.csv",
    'promoted_content': "promoted_content.csv"
}

df_list = {}

for f_name, f_path in file_list.items():
    df_list[f_name] = {"data": pd.read_csv(f"{dir_path}/{f_path}")}

# %%
for df_name, df_info in df_list.items():
    print(f"{df_name}: {list(df_info['data'].columns)}")
# Out:
# clicks: ['display_id', 'ad_id', 'clicked']
# documents_categories: ['document_id', 'category_id', 'confidence_level']
# documents_entities: ['document_id', 'entity_id', 'confidence_level']
# documents_meta: ['document_id', 'source_id', 'publisher_id', 'publish_time']
# documents_topics: ['document_id', 'topic_id', 'confidence_level']
# events: ['display_id', 'uuid', 'document_id', 'timestamp', 'platform', 'geo_location']
# page_views: ['uuid', 'document_id', 'timestamp', 'platform', 'geo_location', 'traffic_source']
# promoted_content: ['ad_id', 'document_id', 'campaign_id', 'advertiser_id']

# %%
# define necessary functions

def find_column_with_prefix(df, to_find_name):
    idx = 0
    rename_list = {}
    for col_name in df.columns:
        if col_name.startswith(f"{to_find_name}_"):
            rename_list[col_name] = f"{to_find_name}_{idx}"
            idx += 1
    return rename_list
            
def combine_same_columns(df):
    to_rename_columns = []
    for col_name in df.columns:
        if col_name.endswith("_x"):
            to_rename_dict = {col_name: col_name[:-2]}
            df = df.rename(columns = to_rename_dict)
        if col_name.endswith("_y"):
            if col_name[:-2] not in to_rename_columns:
                to_rename_columns.append(col_name[:-2])
    # find all columns use to_rename_columns
    to_rename_dict = {}
    for col_name in to_rename_columns:
        to_rename_dict.update(find_column_with_prefix(df, col_name))
    if(len(to_rename_dict) > 0):
        print(to_rename_dict)
    df = df.rename(columns = to_rename_dict)
    return df

def merge_tables(df_list, main_table, to_merge):
    ret_df = main_table
    for df_name, df_info in df_list.items():
        if df_name not in to_merge:
            continue
        df_indexed = df_info["data"]
        #print(df_indexed)
        with Timer(f"merge {df_name} to main_table"):
            ret_df = ret_df.merge(df_indexed, on=df_info["primary_keys"], how="outer")
            ret_df = combine_same_columns(ret_df)
            ret_df = ret_df.dropna(subset=['clicked'])
    return ret_df

def find_tables_share_same_feature(df_list, target_table, candidates):
    related_tables = {}
    for t in candidates:
        for key in df_list[t]['data'].columns:
            if key in target_table.columns:
                if t not in related_tables:
                    related_tables[t] = []
                related_tables[t].append(key)
    return related_tables

# %%
df_list["clicks"]["data"]
# Out:
#         display_id   ad_id  clicked
# 0          7485900   34053        0
# 1          4060011   94860        0
# 2          6753026  367622        0
# 3          2811702   64255        0
# 4         16687744  230212        1
# ...            ...     ...      ...
# 871412     5768881  406501        0
# 871413    14904301  470780        0
# 871414      275389  221644        0
# 871415     3315522  262638        0
# 871416     7812793  153330        0
#
# [871417 rows x 3 columns]

# %%
from utils import Timer
# 1. use forward methods to find related tables
table_relations = {}
target_table = df_list["clicks"]["data"]
candidate_tables = ["documents_meta", "documents_categories", "documents_entities", "documents_topics", "events", "page_views", "promoted_content"]
with Timer("Detect relations"):
    table_relations = find_tables_share_same_feature(df_list, target_table, candidate_tables)
    print(table_relations)

with Timer("merge tables"):
    for table_name, primary_keys in table_relations.items():
        df_list[table_name]["primary_keys"] = primary_keys
    train_df = merge_tables(df_list, target_table, table_relations.keys())

train_df
# Out:
# {'events': ['display_id'], 'promoted_content': ['ad_id']}
# Detect relations took 0.00032424391247332096 sec
#   merge events to main_table took 0.46689542080275714 sec
# {'document_id_y': 'document_id_0'}
#   merge promoted_content to main_table took 0.4212398948147893 sec
# merge tables took 0.8882813840173185 sec
#         display_id     ad_id  clicked uuid  document_id  timestamp  platform  \
# 0        7485900.0   34053.0      0.0  NaN          NaN        NaN       NaN
# 1        7485900.0   34053.0      0.0  NaN          NaN        NaN       NaN
# 2        7591078.0   34053.0      0.0  NaN          NaN        NaN       NaN
# 3        7564828.0   34053.0      0.0  NaN          NaN        NaN       NaN
# 4        8849891.0   34053.0      0.0  NaN          NaN        NaN       NaN
# ...            ...       ...      ...  ...          ...        ...       ...
# 871477    577788.0  333623.0      0.0  NaN          NaN        NaN       NaN
# 871478  14758398.0  378951.0      0.0  NaN          NaN        NaN       NaN
# 871479   2652289.0  105833.0      1.0  NaN          NaN        NaN       NaN
# 871480   1781046.0  121526.0      1.0  NaN          NaN        NaN       NaN
# 871481   7812793.0  153330.0      0.0  NaN          NaN        NaN       NaN
#
#        geo_location  document_id_0  campaign_id  advertiser_id
# 0               NaN            NaN          NaN            NaN
# 1               NaN            NaN          NaN            NaN
# 2               NaN            NaN          NaN            NaN
# 3               NaN            NaN          NaN            NaN
# 4               NaN            NaN          NaN            NaN
# ...             ...            ...          ...            ...
# 871477          NaN            NaN          NaN            NaN
# 871478          NaN            NaN          NaN            NaN
# 871479          NaN            NaN          NaN            NaN
# 871480          NaN            NaN          NaN            NaN
# 871481          NaN            NaN          NaN            NaN
#
# [871482 rows x 11 columns]

# %%
# 2. use forward methods to find related tables
table_relations = {}
target_table = train_df
candidate_tables = ["documents_meta", "documents_categories", "documents_entities", "documents_topics", "page_views",]
with Timer("Detect relations"):
    table_relations = find_tables_share_same_feature(df_list, target_table, candidate_tables)
    print(table_relations)

with Timer("merge tables"):
    # 2. merge table based on the detected relation
    for table_name, primary_keys in table_relations.items():
        df_list[table_name]["primary_keys"] = primary_keys
    train_df = merge_tables(df_list, target_table, table_relations.keys())
train_df
# Out:
# {'documents_meta': ['document_id'], 'documents_categories': ['document_id'], 'documents_entities': ['document_id'], 'documents_topics': ['document_id'], 'page_views': ['uuid', 'document_id', 'timestamp', 'platform', 'geo_location']}
# Detect relations took 8.813710883259773e-05 sec
#   merge documents_categories to main_table took 0.37086312007158995 sec
# {'confidence_level_y': 'confidence_level_0'}
#   merge documents_entities to main_table took 0.4776874191593379 sec
#   merge documents_meta to main_table took 0.5054727380629629 sec
# {'confidence_level_0': 'confidence_level_0', 'confidence_level_y': 'confidence_level_1'}
#   merge documents_topics to main_table took 0.7566020439844579 sec
#   merge page_views to main_table took 0.9657695100177079 sec
# merge tables took 3.076802648836747 sec
#         display_id     ad_id  clicked            uuid  document_id  \
# 0        7485900.0   34053.0      0.0             NaN          NaN
# 1        7485900.0   34053.0      0.0             NaN          NaN
# 2        7591078.0   34053.0      0.0             NaN          NaN
# 3        7564828.0   34053.0      0.0             NaN          NaN
# 4        8849891.0   34053.0      0.0             NaN          NaN
# ...            ...       ...      ...             ...          ...
# 871489   4850270.0  176284.0      1.0  a03a28d6a2fa7a    2077741.0
# 871490   1319387.0   80057.0      0.0  56b1c264be6b66    1865507.0
# 871491  12038860.0  483296.0      0.0  ec48c58e0887a9    1955760.0
# 871492   1022938.0  330898.0      0.0  565e57d5c44f7a    1779423.0
# 871493  15510792.0    2360.0      0.0  73857f40aae4b3    1073139.0
#
#            timestamp  platform geo_location  document_id_0  campaign_id  ...  \
# 0                NaN       NaN          NaN            NaN          NaN  ...
# 1                NaN       NaN          NaN            NaN          NaN  ...
# 2                NaN       NaN          NaN            NaN          NaN  ...
# 3                NaN       NaN          NaN            NaN          NaN  ...
# 4                NaN       NaN          NaN            NaN          NaN  ...
# ...              ...       ...          ...            ...          ...  ...
# 871489  3.144712e+08       1.0    US>NY>501      1444732.0      21472.0  ...
# 871490  7.897891e+07       2.0    US>NJ>501            NaN          NaN  ...
# 871491  8.069815e+08       1.0    US>OH>510            NaN          NaN  ...
# 871492  6.253706e+07       2.0    US>TX>623      1389793.0      19964.0  ...
# 871493  1.029200e+09       1.0        CA>BC            NaN          NaN  ...
#
#         category_id  confidence_level  entity_id confidence_level_0  \
# 0               NaN               NaN        NaN                NaN
# 1               NaN               NaN        NaN                NaN
# 2               NaN               NaN        NaN                NaN
# 3               NaN               NaN        NaN                NaN
# 4               NaN               NaN        NaN                NaN
# ...             ...               ...        ...                ...
# 871489          NaN               NaN        NaN                NaN
# 871490          NaN               NaN        NaN                NaN
# 871491          NaN               NaN        NaN                NaN
# 871492          NaN               NaN        NaN                NaN
# 871493          NaN               NaN        NaN                NaN
#
#         source_id  publisher_id         publish_time topic_id  \
# 0             NaN           NaN                  NaN      NaN
# 1             NaN           NaN                  NaN      NaN
# 2             NaN           NaN                  NaN      NaN
# 3             NaN           NaN                  NaN      NaN
# 4             NaN           NaN                  NaN      NaN
# ...           ...           ...                  ...      ...
# 871489     6869.0          41.0  2016-06-16 22:00:00      NaN
# 871490        NaN           NaN                  NaN      NaN
# 871491        NaN           NaN                  NaN      NaN
# 871492        NaN           NaN                  NaN      NaN
# 871493        NaN           NaN                  NaN      NaN
#
#         confidence_level_1  traffic_source
# 0                      NaN             NaN
# 1                      NaN             NaN
# 2                      NaN             NaN
# 3                      NaN             NaN
# 4                      NaN             NaN
# ...                    ...             ...
# 871489                 NaN             NaN
# 871490                 NaN             NaN
# 871491                 NaN             NaN
# 871492                 NaN             NaN
# 871493                 NaN             NaN
#
# [871494 rows x 21 columns]

# %%
train_df = train_df.dropna(subset=['uuid', 'document_id', 'timestamp'])

# %%
filter_cond = train_df['display_id'].to_list()
df_list['clicks']['data'][df_list['clicks']['data']['display_id'].isin(filter_cond)].to_csv(f"{dir_path}/clicks_small.csv", index=False)

# %%
pd.read_csv(f"{dir_path}/clicks_small.csv")
# Out:
#       display_id   ad_id  clicked
# 0       16284020   81182        0
# 1       10851688  198590        0
# 2        4419817   44953        0
# 3         970696    1976        0
# 4       10118455  146534        0
# ...          ...     ...      ...
# 8708    13049659   44146        0
# 8709    16742628  183739        0
# 8710    12521380   85217        1
# 8711     1823452  252531        0
# 8712    11704475  252587        0
#
# [8713 rows x 3 columns]

# %% [markdown]
# # Backup

# %%
# 1. do data wrangling to each table
def get_day_from_timestamp(ts_s):
    np_ts = ts_s.to_numpy()
    np_day = (np_ts / 1000 / 3600 / 24).astype(int)
    return pd.Series(np_day)

def index_table(df, groupby_key):
    list_keys = [i for i in df.columns if i != groupby_key]
    return df.groupby(groupby_key).agg({i: lambda x: list(x) for i in list_keys})

# TODO: using incremental method to fill publisher_id for every documents_meta entry

# TODO: create new feature for geo info

df_list['events']['day'] = get_day_from_timestamp(df_list['events']['timestamp'])
df_list['page_views']['day'] = get_day_from_timestamp(df_list['page_views']['timestamp'])

df_list['documents_categories'] = index_table(df_list['documents_categories'], 'document_id')
df_list['documents_topics'] = index_table(df_list['documents_topics'], 'document_id')
df_list['documents_entities'] = index_table(df_list['documents_entities'], 'document_id')

# %%
# 2. merge documents files with 'document_id' as key into one documents_df

documents_df = df_list['documents_meta'].merge(df_list['documents_categories'], on="document_id", how="left")
documents_df = documents_df.merge(df_list['documents_topics'], on="document_id", how="left")
documents_df = documents_df.merge(df_list['documents_entities'], on="document_id", how="left")

# %%
# 3. use page_views and documents to create users_profile_df

page_views_train_df = df_list['page_views'].merge(documents_df, on='document_id', how='left')

# select columns
# fill na
# 1. group by index key
users_profile_df = index_table(page_views_train_df, "uuid")
# 2. create new features: num_views, categories, topics, entities
# noted: categories, topics, entities are tf-idfs -> TODO

# %%
# 4. use document_meta and page_views to add more info for events

events_df = df_list['events'].merge(df_list['documents_meta'], on="document_id", how="left")
events_df = events_df.merge(df_list['page_views'], on=["uuid", "document_id", "platform", "geo_location", "day"], how="left")

# %%
clicks_train_df = df_list['clicks'].merge(df_list['promoted_content'], on = 'ad_id', how='left')
clicks_train_df = clicks_train_df.merge(df_list['documents_meta'], on = 'document_id', how='left')
clicks_train_df = clicks_train_df.merge(events_df, on = 'display_id', how='left')

# %%
clicks_train_df
# Out:
#         display_id   ad_id  clicked  document_id_x  campaign_id  \
# 0          7485900   34053        0            NaN          NaN
# 1          4060011   94860        0            NaN          NaN
# 2          6753026  367622        0            NaN          NaN
# 3          2811702   64255        0            NaN          NaN
# 4         16687744  230212        1            NaN          NaN
# ...            ...     ...      ...            ...          ...
# 871477     5768881  406501        0            NaN          NaN
# 871478    14904301  470780        0            NaN          NaN
# 871479      275389  221644        0            NaN          NaN
# 871480     3315522  262638        0            NaN          NaN
# 871481     7812793  153330        0            NaN          NaN
#
#         advertiser_id  source_id_x  publisher_id_x publish_time_x uuid  \
# 0                 NaN          NaN             NaN            NaN  NaN
# 1                 NaN          NaN             NaN            NaN  NaN
# 2                 NaN          NaN             NaN            NaN  NaN
# 3                 NaN          NaN             NaN            NaN  NaN
# 4                 NaN          NaN             NaN            NaN  NaN
# ...               ...          ...             ...            ...  ...
# 871477            NaN          NaN             NaN            NaN  NaN
# 871478            NaN          NaN             NaN            NaN  NaN
# 871479            NaN          NaN             NaN            NaN  NaN
# 871480            NaN          NaN             NaN            NaN  NaN
# 871481            NaN          NaN             NaN            NaN  NaN
#
#         document_id_y  timestamp_x  platform geo_location  day  source_id_y  \
# 0                 NaN          NaN       NaN          NaN  NaN          NaN
# 1                 NaN          NaN       NaN          NaN  NaN          NaN
# 2                 NaN          NaN       NaN          NaN  NaN          NaN
# 3                 NaN          NaN       NaN          NaN  NaN          NaN
# 4                 NaN          NaN       NaN          NaN  NaN          NaN
# ...               ...          ...       ...          ...  ...          ...
# 871477            NaN          NaN       NaN          NaN  NaN          NaN
# 871478            NaN          NaN       NaN          NaN  NaN          NaN
# 871479            NaN          NaN       NaN          NaN  NaN          NaN
# 871480            NaN          NaN       NaN          NaN  NaN          NaN
# 871481            NaN          NaN       NaN          NaN  NaN          NaN
#
#         publisher_id_y publish_time_y  timestamp_y  traffic_source
# 0                  NaN            NaN          NaN             NaN
# 1                  NaN            NaN          NaN             NaN
# 2                  NaN            NaN          NaN             NaN
# 3                  NaN            NaN          NaN             NaN
# 4                  NaN            NaN          NaN             NaN
# ...                ...            ...          ...             ...
# 871477             NaN            NaN          NaN             NaN
# 871478             NaN            NaN          NaN             NaN
# 871479             NaN            NaN          NaN             NaN
# 871480             NaN            NaN          NaN             NaN
# 871481             NaN            NaN          NaN             NaN
#
# [871482 rows x 20 columns]

# %%
# 2. create documents meta
# 2.1 convert documents infos to use 'documents_id' as index
df_list['documents_categories'] = df_list['documents_categories'].groupby("document_id").apply(list)


documents_df = df_list['documents_meta'].merge(df_list['documents_categories'], on="document_id", how="left")
documents_df = documents_df.merge(df_list['documents_topics'], on="document_id", how="left")
documents_df = documents_df.merge(df_list['documents_entities'], on="document_id", how="left")

    documents_categories_grouped_df,
    on=F.col("document_id_doc") == F.col("documents_categories_grouped.document_id_cat"),
    how='left') \
    .join(documents_topics_grouped_df,
          on=F.col("document_id_doc") == F.col("documents_topics_grouped.document_id_top"),
          how='left') \
    .join(documents_entities_grouped_df,
          on=F.col("document_id_doc") == F.col("documents_entities_grouped.document_id_ent"),
          how='left') \
    .cache()

# %%
train_df[['display_id', 'day_event']]
# Out:
#         display_id   ad_id  clicked  document_id_x  campaign_id  \
# 0          7485900   34053        0         873183         4988
# 1          4060011   94860        0         842023         8043
# 2          6753026  367622        0        1550906        29896
# 3          2811702   64255        0         747047         8568
# 4         16687744  230212        1         934549        19284
# ...            ...     ...      ...            ...          ...
# 871447     5768881  406501        0        1670786        27502
# 871448    14904301  470780        0        2319414        17402
# 871449      275389  221644        0        1559982         5125
# 871450     3315522  262638        0        1635743        26690
# 871451     7812793  153330        0         919842        18825
#
#         advertiser_id uuid  document_id_y  timestamp  platform geo_location
# 0                1973  NaN            NaN        NaN       NaN          NaN
# 1                 394  NaN            NaN        NaN       NaN          NaN
# 2                1650  NaN            NaN        NaN       NaN          NaN
# 3                1077  NaN            NaN        NaN       NaN          NaN
# 4                3283  NaN            NaN        NaN       NaN          NaN
# ...               ...  ...            ...        ...       ...          ...
# 871447           2879  NaN            NaN        NaN       NaN          NaN
# 871448           1055  NaN            NaN        NaN       NaN          NaN
# 871449            628  NaN            NaN        NaN       NaN          NaN
# 871450           1684  NaN            NaN        NaN       NaN          NaN
# 871451           1650  NaN            NaN        NaN       NaN          NaN
#
# [871452 rows x 11 columns]

# %%
# promoted_content process
# drop na of geo_location and platform

# %%
for f_name, df in df_list.items():
    print(f_name)
    display(df)
# Out:
# clicks
#         display_id   ad_id  clicked
# 0          7485900   34053        0
# 1          4060011   94860        0
# 2          6753026  367622        0
# 3          2811702   64255        0
# 4         16687744  230212        1
# ...            ...     ...      ...
# 871412     5768881  406501        0
# 871413    14904301  470780        0
# 871414      275389  221644        0
# 871415     3315522  262638        0
# 871416     7812793  153330        0
#
# [871417 rows x 3 columns]
# documents_categories
#        document_id  category_id  confidence_level
# 0          2352362         1708          0.780317
# 1          1594739         1702          0.920000
# 2          1805482         1909          0.920000
# 3          2918616         1909          0.070000
# 4          2612162         1702          0.372515
# ...            ...          ...               ...
# 54810       932786         1408          0.920000
# 54811       120841         1513          0.920000
# 54812      1115090         1702          0.033258
# 54813      1072518         1904          0.056042
# 54814      2253400         1907          0.652935
#
# [54815 rows x 3 columns]
# documents_entities
#        document_id                         entity_id  confidence_level
# 0          1165831  1ef5e52a1d88a24d106e3ac4d07c053d          0.371870
# 1          1050055  95f9914cccd5d27523c3f8fdb26ec974          0.429142
# 2           477528  a37b04d4455859fac64e1f2da229ca19          0.221397
# 3          1482012  ae25657b0f0f63a5036f8dffd77bd257          0.208224
# 4           624144  e3e4b172a6e3fe3a428fb8d0f18cc611          0.752378
# ...            ...                               ...               ...
# 55371      1758005  d38aa3238f050676fb217363b4793d5c          0.249378
# 55372      1787109  8fb694b25a41a6ffbb37870d7b15b9ef          0.863598
# 55373       176867  98bf11f29dd0160f58d870c0c7c6f07f          0.332959
# 55374      1057197  835581bade5c67504d6c0c9135706c67          0.241850
# 55375      1830404  009f59c1c46821fb23464a501893892a          0.777238
#
# [55376 rows x 3 columns]
# documents_meta
#        document_id  source_id  publisher_id         publish_time
# 0           455174      842.0          38.0  2014-08-20 00:00:00
# 1          2757969      465.0         160.0  2016-06-24 07:00:00
# 2           394340        3.0         740.0  2016-07-21 00:00:00
# 3          1493309     1516.0          74.0                  NaN
# 4          1485635     4194.0         723.0  2016-05-23 09:00:00
# ...            ...        ...           ...                  ...
# 29988      1720729      127.0          84.0  2016-06-10 23:00:00
# 29989        49179     1907.0         284.0                  NaN
# 29990      2509249     1929.0         265.0  2016-06-22 13:00:00
# 29991      1938596     3781.0         299.0  2016-06-15 13:00:00
# 29992       345414     4786.0         565.0  2014-06-19 00:00:00
#
# [29993 rows x 4 columns]
# documents_topics
#         document_id  topic_id  confidence_level
# 0           1627006       249          0.124091
# 1           1776107       216          0.092571
# 2           1350395       176          0.053003
# 3           1485624       290          0.067220
# 4            588655       231          0.010365
# ...             ...       ...               ...
# 113255      1047055        37          0.029292
# 113256      1687015        66          0.025900
# 113257       567346       231          0.010365
# 113258      1825982        20          0.052338
# 113259      1526001        37          0.013532
#
# [113260 rows x 3 columns]
# events
#         display_id            uuid  document_id   timestamp  platform  \
# 0          4967935  40dfeb57f000ee      1198481   320930355         1
# 1          8666478  82056b07568174      2272350   584950772         1
# 2         20999551  9c5d03fac43aaa      1381525  1184004787         2
# 3          1241053  f88f4d99844dd4      1479631    74551999         1
# 4         14537827  35d20b3563cdfc      2305575   957265831         2
# ...            ...             ...          ...         ...       ...
# 231196     2140178  a81a8be3c30997       859508   138016907         2
# 231197    15648428  d01a974f0c8cdf      1526957  1039456560         2
# 231198    22777619  fcbf55cd6c90a7      2945036  1277332641         1
# 231199     3755812  3e0870229c1773      2038568   239683133         2
# 231200    14129088  e4ca444ea859f5       235399   928340301         3
#
#        geo_location
# 0         US>AL>698
# 1             ID>30
# 2             NL>15
# 3         US>CA>862
# 4         US>WI>617
# ...             ...
# 231196    US>VA>573
# 231197    US>GA>524
# 231198    US>TX>623
# 231199    US>WI>669
# 231200    US>WI>617
#
# [231201 rows x 6 columns]
# page_views
#                  uuid  document_id  timestamp  platform geo_location  \
# 0      7db77ca87e4258      1786253   40516871         1    US>CO>751
# 1      5938a1ec6e3af5      1482450   49732213         1        PE>15
# 2      ad8604581c44f8      1812224   48401515         1    US>LA>622
# 3      b1727224174818       379054   31169451         2        HK>00
# 4      7e031459822b2d        95516   42031607         2    US>AZ>753
# ...               ...          ...        ...       ...          ...
# 99995  dc40b2f27face0      1833998   47418035         2    US>TX>625
# 99996  117a07a5cbb4f2       838069   47145780         2    US>NY>501
# 99997  1e8fd7477f588b          234   61175061         3    US>MN>613
# 99998  7da577646a63e7        25792   53891075         1    US>MA>506
# 99999  3423abc1c17fbe       809909   42981364         1        GB>H9
#
#        traffic_source
# 0                   1
# 1                   3
# 2                   1
# 3                   2
# 4                   2
# ...               ...
# 99995               1
# 99996               2
# 99997               1
# 99998               1
# 99999               2
#
# [100000 rows x 6 columns]
# promoted_content
#        ad_id  document_id  campaign_id  advertiser_id
# 0     279845      1671112        27551           3074
# 1      28185       668644         4204           1352
# 2      17829       748438         2931           1636
# 3     193642      1484963        22788           3543
# 4     195462       866412        17909           1452
# ...      ...          ...          ...            ...
# 5591   40191       602076         5664           1890
# 5592  326105      1751141        29116           2176
# 5593   36590       899623         5286            823
# 5594  397970      1109919        30667           2874
# 5595  475902      2340053        27166            266
#
# [5596 rows x 4 columns]
