# %% [markdown]
# # RecDP LLM - Prompt Enhancement
#
# This component is using promptsource toolkit for creating, sharing and using natural language prompts to improve the quality of finetune datasets.

# %% [markdown]
# # Get Started

# %% [markdown]
# ## 1. Install pyrecdp and dependencies

# %%
! DEBIAN_FRONTEND=noninteractive apt-get install -qq -y openjdk-8-jre
! pip install -q pyrecdp --pre
# ! pip install 'git+https://github.com/intel/e2eAIOK.git#egg=pyrecdp&subdirectory=RecDP'
# Out:
# /tmp
# Cloning into 'e2eAIOK'...
# remote: Enumerating objects: 13811, done.
# remote: Counting objects: 100% (2668/2668), done.
# remote: Compressing objects: 100% (584/584), done.
# remote: Total 13811 (delta 2191), reused 2298 (delta 2071), pack-reused 11143
# Receiving objects: 100% (13811/13811), 220.68 MiB | 23.67 MiB/s, done.
# Resolving deltas: 100% (8119/8119), done.
# Updating files: 100% (1040/1040), done.
# Branch 'Fix_promptsource_bug' set up to track remote branch 'Fix_promptsource_bug' from 'origin'.
# Switched to a new branch 'Fix_promptsource_bug'
# running sdist
# running egg_info
# creating pyrecdp.egg-info
# writing pyrecdp.egg-info/PKG-INFO
# writing dependency_links to pyrecdp.egg-info/dependency_links.txt
# writing requirements to pyrecdp.egg-info/requires.txt
# writing top-level names to pyrecdp.egg-info/top_level.txt
# writing manifest file 'pyrecdp.egg-info/SOURCES.txt'
# reading manifest file 'pyrecdp.egg-info/SOURCES.txt'
# ...

# %% [markdown]
# ## 2. Prepare your data

# %%
# %mkdir -p /content/test_data
# %cd /content/test_data
# !wget https://raw.githubusercontent.com/intel/e2eAIOK/main/RecDP/tests/data/alpaca/alpaca_data_50.jsonl
# Out:
# /content/test_data
# --2023-11-09 10:27:51--  https://raw.githubusercontent.com/intel/e2eAIOK/main/RecDP/tests/data/alpaca/alpaca_data_50.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25027 (24K) [text/plain]
# Saving to: ‘alpaca_data_50.jsonl.1’
#
# alpaca_data_50.json 100%[===================>]  24.44K  --.-KB/s    in 0.001s
#
# 2023-11-09 10:27:51 (16.2 MB/s) - ‘alpaca_data_50.jsonl.1’ saved [25027/25027]

# %% [markdown]
# ## 3. Text Prompt

# %% [markdown]
# ### 3.1 Process with text prompt

# %%
from pyrecdp.LLM import TextPipeline, ResumableTextPipeline
from pyrecdp.primitives.operations import *

pipeline = ResumableTextPipeline()
ops = [
    JsonlReader("/content/test_data/"),
    TextPrompt(dataset_name="alpaca", prompt_name="causal_llm_1"),
    ParquetWriter("/content/test_data/promot/")
]
pipeline.add_operations(ops)
ret = pipeline.execute()
del pipeline
# Out:
# JAVA_HOME is not set, use default value of /usr/lib/jvm/java-8-openjdk-amd64/
# /usr/local/lib/python3.10/dist-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %% [markdown]
# ### 3.2 View processed data

# %%
import pandas as pd
alpaca_prompt_pd = pd.read_parquet("/content/test_data/promot/alpaca_data_50.jsonl")
alpaca_prompt_pd.head(10)
# Out:
#                                          instruction  \
# 0               Give three tips for staying healthy.
# 1                 What are the three primary colors?
# 2                 Describe the structure of an atom.
# 3                   How can we reduce air pollution?
# 4  Describe a time when you had to make a difficu...
# 5                          Identify the odd one out.
# 6  Explain why the following fraction is equivale...
# 7  Write a short story in third person narration ...
# 8                       Render a 3D model of a house
# 9  Evaluate this sentence for spelling and gramma...
#
#                                           input  \
# 0
# 1
# 2
# 3
# 4
# 5                  Twitter, Instagram, Telegram
# 6                                          4/16
# 7
# 8
# 9  He finnished his meal and left the resturant
#
#                                               output             source_id  \
# 0  1.Eat a balanced diet and make sure to include...  alpaca_data_50.jsonl
# ...
