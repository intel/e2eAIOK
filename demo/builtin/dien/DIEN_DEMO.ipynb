# %% [markdown]
# # DIEN DEMO
#
# Online ads display CTR predication, evolved from DIN(Alibaba) which uses sequence model to simulate user interest evolving process.
#
# * original source
#     * Source repo: https://github.com/alibaba/ai-matrix
#
#
# # Content
# * [Model Architecture](#Model-Architecture)
# * [Optimizations](#Optimizations)
# * [Performance](#Performance-Overview)
# * [Demo](#DEMO)
#
#
# ------
#
# # Model Architecture
#
# <div><img src="./img/dien-arch.png" alt="DIEN Model Architecture" width="600"></div>
#
# * DIEN (from bottom to up)
#     * Behavior layer: convert sequence behaviors to embedding vector
#     * Interest Extractor Layer: extracts interest sequence based on behavior sequence
#     * Interest evolving layer: AUGRU models interest evolving process that is relative to target item.
#
#
# # Optimizations
#
# * Motivation
#     * Original ETL was implemented with pure python
#     * Original Training on single node CPU showed 2.55x gap to GPU
#     * Inference on CPU nodes can be run with 8X parallism
#
# * Data Process
#     * speeding up by 15x
#     * Data Ingestion: Rewrite Data Ingestion wit spark and directly load for preprocessing, 35x speed up
#     * PreProcessing: re-implement DataProcessing with RecDP spark, 12.27x speed up
#
# <div><img src="./img/dien-dataprocessing.png" alt="DIEN Training" width="900"></div>
#
# * Training
#     * Speeding up by 8.12x
#     * Tensorflow optimization: Switch to use Intel optimized Tensorflow2
#     * Optimized DataLoader: complete data categorify in ETL
#     * Scaling out: Scaling out training from single node to 4 CLX-8535 nodes
#
# <div><img src="./img/dien-scaling.png" alt="DIEN Inference" width="900"></div>
#
# * Inference
#     * Improved 882x
#     * inference scaling out from single process on one node to 64 processes on 4 nodes
#     * Optimized DataLoader: complete data categorify in ETL
#     * Multi instance inference
#
#
# # Performance Overview
#
# * For Training
#     * Our optimized DIEN end to end training time on CPU vs. on AWS P4D A100 shows gap as 2.14x(single CLX node), after scaling out to 4 CLX nodes, gap is reduced to 1.05x
# <div><img src="./img/dien-training-perf.png" alt="DIEN Training" width="500"></div>
#
# * For Inference
#     * Our optimized DIEN inference throughput on CPU vs on AWS P4D A100 shows 2.24x better on single CLX, which can be linear scaling out to multiple nodes.
# <div><img src="./img/dien-infer-perf.png" alt="DIEN Inference" width="500"></div>
#
#
# ------

# %% [markdown]
# # DEMO
#
# * [Environment Setup](#Environment-Setup)
# * [Data Process](#Data-Process)
# * [Train](#Train)
# * [Inference](#Inference)

# %% [markdown]
# ## Environment Setup
# ``` bash
# # Setup ENV
# git clone https://github.com/intel/e2eAIOK.git
# cd e2eAIOK
# git submodule update --init --recursive
# python3 scripts/start_e2eaiok_docker.py -b tensorflow -w ${host0} ${host1} ${host2} ${host3} --proxy ""
# ```

# %% [markdown]
# ## Enter Docker
#
# ```
# sshpass -p docker ssh ${host0} -p 12344
# ```

# %% [markdown]
# ## Workflow Prepare
#
# ``` bash
# # prepare model codes
# cd /home/vmagent/app/e2eaiok/modelzoo/dien/train
# sh patch_dien.sh
#
# # Download Dataset
# cd /home/vmagent/app/e2eaiok/modelzoo/dien/feature_engineering/
# ./download_dataset /home/vmagent/app/dataset/
#
# # source spark env
# source /home/spark-env.sh
#
# # Start services
# # only if there is no spark service running, may check ${localhost}:8080 to confirm
# /home/start_spark_service.sh
# ```

# %% [markdown]
# ## Data Process

# %%
# Data Processing
! cd /home/vmagent/app/e2eaiok/modelzoo/dien/feature_engineering/; python preprocessing.py --train --dataset_path /home/vmagent/app/dataset/amazon_reviews_proc/
# Out:
# sr140
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/29 00:53:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/10/29 00:53:59 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# recdp-scala-extension is enabled
# per core memory size is 3.750 GB and shuffle_disk maximum capacity is 1200.000 GB
# start spark process took 4.397668769001029 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small//output//reviews-info
# parse reviews-info with spark took 10.765656954958104 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small//output//item-info
# parse item-info with spark took 7.706160656991415 secs
# load_uid_voc took 21.505661596078426 secs
# load_mid_voc took 2.0955851699691266 secs
# load_cat_voc took 0.09839683200698346 secs
# root
#  |-- asin: string (nullable = true)
#  |-- asin_id: integer (nullable = true)
#  |-- category: string (nullable = true)
#
# root
#  |-- category: string (nullable = true)
#  |-- asin: string (nullable = true)
#  |-- asin_id: integer (nullable = true)
#  |-- cat_id: integer (nullable = true)
#
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small//output//local_test_splitByUser.parquet
# categorify took 9.486099442001432 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small//output//collapsed
# collapse hist took 5.782857689075172 secs
# /home/spark-3.2.1-bin-hadoop3.2/python/pyspark/sql/context.py:127: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small//output//records_with_negative_sample
# add_negative_sample took 8.41070852195844 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small//output//records_with_negative_hists
# add_negative_hist_cols took 2.5248981839977205 secs
# save_to_local_splitByUser took 1.8036975730210543 secs
# Total process time is 71.43828118697274 secs

# %%
# Data Processing for test
! cd /home/vmagent/app/e2eaiok/modelzoo/dien/feature_engineering/; python preprocessing.py --test --dataset_path /home/vmagent/app/dataset/amazon_reviews_proc/
# Out:
# sr140
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/27 16:21:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/10/27 16:21:01 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# recdp-scala-extension is enabled
# per core memory size is 3.750 GB and shuffle_disk maximum capacity is 1200.000 GB
# start spark process took 4.422215551021509 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small/output//reviews-info
# parse reviews-info with spark took 10.50614679302089 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small/output//item-info
# parse item-info with spark took 8.346528457012028 secs
# load_uid_voc took 20.945628019981086 secs
# load_mid_voc took 2.1035494540119544 secs
# load_cat_voc took 0.08788969891611487 secs
# /home/spark-3.2.1-bin-hadoop3.2/python/pyspark/sql/context.py:127: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small/output//test_records_with_negative_hists
# add_negative_hist_cols took 4.714258512016386 secs
# save data to file:////home/vmagent/app/dataset/amazon_reviews_small/output//local_test_splitByUser.parquet
# categorify took 35.755975643056445 secs
# save_to_local_splitByUser took 1.635099616018124 secs
# Total process time is 75.84705228498206 secs

# %% [markdown]
# ## Train

# %% [markdown]
# ### DEMO Single Node Train

# %%
! cp /home/vmagent/app/e2eaiok/modelzoo/dien/meta.yaml /home/vmagent/app/dataset/amazon_reviews/

# %%
# Train (single node)
! cd /home/vmagent/app/e2eaiok/; python -u run_e2eaiok.py --data_path /home/vmagent/app/dataset/amazon_reviews --model_name dien  2>dien_train.log
# Out:
# ===============================================
# ***    Best Trained Model    ***
# ===============================================
#   Model Type: dien
#   Model Saved Path:
#   Sigopt Experiment id is None
#   === Result Metrics ===
# ===============================================
# 2022:10:31-21:11:00:(85796) |WARN| did not find MPI-launcher specific variables, switch to ATL/OFI, to force enable ATL/MPI set CCL_ATL_TRANSPORT=mpi
# local_rank=0, rank=0, size=1
# one_ccl is_enabled:  True
# Advanced train
# {'uid_voc': '/home/vmagent/app/dataset/amazon_reviews/uid_voc.pkl', 'mid_voc': '/home/vmagent/app/dataset/amazon_reviews/mid_voc.pkl', 'cat_voc': '/home/vmagent/app/dataset/amazon_reviews/cat_voc.pkl', 'train_file': '/home/vmagent/app/dataset/amazon_reviews_small/train/local_train_splitByUser', 'test_file': '/home/vmagent/app/dataset/amazon_reviews_small/valid/local_test_splitByUser', 'model_type': 'DIEN', 'seed': 3, 'batch_size': 256, 'data_type': 'FP32'}
# batch_size:  256
# model:  DIEN
# embedding_device cpu
# best model will be saved to /home/vmagent/app/e2eaiok/result/3c3c066abc64c20f027199f6cdfe8ab8/dnn_best_model
# /home/vmagent/app/e2eaiok/result/3c3c066abc64c20f027199f6cdfe8ab8/dnn_best_model/ckpt_noshuffDIEN3
# Number of uid = 8026324, mid = 2330066, cat = 2752
# embedding on cpu
# -----------------------------------
# Start to load Data from disk
# Loading Data from disk is completed with 26.51533532142639 secs, start to train
# iter: 500 ----> train_loss: 1.6046 ---- train_accuracy: 0.5523 ---- train_aux_loss: 1.2653 ---- train_time: 88.368
#  test_auc: 0.6447 ----test_loss: 1.5706 ---- test_accuracy: 0.5986 ---- test_aux_loss: 1.3855 ---- eval_time: 25.925 ---- num_iters: 474
# current auc is 0.6446767201997599, target auc is 0.82
# iter: 1000 ----> train_loss: 1.5868 ---- train_accuracy: 0.5835 ---- train_aux_loss: 1.2554 ---- train_time: 87.205
#  test_auc: 0.6544 ----test_loss: 1.6160 ---- test_accuracy: 0.6107 ---- test_aux_loss: 1.3770 ---- eval_time: 25.580 ---- num_iters: 474
# current auc is 0.6544130420851858, target auc is 0.82
# iter: 1500 ----> train_loss: 1.5786 ---- train_accuracy: 0.5966 ---- train_aux_loss: 1.2505 ---- train_time: 88.792
#  test_auc: 0.6780 ----test_loss: 1.6359 ---- test_accuracy: 0.6315 ---- test_aux_loss: 1.3621 ---- eval_time: 25.600 ---- num_iters: 474
# current auc is 0.6780429097909634, target auc is 0.82
# iteration:  928
# iter: 1954
# Total recommendations: 5120000
# process time breakdown in seconds are session_init 2.423, train_prepare 26.515, train 344.795, test_prepare 17.479, test 77.105, model save 0.000
#
# We found the best model! Here is the model explaination
#
# ===============================================
# ***    Best Trained Model    ***
# ===============================================
#   Model Type: dien
#   Model Saved Path: /home/vmagent/app/e2eaiok/result/3c3c066abc64c20f027199f6cdfe8ab8
#   Sigopt Experiment id is None
#   === Result Metrics ===
#     AUC: 0.6780429097909634
#     training_time: 344.79491233825684
# ===============================================

# %% [markdown]
# ### DEMO Distributed Train

# %%
# Train (4 nodes)
! cat /home/vmagent/app/e2eaiok/conf/e2eaiok_defaults_dien_example.conf
! cd /home/vmagent/app/e2eaiok/; python -u run_e2eaiok.py --data_path /home/vmagent/app/dataset/amazon_reviews_distributed --model_name dien   --conf conf/e2eaiok_defaults_dien_example.conf 2>dien_distributed_train.log
# Out:
# ppn: 4
# iface: ens5f1
# hosts:
# - 10.112.228.19
# - 10.112.228.24
# - 10.112.228.27
# - 10.112.228.30
#
# ===============================================
# ***    Best Trained Model    ***
# ===============================================
#   Model Type: dien
#   Model Saved Path: /home/vmagent/app/e2eaiok/result/dien/20221012_224124/3c3c066abc64c20f027199f6cdfe8ab8
#   Sigopt Experiment id is None
#   === Result Metrics ===
#     AUC: 0.8244640665336023
#     training_time: 1219.0652213096619
# ===============================================
# Filtering local host names.
# Remote host found: 10.112.228.24 10.112.228.27 10.112.228.30
# Checking ssh on all remote hosts.
# SSH was successful into all the remote hosts.
# [2]<stdout>:local_rank=0, rank=2, size=4
# [3]<stdout>:local_rank=0, rank=3, size=4
# [1]<stdout>:local_rank=0, rank=1, size=4
# [0]<stdout>:local_rank=0, rank=0, size=4
# [2]<stdout>:one_ccl is_enabled:  True
# [3]<stdout>:one_ccl is_enabled:  True
# [1]<stdout>:one_ccl is_enabled:  True
# [0]<stdout>:one_ccl is_enabled:  True
# [2]<stdout>:batch_size:  256
# [3]<stdout>:batch_size:  256
# [1]<stdout>:batch_size:  256
# [0]<stdout>:batch_size:  256
# [0]<stdout>:model:  DIEN
# [0]<stdout>:embedding_device cpu
# [1]<stdout>:model:  DIEN
# [1]<stdout>:embedding_device cpu
# [3]<stdout>:model:  DIEN
# [3]<stdout>:embedding_device cpu
# [2]<stdout>:model:  DIEN
# [2]<stdout>:embedding_device cpu
# [0]<stdout>:best model will be saved to /home/vmagent/app/e2eaiok/result/dien/20221012_232451/3c3c066abc64c20f027199f6cdfe8ab8/dnn_best_model
# [0]<stdout>:/home/vmagent/app/e2eaiok/result/dien/20221012_232451/3c3c066abc64c20f027199f6cdfe8ab8/dnn_best_model/ckpt_noshuffDIEN3
# [2]<stdout>:Number of uid = 8026324, mid = 2330066, cat = 2752
# [3]<stdout>:Number of uid = 8026324, mid = 2330066, cat = 2752
# [1]<stdout>:Number of uid = 8026324, mid = 2330066, cat = 2752
# [0]<stdout>:Number of uid = 8026324, mid = 2330066, cat = 2752
# [2]<stdout>:-----------------------------------
# [3]<stdout>:-----------------------------------
# [1]<stdout>:-----------------------------------
# [0]<stdout>:-----------------------------------
# [2]<stdout>:Start to load Data from disk
# [0]<stdout>:Start to load Data from disk
# [3]<stdout>:Start to load Data from disk
# [1]<stdout>:Start to load Data from disk
# [3]<stdout>:Loading Data from disk is completed with 29.545156955718994 secs, start to train
# [0]<stdout>:Loading Data from disk is completed with 29.573992252349854 secs, start to train
# [0]<stdout>:3295
# [1]<stdout>:Loading Data from disk is completed with 29.633468627929688 secs, start to train
# [2]<stdout>:Loading Data from disk is completed with 29.788084745407104 secs, start to train
# [0]<stdout>:iter: 500 ----> train_loss: 1.6698 ---- train_accuracy: 0.5816 ---- train_aux_loss: 1.3364 ---- train_time: 68.144
# [2]<stdout>:iter: 500 ----> train_loss: 1.6738 ---- train_accuracy: 0.5830 ---- train_aux_loss: 1.3410 ---- train_time: 67.936
# [1]<stdout>:iter: 500 ----> train_loss: 1.6678 ---- train_accuracy: 0.5820 ---- train_aux_loss: 1.3344 ---- train_time: 68.081
# [3]<stdout>:iter: 500 ----> train_loss: 1.6739 ---- train_accuracy: 0.5829 ---- train_aux_loss: 1.3405 ---- train_time: 68.182
# [3]<stdout>: test_auc: 0.6876 ----test_loss: 1.6413 ---- test_accuracy: 0.6375 ---- test_aux_loss: 1.3748 ---- eval_time: 14.310 ---- num_iters: 474
# [3]<stdout>:current auc is 0.6876161881832087, target auc is 0.82
# [0]<stdout>: test_auc: 0.6876 ----test_loss: 1.6413 ---- test_accuracy: 0.6375 ---- test_aux_loss: 1.3748 ---- eval_time: 14.805 ---- num_iters: 474
# [0]<stdout>:current auc is 0.6876161881832087, target auc is 0.82
# [1]<stdout>: test_auc: 0.6876 ----test_loss: 1.6413 ---- test_accuracy: 0.6375 ---- test_aux_loss: 1.3748 ---- eval_time: 14.649 ---- num_iters: 474
# [1]<stdout>:current auc is 0.6876161881832087, target auc is 0.82
# [2]<stdout>: test_auc: 0.6876 ----test_loss: 1.6413 ---- test_accuracy: 0.6375 ---- test_aux_loss: 1.3748 ---- eval_time: 26.241 ---- num_iters: 474
# [2]<stdout>:current auc is 0.6876161881832087, target auc is 0.82
# [0]<stdout>:iter: 1000 ----> train_loss: 1.5875 ---- train_accuracy: 0.6332 ---- train_aux_loss: 1.2733 ---- train_time: 73.527
# [2]<stdout>:iter: 1000 ----> train_loss: 1.5854 ---- train_accuracy: 0.6331 ---- train_aux_loss: 1.2711 ---- train_time: 62.801
# [1]<stdout>:iter: 1000 ----> train_loss: 1.5822 ---- train_accuracy: 0.6358 ---- train_aux_loss: 1.2684 ---- train_time: 72.844
# [3]<stdout>:iter: 1000 ----> train_loss: 1.5914 ---- train_accuracy: 0.6331 ---- train_aux_loss: 1.2774 ---- train_time: 73.941
# [3]<stdout>: test_auc: 0.7380 ----test_loss: 1.4996 ---- test_accuracy: 0.6778 ---- test_aux_loss: 1.2184 ---- eval_time: 12.307 ---- num_iters: 474
# [3]<stdout>:current auc is 0.7379803826395592, target auc is 0.82
# [1]<stdout>: test_auc: 0.7380 ----test_loss: 1.4996 ---- test_accuracy: 0.6778 ---- test_aux_loss: 1.2184 ---- eval_time: 12.644 ---- num_iters: 474
# [1]<stdout>:current auc is 0.7379803826395592, target auc is 0.82
# [0]<stdout>: test_auc: 0.7380 ----test_loss: 1.4996 ---- test_accuracy: 0.6778 ---- test_aux_loss: 1.2184 ---- eval_time: 13.059 ---- num_iters: 474
# [0]<stdout>:current auc is 0.7379803826395592, target auc is 0.82
# [2]<stdout>: test_auc: 0.7380 ----test_loss: 1.4996 ---- test_accuracy: 0.6778 ---- test_aux_loss: 1.2184 ---- eval_time: 16.591 ---- num_iters: 474
# [2]<stdout>:current auc is 0.7379803826395592, target auc is 0.82
# [2]<stdout>:iter: 1500 ----> train_loss: 1.4885 ---- train_accuracy: 0.6664 ---- train_aux_loss: 1.1900 ---- train_time: 64.988
# [0]<stdout>:iter: 1500 ----> train_loss: 1.4881 ---- train_accuracy: 0.6671 ---- train_aux_loss: 1.1901 ---- train_time: 68.473
# [3]<stdout>:iter: 1500 ----> train_loss: 1.4909 ---- train_accuracy: 0.6654 ---- train_aux_loss: 1.1922 ---- train_time: 69.187
# [1]<stdout>:iter: 1500 ----> train_loss: 1.4963 ---- train_accuracy: 0.6658 ---- train_aux_loss: 1.1972 ---- train_time: 68.748
# [1]<stdout>: test_auc: 0.7878 ----test_loss: 1.3290 ---- test_accuracy: 0.7222 ---- test_aux_loss: 1.1523 ---- eval_time: 12.855 ---- num_iters: 474
# [1]<stdout>:current auc is 0.7877946883887192, target auc is 0.82
# [2]<stdout>: test_auc: 0.7878 ----test_loss: 1.3290 ---- test_accuracy: 0.7222 ---- test_aux_loss: 1.1523 ---- eval_time: 12.602 ---- num_iters: 474
# [2]<stdout>:current auc is 0.7877946883887192, target auc is 0.82
# [3]<stdout>: test_auc: 0.7878 ----test_loss: 1.3290 ---- test_accuracy: 0.7222 ---- test_aux_loss: 1.1523 ---- eval_time: 12.989 ---- num_iters: 474
# [3]<stdout>:current auc is 0.7877946883887192, target auc is 0.82
# [0]<stdout>: test_auc: 0.7878 ----test_loss: 1.3290 ---- test_accuracy: 0.7222 ---- test_aux_loss: 1.1523 ---- eval_time: 13.401 ---- num_iters: 474
# [0]<stdout>:current auc is 0.7877946883887192, target auc is 0.82
# [1]<stdout>:iter: 2000 ----> train_loss: 1.4357 ---- train_accuracy: 0.6850 ---- train_aux_loss: 1.1471 ---- train_time: 65.744
# [0]<stdout>:iter: 2000 ----> train_loss: 1.4375 ---- train_accuracy: 0.6855 ---- train_aux_loss: 1.1490 ---- train_time: 65.241
# [3]<stdout>:iter: 2000 ----> train_loss: 1.4350 ---- train_accuracy: 0.6866 ---- train_aux_loss: 1.1471 ---- train_time: 65.521
# [2]<stdout>:iter: 2000 ----> train_loss: 1.4345 ---- train_accuracy: 0.6882 ---- train_aux_loss: 1.1482 ---- train_time: 65.655
# [3]<stdout>: test_auc: 0.8055 ----test_loss: 1.3108 ---- test_accuracy: 0.7401 ---- test_aux_loss: 1.0801 ---- eval_time: 11.977 ---- num_iters: 474
# [3]<stdout>:current auc is 0.8054885616440928, target auc is 0.82
# [0]<stdout>: test_auc: 0.8055 ----test_loss: 1.3108 ---- test_accuracy: 0.7401 ---- test_aux_loss: 1.0801 ---- eval_time: 12.752 ---- num_iters: 474
# [0]<stdout>:current auc is 0.8054885616440928, target auc is 0.82
# [1]<stdout>: test_auc: 0.8055 ----test_loss: 1.3108 ---- test_accuracy: 0.7401 ---- test_aux_loss: 1.0801 ---- eval_time: 13.128 ---- num_iters: 474
# [1]<stdout>:current auc is 0.8054885616440928, target auc is 0.82
# [2]<stdout>: test_auc: 0.8055 ----test_loss: 1.3108 ---- test_accuracy: 0.7401 ---- test_aux_loss: 1.0801 ---- eval_time: 16.579 ---- num_iters: 474
# [2]<stdout>:current auc is 0.8054885616440928, target auc is 0.82
# [3]<stdout>:iter: 2500 ----> train_loss: 1.4045 ---- train_accuracy: 0.6987 ---- train_aux_loss: 1.1227 ---- train_time: 69.517
# [2]<stdout>:iter: 2500 ----> train_loss: 1.4117 ---- train_accuracy: 0.7013 ---- train_aux_loss: 1.1315 ---- train_time: 64.551
# [1]<stdout>:iter: 2500 ----> train_loss: 1.4069 ---- train_accuracy: 0.6974 ---- train_aux_loss: 1.1252 ---- train_time: 68.205
# [0]<stdout>:iter: 2500 ----> train_loss: 1.4066 ---- train_accuracy: 0.6985 ---- train_aux_loss: 1.1261 ---- train_time: 68.606
# [3]<stdout>: test_auc: 0.8179 ----test_loss: 1.2575 ---- test_accuracy: 0.7536 ---- test_aux_loss: 1.0438 ---- eval_time: 12.231 ---- num_iters: 474
# [3]<stdout>:current auc is 0.8178629308561842, target auc is 0.82
# [0]<stdout>: test_auc: 0.8179 ----test_loss: 1.2575 ---- test_accuracy: 0.7536 ---- test_aux_loss: 1.0438 ---- eval_time: 12.704 ---- num_iters: 474
# [0]<stdout>:current auc is 0.8178629308561842, target auc is 0.82
# [2]<stdout>: test_auc: 0.8179 ----test_loss: 1.2575 ---- test_accuracy: 0.7536 ---- test_aux_loss: 1.0438 ---- eval_time: 12.544 ---- num_iters: 474
# [2]<stdout>:current auc is 0.8178629308561842, target auc is 0.82
# [1]<stdout>: test_auc: 0.8179 ----test_loss: 1.2575 ---- test_accuracy: 0.7536 ---- test_aux_loss: 1.0438 ---- eval_time: 13.341 ---- num_iters: 474
# [1]<stdout>:current auc is 0.8178629308561842, target auc is 0.82
# [2]<stdout>:iter: 3000 ----> train_loss: 1.3763 ---- train_accuracy: 0.7062 ---- train_aux_loss: 1.1000 ---- train_time: 67.928
# [0]<stdout>:iter: 3000 ----> train_loss: 1.3725 ---- train_accuracy: 0.7095 ---- train_aux_loss: 1.0983 ---- train_time: 68.130
# [3]<stdout>:iter: 3000 ----> train_loss: 1.3711 ---- train_accuracy: 0.7108 ---- train_aux_loss: 1.0968 ---- train_time: 68.837
# [1]<stdout>:iter: 3000 ----> train_loss: 1.3736 ---- train_accuracy: 0.7086 ---- train_aux_loss: 1.0976 ---- train_time: 67.631
# [2]<stdout>: test_auc: 0.8305 ----test_loss: 1.2083 ---- test_accuracy: 0.7641 ---- test_aux_loss: 1.0033 ---- eval_time: 11.635 ---- num_iters: 474
# [2]<stdout>:current auc is 0.8305432393938367, target auc is 0.82
# [2]<stdout>:current AUC 0.8305432393938367 is greater than target 0.82, stop training
# [2]<stdout>:iteration:  474
# [2]<stdout>:iter: 3000
# [2]<stdout>:Total recommendations: 5120000
# [2]<stdout>:process time breakdown in seconds are session_init 6.106, train_prepare 29.788, train 393.859, test_prepare 8.456, test 96.192, model save 0.000
# [1]<stdout>: test_auc: 0.8305 ----test_loss: 1.2083 ---- test_accuracy: 0.7641 ---- test_aux_loss: 1.0033 ---- eval_time: 13.110 ---- num_iters: 474
# [1]<stdout>:current auc is 0.8305432393938367, target auc is 0.82
# [1]<stdout>:current AUC 0.8305432393938367 is greater than target 0.82, stop training
# [1]<stdout>:iteration:  474
# [1]<stdout>:iter: 3000
# [1]<stdout>:Total recommendations: 5120000
# [1]<stdout>:process time breakdown in seconds are session_init 6.110, train_prepare 29.633, train 411.253, test_prepare 9.971, test 79.727, model save 0.000
# [3]<stdout>: test_auc: 0.8305 ----test_loss: 1.2083 ---- test_accuracy: 0.7641 ---- test_aux_loss: 1.0033 ---- eval_time: 13.748 ---- num_iters: 474
# [3]<stdout>:current auc is 0.8305432393938367, target auc is 0.82
# [3]<stdout>:current AUC 0.8305432393938367 is greater than target 0.82, stop training
# [3]<stdout>:iteration:  474
# [3]<stdout>:iter: 3000
# [3]<stdout>:Total recommendations: 5120000
# [3]<stdout>:process time breakdown in seconds are session_init 6.108, train_prepare 29.545, train 415.186, test_prepare 9.411, test 77.560, model save 0.000
# [0]<stdout>: test_auc: 0.8305 ----test_loss: 1.2083 ---- test_accuracy: 0.7641 ---- test_aux_loss: 1.0033 ---- eval_time: 13.736 ---- num_iters: 474
# [0]<stdout>:current auc is 0.8305432393938367, target auc is 0.82
# [0]<stdout>:current AUC 0.8305432393938367 is greater than target 0.82, stop training
# [0]<stdout>:iteration:  474
# [0]<stdout>:iter: 3000
# [0]<stdout>:Total recommendations: 5120000
# [0]<stdout>:process time breakdown in seconds are session_init 6.100, train_prepare 29.574, train 412.121, test_prepare 9.329, test 80.457, model save 0.000
#
# We found the best model! Here is the model explaination
#
# ===============================================
# ***    Best Trained Model    ***
# ===============================================
#   Model Type: dien
#   Model Saved Path: /home/vmagent/app/e2eaiok/result/dien/20221012_232451/3c3c066abc64c20f027199f6cdfe8ab8
#   Sigopt Experiment id is None
#   === Result Metrics ===
#     AUC: 0.8305432393938367
#     training_time: 412.12084555625916
# ===============================================

# %% [markdown]
# ## Inference

# %%
# Inference with Single Node, 64 instances
! cd /home/vmagent/app/e2eaiok/modelzoo/dien; sh infer.sh
