# %% [markdown]
# # DriveThru Suggested Sell Recommender
# DriveThru Suggested Sell Recommender built using Apache MXnet
#
# use pytorch_env

# %%
import os
os.environ['NUMEXPR_MAX_THREADS'] = '88'
os.environ['NUMEXPR_NUM_THREADS'] = '70'
import numexpr as ne

# %% [markdown]
# ## Initialization
# import libraries

# %%
import os
import boto3
import mxnet as mx
import pandas as pd
import numpy as np
import s3fs
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import logging
from datetime import datetime

# %%
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.basicConfig(filename='./drivethru_log',level=logging.DEBUG)

# %% [markdown]
# ## Data Preparation
# Load data from S3 bucket

# %%
bucket = ...
#prefix = '/home/sparkuser/jupyter/Jian/BlueWhale-POC/ScalingNotebook/BurgerKing/data/'
prefix = '/home/sparkuser/jupyter/Jian/BlueWhale-POC/ScalingNotebook/BurgerKing/data_10000/'

model_prefix = ...
batch_size = 1000
num_epoch = 1
num_gpus = range(8)
#context = [mx.gpu(int(i)) for i in num_gpus] if num_gpus else [mx.cpu()]
context=mx.cpu()
model_checkpoint_interval = 5

# %%
'''
# Split and download training data from s3
session = boto3.Session(
    aws_access_key_id=...
    aws_secret_access_key=...
)
s3_client = session.client('s3', verify=False)


df_list = []
keys = []
resp = s3_client.list_objects_v2(Bucket=bucket, Prefix=prefix)
for obj in resp['Contents']:
    keys.append(obj['Key'])
keys_dedup = list(dict.fromkeys(keys))
'''
# Out:
# "\n# Split and download training data from s3\nsession = boto3.Session(\n    aws_access_key_id=...\n    aws_secret_access_key=...\n)\ns3_client = session.client('s3', verify=False)\n\n\ndf_list = []\nkeys = []\nresp = s3_client.list_objects_v2(Bucket=bucket, Prefix=prefix)\nfor obj in resp['Contents']:\n    keys.append(obj['Key'])\nkeys_dedup = list(dict.fromkeys(keys))\n"

# %%
#print(keys_dedup)

# %%
'''
for key in keys_dedup:
    obj = s3_client.get_object(Bucket=bucket, Key=key)
    df = pd.read_json(obj['Body'], orient='columns', lines=True)
    df_list.append(df)

data = pd.concat(df_list)
'''
df_list = []
num_files=10
for num in range(0,7):
    df = pd.read_json(prefix+str(num)+".json", orient='columns', lines=True)
    df_list.append(df)
data = pd.concat(df_list)

# %%
print(data)
# Out:
#                          pluids  timeidx  bkidx  weatheridx  feelsBucket  \
# 0     [506, 471, 209, 221, 147]      100    121          21            8
# 1      [426, 208, 22, 273, 270]       26     69           3           12
# 2     [173, 348, 426, 378, 386]       17     70          30           15
# 3      [109, 71, 130, 501, 381]       40     72          34           11
# 4     [257, 235, 244, 337, 357]      163     48          31            7
# ...                         ...      ...    ...         ...          ...
# 9995   [205, 178, 286, 28, 475]      105    107          30            6
# 9996    [180, 83, 46, 451, 132]      127    101          18           16
# 9997   [504, 204, 109, 87, 217]       47      2           3           17
# 9998     [95, 257, 336, 1, 386]       35      6          33            6
# 9999    [214, 150, 493, 9, 413]      135     78           9            8
#
#       label
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
# ...     ...
# 9995      1
# 9996      1
# 9997      1
# 9998      0
# 9999      1
#
# [70000 rows x 6 columns]

# %%
train, test = train_test_split(data, test_size=0.001, random_state=100)

# %%
n_plus, n_time, n_bkids, n_weather, n_feels = int(train['pluids'].apply(lambda row: max(row)).max()), \
                                              int(train['timeidx'].max()), int(train['bkidx'].max()), \
                                              int(train['weatheridx'].max()), int(train['feelsBucket'].max())

# %%
n_plus, n_time, n_bkids, n_weather, n_feels
# Out:
# (521, 166, 125, 34, 19)

# %% [markdown]
# Load pandas dataframe into mxnet ndarray

# %%
#当数据存储在内存中，由NDArray 或numpy ndarray 支持时，我们可以使用NDArrayIter 读取数据

# 数据迭代器

X_train = mx.io.NDArrayIter(data={'pluids': np.array(train['pluids'].values.tolist(), dtype=int),
                                  'bkidx': train['bkidx'].values,
                                  'timeidx': train['timeidx'].values,
                                  'feels_bucket': train['feelsBucket'].values,
                                  'weatheridx': train['weatheridx'].values}, 
                            label={'output_label': train['label'].values}, 
                            batch_size=batch_size,
                            shuffle=True)

X_eval = mx.io.NDArrayIter(data={'pluids': np.array(test['pluids'].values.tolist(), dtype=int),
                                 'bkidx': test['bkidx'].values,
                                 'timeidx': test['timeidx'].values,
                                 'feels_bucket': test['feelsBucket'].values,
                                 'weatheridx': test['weatheridx'].values}, 
                            label={'output_label': test['label'].values}, 
                            batch_size=batch_size,
                            shuffle=True)

y_true = mx.symbol.Variable('output_label')

# %% [markdown]
# ## Build Model

# %%
# build the neural networks
# nn.Dense(2) -> a dense layer with 2 output units 

from mxnet.gluon import nn, rnn
class SelfAttention(nn.HybridBlock):
    def __init__(self, att_unit, att_hops, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)
        with self.name_scope():
            self.ut_dense = nn.Dense(att_unit, activation='tanh', flatten=False)
            self.et_dense = nn.Dense(att_hops, activation=None, flatten=False)

    def hybrid_forward(self, F, x):
        # x shape: [batch_size, seq_len, embedding_width]
        # ut shape: [batch_size, seq_len, att_unit]
        ut = self.ut_dense(x)
        # et shape: [batch_size, seq_len, att_hops]
        et = self.et_dense(ut)

        # att shape: [batch_size,  att_hops, seq_len]
        att = F.softmax(F.transpose(et, axes=(0, 2, 1)), axis=-1)
        # output shape [batch_size, att_hops, embedding_width]
        output = F.batch_dot(att, x)

        return output, att

# %%
#MXNet提供了Symbol API，一个用于符号编程的接口。所谓符号编程，相比于传统的一步步计算，我们首先会定义一个计算图。
#计算图中包含规定的输入和输出的占位符。然后编译它，并与NDArray绑定起来进行计算。


pluids = mx.symbol.Variable('pluids')
bkidx = mx.symbol.Variable('bkidx')
timeidx = mx.symbol.Variable('timeidx')
feels_bucket = mx.symbol.Variable('feels_bucket')
weatheridx = mx.symbol.Variable('weatheridx')

#Embedding是一种词向量化技术，这种技术可以保持语义（例如相近语义的词的向量距离会较近），
# 将尺寸为(d0,d1...dn)的输入向量进行词向量化技术后转换为尺寸为(d0,d1,...,dn,out_dim)的向量，多出的一维为词向量，
# 即使用一个向量代替原来一个词的位置。
# parameters: 参数input_dim为输入向量的范围，即输入data的范围在[0,input_dim)之间
# 参数output_dim为词向量大小, 可选参数weight，可传入指定的词向量字典; 可选参数name，可传入名称

plu_embed = mx.symbol.Embedding(data=pluids, input_dim=n_plus, output_dim=50, name='plu_embed')
bkidx_embed = mx.symbol.Embedding(data=bkidx, input_dim=n_bkids, output_dim=100, name='bkid_embed')
time_embed = mx.symbol.Embedding(data=timeidx, input_dim=n_time, output_dim=100, name='time_embed')
feels_embed = mx.symbol.Embedding(data=feels_bucket, input_dim=n_feels, output_dim=100, name='feels_embed')
weather_embed = mx.symbol.Embedding(data=weatheridx, input_dim=n_weather, output_dim=100, name='weather_embed')

# %%
#:RNN容器，用于组合多个RNN层
stacked_rnn_cells = mx.rnn.SequentialRNNCell()
# ⻔控循环神经⽹络（gated recurrent neural network）的提出，正是为了更好地捕捉时间序列中时
# 间步距离较⼤的依赖关系。它通过可以学习的⻔来控制信息的流动。其中，⻔控循环单元（gated
# recurrent unit，简称 GRU）是⼀种常⽤的⻔控循环神经⽹络

#build a bi directional RNN with 50 hidden units  

stacked_rnn_cells.add(mx.rnn.BidirectionalCell(mx.rnn.GRUCell(num_hidden=50, prefix="gru_l"),
                                               mx.rnn.GRUCell(num_hidden=50, prefix="gru_r")))

stacked_out, _ = stacked_rnn_cells.unroll(length=5, inputs=plu_embed, merge_outputs=True, layout="NTC")

# %%
attention_out, att = SelfAttention(100, 1).hybrid_forward(mx.sym, stacked_out)
flatten = mx.symbol.flatten(attention_out, "flatten")

# %%
context_features = mx.symbol.broadcast_mul((1 + bkidx_embed + time_embed + weather_embed + feels_embed), 
                                           flatten, name='latent_cross')

# Activation layers apply a non-linear function on the previous layer's output.
ac1 = mx.symbol.Activation(data=context_features, act_type="relu", name="relu1")
dropout1 = mx.symbol.Dropout(data=ac1, p=0.3, name="dropout1")

## The input is fed to a fully connected layer that computes Y=WX+b.
# This is the main computation module in the network.
fc1 = mx.symbol.FullyConnected(data=dropout1, num_hidden=int(n_plus), name='fc1')

# Finally we have a loss layer that compares the network's output with label and generates gradient signals.
rec_model = mx.symbol.SoftmaxOutput(data=fc1, label=y_true, name='output')

# %%
mx.visualization.plot_network(rec_model, save_format="pdf", title="drivethru_rec")

# %%
graph = mx.visualization.plot_network(rec_model, save_format="pdf", title="bi_self_atteion_rec")

# %%
graph.render()
# Out:
# 'bi_self_atteion_rec.gv.pdf'

# %%
mx.visualization.print_summary(rec_model)
# Out:
# ________________________________________________________________________________________________________________________
# Layer (type)                                        Output Shape            Param #     Previous Layer
# ========================================================================================================================
# bkidx(null)                                                                 0
# ________________________________________________________________________________________________________________________
# bkid_embed(Embedding)                                                       12500       bkidx
# ________________________________________________________________________________________________________________________
# _plusscalar0(_plus_scalar)                                                  0           bkid_embed
# ________________________________________________________________________________________________________________________
# time_embed(Embedding)                                                       16600
# ________________________________________________________________________________________________________________________
# _plus30(elemwise_add)                                                       0           _plusscalar0
#                                                                                         time_embed
# ________________________________________________________________________________________________________________________
# weather_embed(Embedding)                                                    3400
# ________________________________________________________________________________________________________________________
# _plus31(elemwise_add)                                                       0           _plus30
#                                                                                         weather_embed
# ________________________________________________________________________________________________________________________
# feels_embed(Embedding)                                                      1900
# ________________________________________________________________________________________________________________________
# _plus32(elemwise_add)                                                       0           _plus31
#                                                                                         feels_embed
# ________________________________________________________________________________________________________________________
# plu_embed(Embedding)                                                        26050
# ________________________________________________________________________________________________________________________
# split0(SliceChannel)                                                        0           plu_embed
# ________________________________________________________________________________________________________________________
# gru_lt0__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_lt0__i2h_slice(SliceChannel)                                            0           gru_lt0__i2h
# ________________________________________________________________________________________________________________________
# gru_lbegin_state_0(_zeros)                                                  0
# ________________________________________________________________________________________________________________________
# gru_lt0__h2h(FullyConnected)                                                150         gru_lbegin_state_0
# ________________________________________________________________________________________________________________________
# gru_lt0__h2h_slice(SliceChannel)                                            0           gru_lt0__h2h
# ________________________________________________________________________________________________________________________
# _plus1(elemwise_add)                                                        0           gru_lt0__i2h_slice
#                                                                                         gru_lt0__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt0__z_act(Activation)                                                  0           _plus1
# ________________________________________________________________________________________________________________________
# _rminusscalar0(_rminus_scalar)                                              0           gru_lt0__z_act
# ________________________________________________________________________________________________________________________
# _plus0(elemwise_add)                                                        0           gru_lt0__i2h_slice
#                                                                                         gru_lt0__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt0__r_act(Activation)                                                  0           _plus0
# ________________________________________________________________________________________________________________________
# _mul0(elemwise_mul)                                                         0           gru_lt0__r_act
#                                                                                         gru_lt0__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus2(elemwise_add)                                                        0           gru_lt0__i2h_slice
#                                                                                         _mul0
# ________________________________________________________________________________________________________________________
# gru_lt0__h_act(Activation)                                                  0           _plus2
# ________________________________________________________________________________________________________________________
# _mul1(elemwise_mul)                                                         0           _rminusscalar0
#                                                                                         gru_lt0__h_act
# ________________________________________________________________________________________________________________________
# _mul2(elemwise_mul)                                                         0           gru_lt0__z_act
#                                                                                         gru_lbegin_state_0
# ________________________________________________________________________________________________________________________
# gru_lt0_out(elemwise_add)                                                   0           _mul1
#                                                                                         _mul2
# ________________________________________________________________________________________________________________________
# expand_dims0(expand_dims)                                                   0           gru_lt0_out
# ________________________________________________________________________________________________________________________
# gru_lt1__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_lt1__i2h_slice(SliceChannel)                                            0           gru_lt1__i2h
# ________________________________________________________________________________________________________________________
# gru_lt1__h2h(FullyConnected)                                                150         gru_lt0_out
# ________________________________________________________________________________________________________________________
# gru_lt1__h2h_slice(SliceChannel)                                            0           gru_lt1__h2h
# ________________________________________________________________________________________________________________________
# _plus4(elemwise_add)                                                        0           gru_lt1__i2h_slice
#                                                                                         gru_lt1__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt1__z_act(Activation)                                                  0           _plus4
# ________________________________________________________________________________________________________________________
# _rminusscalar1(_rminus_scalar)                                              0           gru_lt1__z_act
# ________________________________________________________________________________________________________________________
# _plus3(elemwise_add)                                                        0           gru_lt1__i2h_slice
#                                                                                         gru_lt1__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt1__r_act(Activation)                                                  0           _plus3
# ________________________________________________________________________________________________________________________
# _mul3(elemwise_mul)                                                         0           gru_lt1__r_act
#                                                                                         gru_lt1__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus5(elemwise_add)                                                        0           gru_lt1__i2h_slice
#                                                                                         _mul3
# ________________________________________________________________________________________________________________________
# gru_lt1__h_act(Activation)                                                  0           _plus5
# ________________________________________________________________________________________________________________________
# _mul4(elemwise_mul)                                                         0           _rminusscalar1
#                                                                                         gru_lt1__h_act
# ________________________________________________________________________________________________________________________
# _mul5(elemwise_mul)                                                         0           gru_lt1__z_act
#                                                                                         gru_lt0_out
# ________________________________________________________________________________________________________________________
# gru_lt1_out(elemwise_add)                                                   0           _mul4
#                                                                                         _mul5
# ________________________________________________________________________________________________________________________
# expand_dims1(expand_dims)                                                   0           gru_lt1_out
# ________________________________________________________________________________________________________________________
# gru_lt2__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_lt2__i2h_slice(SliceChannel)                                            0           gru_lt2__i2h
# ________________________________________________________________________________________________________________________
# gru_lt2__h2h(FullyConnected)                                                150         gru_lt1_out
# ________________________________________________________________________________________________________________________
# gru_lt2__h2h_slice(SliceChannel)                                            0           gru_lt2__h2h
# ________________________________________________________________________________________________________________________
# _plus7(elemwise_add)                                                        0           gru_lt2__i2h_slice
#                                                                                         gru_lt2__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt2__z_act(Activation)                                                  0           _plus7
# ________________________________________________________________________________________________________________________
# _rminusscalar2(_rminus_scalar)                                              0           gru_lt2__z_act
# ________________________________________________________________________________________________________________________
# _plus6(elemwise_add)                                                        0           gru_lt2__i2h_slice
#                                                                                         gru_lt2__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt2__r_act(Activation)                                                  0           _plus6
# ________________________________________________________________________________________________________________________
# _mul6(elemwise_mul)                                                         0           gru_lt2__r_act
#                                                                                         gru_lt2__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus8(elemwise_add)                                                        0           gru_lt2__i2h_slice
#                                                                                         _mul6
# ________________________________________________________________________________________________________________________
# gru_lt2__h_act(Activation)                                                  0           _plus8
# ________________________________________________________________________________________________________________________
# _mul7(elemwise_mul)                                                         0           _rminusscalar2
#                                                                                         gru_lt2__h_act
# ________________________________________________________________________________________________________________________
# _mul8(elemwise_mul)                                                         0           gru_lt2__z_act
#                                                                                         gru_lt1_out
# ________________________________________________________________________________________________________________________
# gru_lt2_out(elemwise_add)                                                   0           _mul7
#                                                                                         _mul8
# ________________________________________________________________________________________________________________________
# expand_dims2(expand_dims)                                                   0           gru_lt2_out
# ________________________________________________________________________________________________________________________
# gru_lt3__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_lt3__i2h_slice(SliceChannel)                                            0           gru_lt3__i2h
# ________________________________________________________________________________________________________________________
# gru_lt3__h2h(FullyConnected)                                                150         gru_lt2_out
# ________________________________________________________________________________________________________________________
# gru_lt3__h2h_slice(SliceChannel)                                            0           gru_lt3__h2h
# ________________________________________________________________________________________________________________________
# _plus10(elemwise_add)                                                       0           gru_lt3__i2h_slice
#                                                                                         gru_lt3__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt3__z_act(Activation)                                                  0           _plus10
# ________________________________________________________________________________________________________________________
# _rminusscalar3(_rminus_scalar)                                              0           gru_lt3__z_act
# ________________________________________________________________________________________________________________________
# _plus9(elemwise_add)                                                        0           gru_lt3__i2h_slice
#                                                                                         gru_lt3__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt3__r_act(Activation)                                                  0           _plus9
# ________________________________________________________________________________________________________________________
# _mul9(elemwise_mul)                                                         0           gru_lt3__r_act
#                                                                                         gru_lt3__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus11(elemwise_add)                                                       0           gru_lt3__i2h_slice
#                                                                                         _mul9
# ________________________________________________________________________________________________________________________
# gru_lt3__h_act(Activation)                                                  0           _plus11
# ________________________________________________________________________________________________________________________
# _mul10(elemwise_mul)                                                        0           _rminusscalar3
#                                                                                         gru_lt3__h_act
# ________________________________________________________________________________________________________________________
# _mul11(elemwise_mul)                                                        0           gru_lt3__z_act
#                                                                                         gru_lt2_out
# ________________________________________________________________________________________________________________________
# gru_lt3_out(elemwise_add)                                                   0           _mul10
#                                                                                         _mul11
# ________________________________________________________________________________________________________________________
# expand_dims3(expand_dims)                                                   0           gru_lt3_out
# ________________________________________________________________________________________________________________________
# gru_lt4__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_lt4__i2h_slice(SliceChannel)                                            0           gru_lt4__i2h
# ________________________________________________________________________________________________________________________
# gru_lt4__h2h(FullyConnected)                                                150         gru_lt3_out
# ________________________________________________________________________________________________________________________
# gru_lt4__h2h_slice(SliceChannel)                                            0           gru_lt4__h2h
# ________________________________________________________________________________________________________________________
# _plus13(elemwise_add)                                                       0           gru_lt4__i2h_slice
#                                                                                         gru_lt4__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt4__z_act(Activation)                                                  0           _plus13
# ________________________________________________________________________________________________________________________
# _rminusscalar4(_rminus_scalar)                                              0           gru_lt4__z_act
# ________________________________________________________________________________________________________________________
# _plus12(elemwise_add)                                                       0           gru_lt4__i2h_slice
#                                                                                         gru_lt4__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_lt4__r_act(Activation)                                                  0           _plus12
# ________________________________________________________________________________________________________________________
# _mul12(elemwise_mul)                                                        0           gru_lt4__r_act
#                                                                                         gru_lt4__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus14(elemwise_add)                                                       0           gru_lt4__i2h_slice
#                                                                                         _mul12
# ________________________________________________________________________________________________________________________
# gru_lt4__h_act(Activation)                                                  0           _plus14
# ________________________________________________________________________________________________________________________
# _mul13(elemwise_mul)                                                        0           _rminusscalar4
#                                                                                         gru_lt4__h_act
# ________________________________________________________________________________________________________________________
# _mul14(elemwise_mul)                                                        0           gru_lt4__z_act
#                                                                                         gru_lt3_out
# ________________________________________________________________________________________________________________________
# gru_lt4_out(elemwise_add)                                                   0           _mul13
#                                                                                         _mul14
# ________________________________________________________________________________________________________________________
# expand_dims4(expand_dims)                                                   0           gru_lt4_out
# ________________________________________________________________________________________________________________________
# concat0(Concat)                                                             0           expand_dims0
#                                                                                         expand_dims1
#                                                                                         expand_dims2
#                                                                                         expand_dims3
#                                                                                         expand_dims4
# ________________________________________________________________________________________________________________________
# gru_rt0__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_rt0__i2h_slice(SliceChannel)                                            0           gru_rt0__i2h
# ________________________________________________________________________________________________________________________
# gru_rbegin_state_0(_zeros)                                                  0
# ________________________________________________________________________________________________________________________
# gru_rt0__h2h(FullyConnected)                                                150         gru_rbegin_state_0
# ________________________________________________________________________________________________________________________
# gru_rt0__h2h_slice(SliceChannel)                                            0           gru_rt0__h2h
# ________________________________________________________________________________________________________________________
# _plus16(elemwise_add)                                                       0           gru_rt0__i2h_slice
#                                                                                         gru_rt0__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt0__z_act(Activation)                                                  0           _plus16
# ________________________________________________________________________________________________________________________
# _rminusscalar5(_rminus_scalar)                                              0           gru_rt0__z_act
# ________________________________________________________________________________________________________________________
# _plus15(elemwise_add)                                                       0           gru_rt0__i2h_slice
#                                                                                         gru_rt0__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt0__r_act(Activation)                                                  0           _plus15
# ________________________________________________________________________________________________________________________
# _mul15(elemwise_mul)                                                        0           gru_rt0__r_act
#                                                                                         gru_rt0__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus17(elemwise_add)                                                       0           gru_rt0__i2h_slice
#                                                                                         _mul15
# ________________________________________________________________________________________________________________________
# gru_rt0__h_act(Activation)                                                  0           _plus17
# ________________________________________________________________________________________________________________________
# _mul16(elemwise_mul)                                                        0           _rminusscalar5
#                                                                                         gru_rt0__h_act
# ________________________________________________________________________________________________________________________
# _mul17(elemwise_mul)                                                        0           gru_rt0__z_act
#                                                                                         gru_rbegin_state_0
# ________________________________________________________________________________________________________________________
# gru_rt0_out(elemwise_add)                                                   0           _mul16
#                                                                                         _mul17
# ________________________________________________________________________________________________________________________
# expand_dims5(expand_dims)                                                   0           gru_rt0_out
# ________________________________________________________________________________________________________________________
# gru_rt1__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_rt1__i2h_slice(SliceChannel)                                            0           gru_rt1__i2h
# ________________________________________________________________________________________________________________________
# gru_rt1__h2h(FullyConnected)                                                150         gru_rt0_out
# ________________________________________________________________________________________________________________________
# gru_rt1__h2h_slice(SliceChannel)                                            0           gru_rt1__h2h
# ________________________________________________________________________________________________________________________
# _plus19(elemwise_add)                                                       0           gru_rt1__i2h_slice
#                                                                                         gru_rt1__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt1__z_act(Activation)                                                  0           _plus19
# ________________________________________________________________________________________________________________________
# _rminusscalar6(_rminus_scalar)                                              0           gru_rt1__z_act
# ________________________________________________________________________________________________________________________
# _plus18(elemwise_add)                                                       0           gru_rt1__i2h_slice
#                                                                                         gru_rt1__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt1__r_act(Activation)                                                  0           _plus18
# ________________________________________________________________________________________________________________________
# _mul18(elemwise_mul)                                                        0           gru_rt1__r_act
#                                                                                         gru_rt1__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus20(elemwise_add)                                                       0           gru_rt1__i2h_slice
#                                                                                         _mul18
# ________________________________________________________________________________________________________________________
# gru_rt1__h_act(Activation)                                                  0           _plus20
# ________________________________________________________________________________________________________________________
# _mul19(elemwise_mul)                                                        0           _rminusscalar6
#                                                                                         gru_rt1__h_act
# ________________________________________________________________________________________________________________________
# _mul20(elemwise_mul)                                                        0           gru_rt1__z_act
#                                                                                         gru_rt0_out
# ________________________________________________________________________________________________________________________
# gru_rt1_out(elemwise_add)                                                   0           _mul19
#                                                                                         _mul20
# ________________________________________________________________________________________________________________________
# expand_dims6(expand_dims)                                                   0           gru_rt1_out
# ________________________________________________________________________________________________________________________
# gru_rt2__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_rt2__i2h_slice(SliceChannel)                                            0           gru_rt2__i2h
# ________________________________________________________________________________________________________________________
# gru_rt2__h2h(FullyConnected)                                                150         gru_rt1_out
# ________________________________________________________________________________________________________________________
# gru_rt2__h2h_slice(SliceChannel)                                            0           gru_rt2__h2h
# ________________________________________________________________________________________________________________________
# _plus22(elemwise_add)                                                       0           gru_rt2__i2h_slice
#                                                                                         gru_rt2__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt2__z_act(Activation)                                                  0           _plus22
# ________________________________________________________________________________________________________________________
# _rminusscalar7(_rminus_scalar)                                              0           gru_rt2__z_act
# ________________________________________________________________________________________________________________________
# _plus21(elemwise_add)                                                       0           gru_rt2__i2h_slice
#                                                                                         gru_rt2__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt2__r_act(Activation)                                                  0           _plus21
# ________________________________________________________________________________________________________________________
# _mul21(elemwise_mul)                                                        0           gru_rt2__r_act
#                                                                                         gru_rt2__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus23(elemwise_add)                                                       0           gru_rt2__i2h_slice
#                                                                                         _mul21
# ________________________________________________________________________________________________________________________
# gru_rt2__h_act(Activation)                                                  0           _plus23
# ________________________________________________________________________________________________________________________
# _mul22(elemwise_mul)                                                        0           _rminusscalar7
#                                                                                         gru_rt2__h_act
# ________________________________________________________________________________________________________________________
# _mul23(elemwise_mul)                                                        0           gru_rt2__z_act
#                                                                                         gru_rt1_out
# ________________________________________________________________________________________________________________________
# gru_rt2_out(elemwise_add)                                                   0           _mul22
#                                                                                         _mul23
# ________________________________________________________________________________________________________________________
# expand_dims7(expand_dims)                                                   0           gru_rt2_out
# ________________________________________________________________________________________________________________________
# gru_rt3__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_rt3__i2h_slice(SliceChannel)                                            0           gru_rt3__i2h
# ________________________________________________________________________________________________________________________
# gru_rt3__h2h(FullyConnected)                                                150         gru_rt2_out
# ________________________________________________________________________________________________________________________
# gru_rt3__h2h_slice(SliceChannel)                                            0           gru_rt3__h2h
# ________________________________________________________________________________________________________________________
# _plus25(elemwise_add)                                                       0           gru_rt3__i2h_slice
#                                                                                         gru_rt3__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt3__z_act(Activation)                                                  0           _plus25
# ________________________________________________________________________________________________________________________
# _rminusscalar8(_rminus_scalar)                                              0           gru_rt3__z_act
# ________________________________________________________________________________________________________________________
# _plus24(elemwise_add)                                                       0           gru_rt3__i2h_slice
#                                                                                         gru_rt3__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt3__r_act(Activation)                                                  0           _plus24
# ________________________________________________________________________________________________________________________
# _mul24(elemwise_mul)                                                        0           gru_rt3__r_act
#                                                                                         gru_rt3__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus26(elemwise_add)                                                       0           gru_rt3__i2h_slice
#                                                                                         _mul24
# ________________________________________________________________________________________________________________________
# gru_rt3__h_act(Activation)                                                  0           _plus26
# ________________________________________________________________________________________________________________________
# _mul25(elemwise_mul)                                                        0           _rminusscalar8
#                                                                                         gru_rt3__h_act
# ________________________________________________________________________________________________________________________
# _mul26(elemwise_mul)                                                        0           gru_rt3__z_act
#                                                                                         gru_rt2_out
# ________________________________________________________________________________________________________________________
# gru_rt3_out(elemwise_add)                                                   0           _mul25
#                                                                                         _mul26
# ________________________________________________________________________________________________________________________
# expand_dims8(expand_dims)                                                   0           gru_rt3_out
# ________________________________________________________________________________________________________________________
# gru_rt4__i2h(FullyConnected)                                                150         split0
# ________________________________________________________________________________________________________________________
# gru_rt4__i2h_slice(SliceChannel)                                            0           gru_rt4__i2h
# ________________________________________________________________________________________________________________________
# gru_rt4__h2h(FullyConnected)                                                150         gru_rt3_out
# ________________________________________________________________________________________________________________________
# gru_rt4__h2h_slice(SliceChannel)                                            0           gru_rt4__h2h
# ________________________________________________________________________________________________________________________
# _plus28(elemwise_add)                                                       0           gru_rt4__i2h_slice
#                                                                                         gru_rt4__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt4__z_act(Activation)                                                  0           _plus28
# ________________________________________________________________________________________________________________________
# _rminusscalar9(_rminus_scalar)                                              0           gru_rt4__z_act
# ________________________________________________________________________________________________________________________
# _plus27(elemwise_add)                                                       0           gru_rt4__i2h_slice
#                                                                                         gru_rt4__h2h_slice
# ________________________________________________________________________________________________________________________
# gru_rt4__r_act(Activation)                                                  0           _plus27
# ________________________________________________________________________________________________________________________
# _mul27(elemwise_mul)                                                        0           gru_rt4__r_act
#                                                                                         gru_rt4__h2h_slice
# ________________________________________________________________________________________________________________________
# _plus29(elemwise_add)                                                       0           gru_rt4__i2h_slice
#                                                                                         _mul27
# ________________________________________________________________________________________________________________________
# gru_rt4__h_act(Activation)                                                  0           _plus29
# ________________________________________________________________________________________________________________________
# _mul28(elemwise_mul)                                                        0           _rminusscalar9
#                                                                                         gru_rt4__h_act
# ________________________________________________________________________________________________________________________
# _mul29(elemwise_mul)                                                        0           gru_rt4__z_act
#                                                                                         gru_rt3_out
# ________________________________________________________________________________________________________________________
# gru_rt4_out(elemwise_add)                                                   0           _mul28
#                                                                                         _mul29
# ________________________________________________________________________________________________________________________
# expand_dims9(expand_dims)                                                   0           gru_rt4_out
# ________________________________________________________________________________________________________________________
# concat1(Concat)                                                             0           expand_dims5
#                                                                                         expand_dims6
#                                                                                         expand_dims7
#                                                                                         expand_dims8
#                                                                                         expand_dims9
# ________________________________________________________________________________________________________________________
# reverse0(reverse)                                                           0           concat1
# ________________________________________________________________________________________________________________________
# bi_out(Concat)                                                              0           concat0
#                                                                                         reverse0
# ________________________________________________________________________________________________________________________
# selfattention0_dense0_fwd(FullyConnected)                                   100         bi_out
# ________________________________________________________________________________________________________________________
# selfattention0_dense0_tanh_fwd(Activation)                                  0           selfattention0_dense0_fwd
# ________________________________________________________________________________________________________________________
# selfattention0_dense1_fwd(FullyConnected)                                   1           selfattention0_dense0_tanh_fwd
# ________________________________________________________________________________________________________________________
# transpose0(transpose)                                                       0           selfattention0_dense1_fwd
# ________________________________________________________________________________________________________________________
# softmax0(softmax)                                                           0           transpose0
# ________________________________________________________________________________________________________________________
# batch_dot0(batch_dot)                                                       0           softmax0
#                                                                                         bi_out
# ________________________________________________________________________________________________________________________
# flatten(Flatten)                                                            0           batch_dot0
# ________________________________________________________________________________________________________________________
# latent_cross(broadcast_mul)                                                 0           _plus32
#                                                                                         flatten
# ________________________________________________________________________________________________________________________
# relu1(Activation)                                                           0           latent_cross
# ________________________________________________________________________________________________________________________
# dropout1(Dropout)                                                           0           relu1
# ________________________________________________________________________________________________________________________
# fc1(FullyConnected)                                                         521         dropout1
# ________________________________________________________________________________________________________________________
# output(SoftmaxOutput)                                                       0           fc1
# ========================================================================================================================
# Total params: 64072
# ________________________________________________________________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
mod = mx.mod.Module(symbol=rec_model, 
                    data_names=['pluids', 'bkidx', 'timeidx', 'feels_bucket', 'weatheridx'], 
                    label_names=['output_label'],
                    context=context
                   )

# %%
time3=datetime.now()
# 
mod.fit(train_data=X_train, 
        num_epoch=num_epoch, 
        initializer=mx.init.Xavier(rnd_type="gaussian"),
        optimizer='adagrad',
        eval_metric=['accuracy'],
        validation_metric=['accuracy', mx.metric.TopKAccuracy(3)],
        eval_data=X_eval, 
        batch_end_callback=mx.callback.Speedometer(batch_size, 500),
        epoch_end_callback = None if model_prefix==None else mx.callback.do_checkpoint(model_prefix, 
                                                                                       model_checkpoint_interval))
time4=datetime.now()
model_train_time=time4-time3
print("model train time:")
print(model_train_time)
# Out:
# /home/sparkuser/anaconda3/lib/python3.7/site-packages/dask/dataframe/utils.py:14: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-65d82ccc6bf7> in <module>
#       9         batch_end_callback=mx.callback.Speedometer(batch_size, 500),
#      10         epoch_end_callback = None if model_prefix==None else mx.callback.do_checkpoint(model_prefix,
# ---> 11                                                                                        model_checkpoint_interval))
#      12 time4=datetime.now()
#      13 model_train_time=time4-time3
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/module/base_module.py in fit(self, train_data, eval_data, eval_metric, epoch_end_callback, batch_end_callback, kvstore, optimizer, optimizer_params, eval_end_callback, eval_batch_end_callback, initializer, arg_params, aux_params, allow_missing, force_rebind, force_init, begin_epoch, num_epoch, validation_metric, monitor, sparse_row_id_fn)
#     573                 res = self.score(eval_data, validation_metric,
#     574                                  score_end_callback=eval_end_callback,
# --> 575                                  batch_end_callback=eval_batch_end_callback, epoch=epoch)
#     576                 #TODO: pull this into default
#     577                 for name, val in res:
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/module/base_module.py in score(self, eval_data, eval_metric, num_batch, batch_end_callback, score_end_callback, reset, epoch, sparse_row_id_fn)
#     247         actual_num_batch = 0
#     248
# --> 249         for nbatch, eval_batch in enumerate(eval_data):
#     250             if num_batch is not None and nbatch == num_batch:
#     251                 break
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/io/io.py in __next__(self)
#     228
#     229     def __next__(self):
# --> 230         return self.next()
#     231
#     232     def iter_next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/io/io.py in next(self)
#     680         if not self.iter_next():
#     681             raise StopIteration
# --> 682         data = self.getdata()
#     683         label = self.getlabel()
#     684         # iter should stop when last batch is not complete
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/io/io.py in getdata(self)
#     762     def getdata(self):
#     763         """Get data."""
# --> 764         return self._batchify(self.data)
#     765
#     766     def getlabel(self):
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/io/io.py in _batchify(self, data_source)
#     749             pad = self.batch_size - self.num_data + self.cursor
#     750             first_data = self._getdata(data_source, start=self.cursor)
# --> 751             second_data = self._getdata(data_source, end=pad)
#     752             return self._concat(first_data, second_data)
#     753         # normal case
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/io/io.py in _getdata(self, data_source, start, end)
#     705                 list(self.idx[s]).index(i)
#     706                 for i in sorted(self.idx[s])
# --> 707             ]]) for x in data_source
#     708         ]
#     709
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/io/io.py in <listcomp>(.0)
#     705                 list(self.idx[s]).index(i)
#     706                 for i in sorted(self.idx[s])
# --> 707             ]]) for x in data_source
#     708         ]
#     709
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/ndarray/ndarray.py in __getitem__(self, key)
#     703             if (key.step is None or key.step == 1):
#     704                 if  key.start is not None or key.stop is not None:
# --> 705                     return self._slice(key.start, key.stop)
#     706                 else:
#     707                     return self
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/ndarray/ndarray.py in _slice(self, start, stop)
#    1339         """
#    1340         handle = NDArrayHandle()
# -> 1341         start, stop, _ = _get_index_range(start, stop, self.shape[0])
#    1342
#    1343         check_call(_LIB.MXNDArraySlice(
#
# ~/anaconda3/lib/python3.7/site-packages/mxnet/ndarray/ndarray.py in _get_index_range(start, stop, length, step)
#    3081             raise IndexError('Slicing stop %d exceeds limit of %d' % (stop-length, length))
#    3082     elif stop > length:
# -> 3083         raise IndexError('Slicing stop %d exceeds limit of %d' % (stop, length))
#    3084
#    3085     return start, stop, step
#
# IndexError: Slicing stop 930 exceeds limit of 70

# %%
''''
loaded = mx.mod.Module.load(prefix=model_prefix,
                            epoch=25,
#                             load_optimizer_states=True,
                            data_names=['pluids', 'bkidx', 'timeidx', 'feels_bucket', 'weatheridx'], 
                            label_names=['output_label'],
                            context=context
                            )
'''

# %%
'''
loaded.fit(train_data=X_train, 
           begin_epoch=25,
            num_epoch=200, 
#             initializer=mx.init.Normal(),
            optimizer='adagrad',
            eval_metric='accuracy',
            validation_metric=['accuracy', mx.metric.TopKAccuracy(3)],
            eval_data=X_eval, 
            batch_end_callback=mx.callback.Speedometer(batch_size, 500),
            epoch_end_callback = None if model_prefix==None else mx.callback.do_checkpoint(model_prefix, 5))
'''

# %% [markdown]
# ## Evaluation Result

# %%
test_list = []

for num in range(7,10):
    test = pd.read_json(prefix+str(num)+".json", orient='columns', lines=True)
    test_list.append(test)
test_data = pd.concat(test_list)

# %%
X_evaluation=mx.io.NDArrayIter(data={'pluids': np.array(test_data['pluids'].values.tolist(), dtype=int),
                                  'bkidx': test_data['bkidx'].values,
                                  'timeidx': test_data['timeidx'].values,
                                  'feels_bucket': test_data['feelsBucket'].values,
                                  'weatheridx': test_data['weatheridx'].values},
                              label={'output_label': train['label'].values}, 
                            batch_size=600,
                            shuffle=True)

predictions = mod.predict(X_evaluation)
# we can also use RMSE,MSE as the metric
score = mod.score(X_evaluation, ['acc'])
print("Accuracy score is %f" % (score[0][1]))

# %% [markdown]
# ## Model save and load

# %%
#mod.save_checkpoint(prefix, 9, save_optimizer_states=True)

# %%
#load = mx.model.FeedForward.load(prefix=prefix, epoch=9, ctx=mx.gpu())
