# %%
import os, time
start = time.time()
very_start = time.time()

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
import dask
from dask.distributed import Client, wait, LocalCluster
import dask.dataframe as dd

# %%
client = Client(n_workers=1, 
                       threads_per_worker=96,
                       memory_limit='480GB',ip='10.1.0.xxx')
dask.config.set(shuffle='disk')
dask.config.set({'temporary_directory': '/path/to/dask_tmp'})

# %% [markdown]
# # Load Train

# %%
# %%time
path = '/path/to/bin/tmp/'
train = dd.read_parquet(f'/path/to/dask_tmp/train_10_raw/*.parquet')#,dtypes=dtypes)
valid = dd.read_parquet(f'/path/to/dask_tmp/valid_10_raw/*.parquet')#,dtypes=dtypes)
# Out:
# CPU times: user 106 ms, sys: 14.5 ms, total: 121 ms
# Wall time: 112 ms

# %%
cols_drop = ['tweet','tweet_nortsign']
train = train.drop(cols_drop,axis=1)
valid = valid.drop(cols_drop,axis=1)

# %%
dtype_names = ['count_words', 'count_char', 'count_ats']
for col in dtype_names:
    train[col] = train[col].astype('int32')
    valid[col] = valid[col].astype('int32')

# %%
label_names = ['reply_timestamp', 'retweet_timestamp', 'retweet_with_comment_timestamp', 'like_timestamp']
DONT_USE = ['tweet_id','tweet_timestamp','engaged_with_user_account_creation','enaging_user_account_creation','engage_time',
            'fold','enaging_user_id','engaged_with_user_id', 'dt_dow',
            'engaged_with_user_account_creation', 'enaging_user_account_creation', 'elapsed_time',
             'present_links','present_domains']
DONT_USE += label_names
features = [c for c in train.columns if c not in DONT_USE]

# %% [markdown]
# # Train Model Validate
# We will train on random 10% of first 5 days and validation on last 2 days

# %%
# %%time

SAMPLE_RATIO = 0.5
SEED = 1

if SAMPLE_RATIO < 1.0:
    print(len(train))
    train = train.sample(frac=SAMPLE_RATIO,random_state=42)
    train, = dask.persist(train)
    train.head()
    print(len(train))

train = train.compute()
# train = train.compute()
Y_train = train[label_names]
train = train.drop(label_names,axis=1)

features = [c for c in train.columns if c not in DONT_USE]
print('Using %i features:'%(len(features)),train.shape[1])
np.asarray(features)
# Out:
# 21749425
# 10874713
# Using 121 features: 121
# CPU times: user 11.2 s, sys: 12.6 s, total: 23.8 s
# Wall time: 2min 41s
# array(['hashtags', 'present_media', 'tweet_type', 'language',
#        'engaged_with_user_follower_count',
#        'engaged_with_user_following_count',
#        'engaged_with_user_is_verified', 'enaging_user_follower_count',
#        'enaging_user_following_count', 'enaging_user_is_verified',
#        'engagee_follows_engager', 'len_hashtags', 'len_domains',
#        'len_links', 'dt_hour', 'dt_minute', 'dt_second', 'count_words',
#        'count_char', 'tw_uhash', 'tw_hash', 'count_ats', 'hash0', 'hash1',
#        'tw_freq_hash', 'tw_first_word', 'tw_second_word', 'tw_last_word',
#        'tw_llast_word', 'tw_len', 'TE_present_media_reply_timestamp',
#        'TE_tweet_type_reply_timestamp', 'TE_language_reply_timestamp',
#        'TE_engaged_with_user_id_reply_timestamp',
#        'TE_enaging_user_id_reply_timestamp',
#        'TE_present_media_retweet_timestamp',
#        'TE_tweet_type_retweet_timestamp', 'TE_language_retweet_timestamp',
#        'TE_engaged_with_user_id_retweet_timestamp',
#        'TE_enaging_user_id_retweet_timestamp',
#        'TE_present_media_retweet_with_comment_timestamp',
#        'TE_tweet_type_retweet_with_comment_timestamp',
#        'TE_language_retweet_with_comment_timestamp',
#        'TE_engaged_with_user_id_retweet_with_comment_timestamp',
#        'TE_enaging_user_id_retweet_with_comment_timestamp',
#        'TE_present_media_like_timestamp', 'TE_tweet_type_like_timestamp',
#        'TE_language_like_timestamp',
#        'TE_engaged_with_user_id_like_timestamp',
#        'TE_enaging_user_id_like_timestamp',
#        'TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_reply_timestamp',
#        'TE_engaged_with_user_id_tweet_type_language_reply_timestamp',
#        'TE_tw_first_word_tweet_type_language_reply_timestamp',
#        'TE_tw_last_word_tweet_type_language_reply_timestamp',
#        'TE_hash0_tweet_type_language_reply_timestamp',
#        'TE_hash1_tweet_type_language_reply_timestamp',
#        'TE_tw_uhash_tweet_type_language_reply_timestamp',
#        'TE_tw_hash_reply_timestamp', 'TE_tw_freq_hash_reply_timestamp',
#        'TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_reply_timestamp',
#        'TE_present_domains_present_media_tweet_type_language_reply_timestamp',
#        'TE_present_links_present_media_tweet_type_language_reply_timestamp',
#        'TE_hashtags_present_media_tweet_type_language_reply_timestamp',
#        'TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_retweet_timestamp',
#        'TE_engaged_with_user_id_tweet_type_language_retweet_timestamp',
#        'TE_tw_first_word_tweet_type_language_retweet_timestamp',
#        'TE_tw_last_word_tweet_type_language_retweet_timestamp',
#        'TE_hash0_tweet_type_language_retweet_timestamp',
#        'TE_hash1_tweet_type_language_retweet_timestamp',
#        'TE_tw_uhash_tweet_type_language_retweet_timestamp',
#        'TE_tw_hash_retweet_timestamp',
#        'TE_tw_freq_hash_retweet_timestamp',
#        'TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_retweet_timestamp',
#        'TE_present_domains_present_media_tweet_type_language_retweet_timestamp',
#        'TE_present_links_present_media_tweet_type_language_retweet_timestamp',
#        'TE_hashtags_present_media_tweet_type_language_retweet_timestamp',
#        'TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_retweet_with_comment_timestamp',
#        'TE_engaged_with_user_id_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_tw_first_word_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_tw_last_word_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_hash0_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_hash1_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_tw_uhash_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_tw_hash_retweet_with_comment_timestamp',
#        'TE_tw_freq_hash_retweet_with_comment_timestamp',
#        'TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_retweet_with_comment_timestamp',
#        'TE_present_domains_present_media_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_present_links_present_media_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_hashtags_present_media_tweet_type_language_retweet_with_comment_timestamp',
#        'TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_like_timestamp',
#        'TE_engaged_with_user_id_tweet_type_language_like_timestamp',
#        'TE_tw_first_word_tweet_type_language_like_timestamp',
#        'TE_tw_last_word_tweet_type_language_like_timestamp',
#        'TE_hash0_tweet_type_language_like_timestamp',
#        'TE_hash1_tweet_type_language_like_timestamp',
#        'TE_tw_uhash_tweet_type_language_like_timestamp',
#        'TE_tw_hash_like_timestamp', 'TE_tw_freq_hash_like_timestamp',
#        'TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_like_timestamp',
#        'TE_present_domains_present_media_tweet_type_language_like_timestamp',
#        'TE_present_links_present_media_tweet_type_language_like_timestamp',
#        'TE_hashtags_present_media_tweet_type_language_like_timestamp',
#        'TE_present_media_elapsed_time', 'TE_tweet_type_elapsed_time',
#        'TE_language_elapsed_time', 'CE_present_media', 'CE_tweet_type',
#        'CE_language', 'CE_engaged_with_user_id', 'CE_enaging_user_id',
#        'CE_present_media_norm', 'CE_tweet_type_norm', 'CE_language_norm',
#        'CE_engaged_with_user_id_norm', 'CE_enaging_user_id_norm',
#        'DE_enaging_user_id_enaging_user_following_count_1',
#        'DE_enaging_user_id_enaging_user_following_count_-1',
#        'DE_enaging_user_id_language_1', 'DE_enaging_user_id_language_-1',
#        'a_ff_rate', 'b_ff_rate'], dtype='<U146')

# %%
SAMPLE_RATIO = 0.052 # VAL SET NOW SIZE OF TEST SET
SEED = 1
if SAMPLE_RATIO < 1.0:
    print(len(valid))
    valid = valid.sample(frac=SAMPLE_RATIO,random_state=42)
    valid, = dask.persist(valid)
    valid.head()
    print(len(valid))
    
valid = valid.compute()
Y_valid = valid[label_names]
valid = valid.drop(label_names,axis=1)
# Out:
# 8585006
# 446420

# %%
import sys
sys.path.append("..")
from Models.GBM.LightGBM import LightGBM
params = {
    'num_leaves': 61.35765882069168,
    'learning_rate': 0.07266779287696,
    'max_depth': 28,
    'lambda_l1': 50.0,
    'lambda_l2': 50.0,
    'colsample_bynode': 0.8,
    'colsample_bytree': 0.4,
    'bagging_fraction': 0.8,
    'bagging_freq': 7,
    'max_bin': 163.51837199855655,
    'min_data_in_leaf': 1282.3912530172006
}

LGBM0 = LightGBM(
    objective='binary',
    num_threads=94,
    num_iterations=1500,
    early_stopping_rounds=20,
    **params,
)
LGBM1 = LightGBM(
    objective='binary',
    num_threads=94,
    num_iterations=1500,
    early_stopping_rounds=20,
    **params,
)
LGBM2 = LightGBM(
    objective='binary',
    num_threads=94,
    num_iterations=1500,
    early_stopping_rounds=20,
    **params,
)
LGBM3 = LightGBM(
    objective='binary',
    num_threads=94,
    num_iterations=1500,
    early_stopping_rounds=20,
    **params,
)
model2 = [LGBM0,LGBM1,LGBM2,LGBM3]

# %%
if train.columns.duplicated().sum()>0:
    raise Exception(f'duplicated!: { train.columns[train.columns.duplicated()] }')
print('no dup :) ')
print(f'X_train.shape {train.shape}')
print(f'X_valid.shape {valid.shape}')
# Out:
# no dup :)
# X_train.shape (10874713, 121)
# X_valid.shape (446420, 121)

# %%
# %%time

for col in train.columns:
    if train[col].dtype=='bool':
        train[col] = train[col].astype('int8')
        valid[col] = valid[col].astype('int8')
# Out:
# CPU times: user 1.25 ms, sys: 2 µs, total: 1.25 ms
# Wall time: 1.27 ms

# %%
train.head()
# Out:
#          hashtags  present_media  tweet_type  language  \
# 1971849         0            0.0           1         0
# 1571286         0            5.0           1         4
# 2062484         0            7.0           2         4
# 1419726         0            0.0           1         0
# 1416932         0            5.0           1         1
#
#          engaged_with_user_follower_count  engaged_with_user_following_count  \
# 1971849                            334126                              18414
# 1571286                               490                                529
# 2062484                               243                                253
# 1419726                              2207                                572
# 1416932                               201                                392
#
#          engaged_with_user_is_verified  enaging_user_follower_count  \
# 1971849                              0                           33
# 1571286                              0                           75
# 2062484                              0                          794
# 1419726                              0                         2171
# 1416932                              0                           14
#
#          enaging_user_following_count  enaging_user_is_verified  \
# 1971849                            39                         0
# 1571286                           378                         0
# 2062484                          1002                         0
# 1419726                          1363                         0
# 1416932                            33                         0
#
#          engagee_follows_engager  len_hashtags  len_domains  len_links  \
# 1971849                        0             0            0          0
# 1571286                        1             0            0          0
# 2062484                        1             0            0          0
# 1419726                        1             0            0          0
# 1416932                        1             0            0          0
#
#          dt_hour  dt_minute  dt_second  count_words  count_char  tw_uhash  \
# 1971849       16         31         11           33         170      1799
# 1571286        8         51         18            7          56      6791
# 2062484       18          8         50            2          35         0
# 1419726        6         19          5           17         107      2507
# 1416932        6         16         27           13          75     51238
#
#            tw_hash  count_ats  hash0  hash1  tw_freq_hash  tw_first_word  \
# 1971849  569692180          1   1799      0     569692180         924731
# 1571286 -279645608          1   6791      0    -279645608        1007816
# 2062484 -506757606          0      0      0    -506757606             -1
# 1419726 -214581439          1   2507      0    -214581439         796311
# 1416932  448048590          1  51238      0     448048590         640219
#
#          tw_second_word  tw_last_word  tw_llast_word  tw_len  \
# 1971849          791917          1090           1090      14
# 1571286          155146         94416          94416       3
# 2062484              -1            -1             -1       0
# 1419726          543910         93917          93917       5
# 1416932          633158          1080           1080       7
#
#          TE_present_media_reply_timestamp  TE_tweet_type_reply_timestamp  \
# 1971849                          0.032645                       0.005752
# 1571286                          0.028661                       0.005752
# 2062484                          0.020536                       0.042330
# 1419726                          0.032645                       0.005752
# 1416932                          0.028661                       0.005752
#
#          TE_language_reply_timestamp  TE_engaged_with_user_id_reply_timestamp  \
# 1971849                     0.028732                                 0.027621
# 1571286                     0.019377                                 0.026819
# 2062484                     0.019377                                 0.029500
# 1419726                     0.028732                                 0.019033
# 1416932                     0.026728                                 0.026819
#
#          TE_enaging_user_id_reply_timestamp  \
# 1971849                            0.029500
# 1571286                            0.028096
# 2062484                            0.028096
# 1419726                            0.026819
# 1416932                            0.028096
#
#          TE_present_media_retweet_timestamp  TE_tweet_type_retweet_timestamp  \
# 1971849                            0.079280                         0.112284
# 1571286                            0.087643                         0.112284
# 2062484                            0.115903                         0.077514
# 1419726                            0.079280                         0.112284
# 1416932                            0.087643                         0.112284
#
#          TE_language_retweet_timestamp  \
# 1971849                       0.079864
# 1571286                       0.082539
# 2062484                       0.082539
# 1419726                       0.079864
# 1416932                       0.055023
#
#          TE_engaged_with_user_id_retweet_timestamp  \
# 1971849                                   0.108480
# 1571286                                   0.078970
# 2062484                                   0.086867
# 1419726                                   0.185076
# 1416932                                   0.078970
#
#          TE_enaging_user_id_retweet_timestamp  \
# 1971849                              0.086867
# 1571286                              0.082731
# 2062484                              0.082731
# 1419726                              0.124425
# 1416932                              0.082731
#
#          TE_present_media_retweet_with_comment_timestamp  \
# 1971849                                         0.006447
# 1571286                                         0.007457
# 2062484                                         0.008462
# 1419726                                         0.006447
# 1416932                                         0.007457
#
#          TE_tweet_type_retweet_with_comment_timestamp  \
# 1971849                                      0.006206
# 1571286                                      0.006206
# 2062484                                      0.007917
# 1419726                                      0.006206
# 1416932                                      0.006206
#
#          TE_language_retweet_with_comment_timestamp  \
# 1971849                                    0.007803
# 1571286                                    0.006672
# 2062484                                    0.006672
# 1419726                                    0.007803
# 1416932                                    0.003553
#
#          TE_engaged_with_user_id_retweet_with_comment_timestamp  \
# 1971849                                           0.000457
# 1571286                                           0.006464
# 2062484                                           0.007110
# 1419726                                           0.004587
# 1416932                                           0.006464
#
#          TE_enaging_user_id_retweet_with_comment_timestamp  \
# 1971849                                           0.007110
# 1571286                                           0.006771
# 2062484                                           0.006771
# 1419726                                           0.006464
# 1416932                                           0.006771
#
#          TE_present_media_like_timestamp  TE_tweet_type_like_timestamp  \
# 1971849                         0.364952                      0.246367
# 1571286                         0.449325                      0.246367
# 2062484                         0.492777                      0.482271
# 1419726                         0.364952                      0.246367
# 1416932                         0.449325                      0.246367
#
#          TE_language_like_timestamp  TE_engaged_with_user_id_like_timestamp  \
# 1971849                    0.379281                                0.343649
# 1571286                    0.415885                                0.357950
# 2062484                    0.415885                                0.393745
# 1419726                    0.379281                                0.479836
# 1416932                    0.419006                                0.448859
#
#          TE_enaging_user_id_like_timestamp  \
# 1971849                           0.393745
# 1571286                           0.374995
# 2062484                           0.374995
# 1419726                           0.357950
# 1416932                           0.422614
#
#          TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_reply_timestamp  \
# 1971849                                           0.006945
# 1571286                                           0.004904
# 2062484                                           0.051740
# 1419726                                           0.008158
# 1416932                                           0.004478
#
#          TE_engaged_with_user_id_tweet_type_language_reply_timestamp  \
# 1971849                                           0.014197
# 1571286                                           0.029500
# 2062484                                           0.029500
# 1419726                                           0.020345
# 1416932                                           0.028096
#
#          TE_tw_first_word_tweet_type_language_reply_timestamp  \
# 1971849                                            0.02950
# 1571286                                            0.02950
# 2062484                                            0.03232
# 1419726                                            0.02950
# 1416932                                            0.02950
#
#          TE_tw_last_word_tweet_type_language_reply_timestamp  \
# 1971849                                           0.007291
# 1571286                                           0.004876
# 2062484                                           0.032320
# 1419726                                           0.026819
# 1416932                                           0.005209
#
#          TE_hash0_tweet_type_language_reply_timestamp  \
# 1971849                                      0.010157
# 1571286                                      0.004917
# 2062484                                      0.025486
# 1419726                                      0.004758
# 1416932                                      0.029500
#
#          TE_hash1_tweet_type_language_reply_timestamp  \
# 1971849                                      0.006570
# 1571286                                      0.004257
# 2062484                                      0.027220
# 1419726                                      0.006570
# 1416932                                      0.003646
#
#          TE_tw_uhash_tweet_type_language_reply_timestamp  \
# 1971849                                         0.010157
# 1571286                                         0.004917
# 2062484                                         0.025486
# 1419726                                         0.004758
# 1416932                                         0.029500
#
#          TE_tw_hash_reply_timestamp  TE_tw_freq_hash_reply_timestamp  \
# 1971849                      0.0295                           0.0295
# 1571286                      0.0295                           0.0295
# 2062484                      0.0295                           0.0295
# 1419726                      0.0295                           0.0295
# 1416932                      0.0295                           0.0295
#
#          TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_reply_timestamp  \
# 1971849                                           0.006809
# 1571286                                           0.004934
# 2062484                                           0.051742
# 1419726                                           0.008161
# 1416932                                           0.004331
#
#          TE_present_domains_present_media_tweet_type_language_reply_timestamp  \
# 1971849                                           0.007119
# 1571286                                           0.004565
# 2062484                                           0.016732
# 1419726                                           0.007119
# 1416932                                           0.003759
#
#          TE_present_links_present_media_tweet_type_language_reply_timestamp  \
# 1971849                                           0.007119
# 1571286                                           0.004565
# 2062484                                           0.016732
# 1419726                                           0.007119
# 1416932                                           0.003759
#
#          TE_hashtags_present_media_tweet_type_language_reply_timestamp  \
# 1971849                                           0.007318
# 1571286                                           0.004755
# 2062484                                           0.017758
# 1419726                                           0.007318
# 1416932                                           0.004060
#
#          TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_retweet_timestamp  \
# 1971849                                           0.082877
# 1571286                                           0.109182
# 2062484                                           0.096642
# 1419726                                           0.117667
# 1416932                                           0.089306
#
#          TE_engaged_with_user_id_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.015512
# 1571286                                           0.086867
# 2062484                                           0.086867
# 1419726                                           0.163357
# 1416932                                           0.082731
#
#          TE_tw_first_word_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.086867
# 1571286                                           0.086867
# 2062484                                           0.073602
# 1419726                                           0.086867
# 1416932                                           0.086867
#
#          TE_tw_last_word_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.091097
# 1571286                                           0.080474
# 2062484                                           0.073602
# 1419726                                           0.078970
# 1416932                                           0.073310
#
#          TE_hash0_tweet_type_language_retweet_timestamp  \
# 1971849                                        0.191127
# 1571286                                        0.081145
# 2062484                                        0.081918
# 1419726                                        0.159172
# 1416932                                        0.086867
#
#          TE_hash1_tweet_type_language_retweet_timestamp  \
# 1971849                                        0.094193
# 1571286                                        0.099170
# 2062484                                        0.081671
# 1419726                                        0.094193
# 1416932                                        0.080555
#
#          TE_tw_uhash_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.191127
# 1571286                                           0.081145
# 2062484                                           0.081918
# 1419726                                           0.159172
# 1416932                                           0.086867
#
#          TE_tw_hash_retweet_timestamp  TE_tw_freq_hash_retweet_timestamp  \
# 1971849                      0.086867                           0.086867
# 1571286                      0.086867                           0.086867
# 2062484                      0.086867                           0.086867
# 1419726                      0.086867                           0.086867
# 1416932                      0.086867                           0.086867
#
#          TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_retweet_timestamp  \
# 1971849                                           0.080529
# 1571286                                           0.109122
# 2062484                                           0.097437
# 1419726                                           0.116344
# 1416932                                           0.088920
#
#          TE_present_domains_present_media_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.086885
# 1571286                                           0.096020
# 2062484                                           0.108256
# 1419726                                           0.086885
# 1416932                                           0.082284
#
#          TE_present_links_present_media_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.086885
# 1571286                                           0.096020
# 2062484                                           0.108256
# 1419726                                           0.086885
# 1416932                                           0.082284
#
#          TE_hashtags_present_media_tweet_type_language_retweet_timestamp  \
# 1971849                                           0.084484
# 1571286                                           0.095936
# 2062484                                           0.099966
# 1419726                                           0.084484
# 1416932                                           0.087803
#
#          TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_retweet_with_comment_timestamp  \
# 1971849                                           0.004806
# 1571286                                           0.006926
# 2062484                                           0.013168
# 1419726                                           0.008168
# 1416932                                           0.003817
#
#          TE_engaged_with_user_id_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.001270
# 1571286                                           0.007110
# 2062484                                           0.007110
# 1419726                                           0.004903
# 1416932                                           0.006771
#
#          TE_tw_first_word_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.007110
# 1571286                                           0.007110
# 2062484                                           0.007603
# 1419726                                           0.007110
# 1416932                                           0.007110
#
#          TE_tw_last_word_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.006127
# 1571286                                           0.009440
# 2062484                                           0.007603
# 1419726                                           0.006464
# 1416932                                           0.001693
#
#          TE_hash0_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.004479
# 1571286                                           0.009518
# 2062484                                           0.007703
# 1419726                                           0.017276
# 1416932                                           0.007110
#
#          TE_hash1_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.006772
# 1571286                                           0.006076
# 2062484                                           0.007572
# 1419726                                           0.006772
# 1416932                                           0.003964
#
#          TE_tw_uhash_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.004479
# 1571286                                           0.009518
# 2062484                                           0.007703
# 1419726                                           0.017276
# 1416932                                           0.007110
#
#          TE_tw_hash_retweet_with_comment_timestamp  \
# 1971849                                    0.00711
# 1571286                                    0.00711
# 2062484                                    0.00711
# 1419726                                    0.00711
# 1416932                                    0.00711
#
#          TE_tw_freq_hash_retweet_with_comment_timestamp  \
# 1971849                                         0.00711
# 1571286                                         0.00711
# 2062484                                         0.00711
# 1419726                                         0.00711
# 1416932                                         0.00711
#
#          TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_retweet_with_comment_timestamp  \
# 1971849                                           0.004662
# 1571286                                           0.006878
# 2062484                                           0.013210
# 1419726                                           0.008109
# 1416932                                           0.003954
#
#          TE_present_domains_present_media_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.005856
# 1571286                                           0.005263
# 2062484                                           0.008756
# 1419726                                           0.005856
# 1416932                                           0.003115
#
#          TE_present_links_present_media_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.005856
# 1571286                                           0.005263
# 2062484                                           0.008756
# 1419726                                           0.005856
# 1416932                                           0.003115
#
#          TE_hashtags_present_media_tweet_type_language_retweet_with_comment_timestamp  \
# 1971849                                           0.005944
# 1571286                                           0.005506
# 2062484                                           0.009055
# 1419726                                           0.005944
# 1416932                                           0.003566
#
#          TE_present_domains_language_engagee_follows_engager_tweet_type_present_media_engaged_with_user_is_verified_like_timestamp  \
# 1971849                                           0.244193
# 1571286                                           0.335224
# 2062484                                           0.656567
# 1419726                                           0.285034
# 1416932                                           0.328778
#
#          TE_engaged_with_user_id_tweet_type_language_like_timestamp  \
# 1971849                                           0.168526
# 1571286                                           0.393745
# 2062484                                           0.393745
# 1419726                                           0.478445
# 1416932                                           0.422614
#
#          TE_tw_first_word_tweet_type_language_like_timestamp  \
# 1971849                                           0.393745
# 1571286                                           0.393745
# 2062484                                           0.505780
# 1419726                                           0.393745
# 1416932                                           0.393745
#
#          TE_tw_last_word_tweet_type_language_like_timestamp  \
# 1971849                                           0.226908
# 1571286                                           0.362603
# 2062484                                           0.505780
# 1419726                                           0.357950
# 1416932                                           0.272628
#
#          TE_hash0_tweet_type_language_like_timestamp  \
# 1971849                                     0.234804
# 1571286                                     0.365624
# 2062484                                     0.517565
# 1419726                                     0.329636
# 1416932                                     0.393745
#
#          TE_hash1_tweet_type_language_like_timestamp  \
# 1971849                                     0.279081
# 1571286                                     0.311002
# 2062484                                     0.523603
# 1419726                                     0.279081
# 1416932                                     0.257394
#
#          TE_tw_uhash_tweet_type_language_like_timestamp  \
# 1971849                                        0.234804
# 1571286                                        0.365624
# 2062484                                        0.517565
# 1419726                                        0.329636
# 1416932                                        0.393745
#
#          TE_tw_hash_like_timestamp  TE_tw_freq_hash_like_timestamp  \
# 1971849                   0.393745                        0.393745
# 1571286                   0.393745                        0.393745
# 2062484                   0.393745                        0.393745
# 1419726                   0.393745                        0.393745
# 1416932                   0.393745                        0.393745
#
#          TE_present_media_tweet_type_language_engaged_with_user_is_verified_enaging_user_is_verified_engagee_follows_engager_like_timestamp  \
# 1971849                                           0.236954
# 1571286                                           0.334552
# 2062484                                           0.655696
# 1419726                                           0.280565
# 1416932                                           0.321286
#
#          TE_present_domains_present_media_tweet_type_language_like_timestamp  \
# 1971849                                           0.236088
# 1571286                                           0.324611
# 2062484                                           0.598832
# 1419726                                           0.236088
# 1416932                                           0.333343
#
#          TE_present_links_present_media_tweet_type_language_like_timestamp  \
# 1971849                                           0.236088
# 1571286                                           0.324611
# 2062484                                           0.598832
# 1419726                                           0.236088
# 1416932                                           0.333343
#
#          TE_hashtags_present_media_tweet_type_language_like_timestamp  \
# 1971849                                           0.242079
# 1571286                                           0.330727
# 2062484                                           0.608145
# 1419726                                           0.242079
# 1416932                                           0.339689
#
#          TE_present_media_elapsed_time  TE_tweet_type_elapsed_time  \
# 1971849                       0.000012                    0.000007
# 1571286                       0.000012                    0.000007
# 2062484                       0.000011                    0.000013
# 1419726                       0.000012                    0.000007
# 1416932                       0.000012                    0.000007
#
#          TE_language_elapsed_time  CE_present_media  CE_tweet_type  \
# 1971849                  0.000009        18765501.0        9965234
# 1571286                  0.000009         6037524.0        9965234
# 2062484                  0.000009         1705608.0       17904537
# 1419726                  0.000009        18765501.0        9965234
# 1416932                  0.000019         6037524.0        9965234
#
#          CE_language  CE_engaged_with_user_id  CE_enaging_user_id  \
# 1971849     10957387                    434.0                 1.0
# 1571286      1949730                      4.0                 3.0
# 2062484      1949730                      2.0                 2.0
# 1419726     10957387                     20.0                 4.0
# 1416932      5205178                      4.0                 2.0
#
#          CE_present_media_norm  CE_tweet_type_norm  CE_language_norm  \
# 1971849               0.620148            0.329896          0.365925
# 1571286               0.198910            0.329896          0.063731
# 2062484               0.055562            0.587231          0.063731
# 1419726               0.620148            0.329896          0.365925
# 1416932               0.198910            0.329896          0.169873
#
#          CE_engaged_with_user_id_norm  CE_enaging_user_id_norm  \
# 1971849                  1.526477e-05             4.597823e-08
# 1571286                  1.839129e-07             1.379347e-07
# 2062484                  9.195645e-08             9.195645e-08
# 1419726                  7.356516e-07             1.379347e-07
# 1416932                  1.379347e-07             9.195645e-08
#
#          DE_enaging_user_id_enaging_user_following_count_1  \
# 1971849                                               -0.0
# 1571286                                                0.0
# 2062484                                                0.0
# 1419726                                                0.0
# 1416932                                               -0.0
#
#          DE_enaging_user_id_enaging_user_following_count_-1  \
# 1971849                                               -0.0
# 1571286                                                0.0
# 2062484                                                0.0
# 1419726                                                0.0
# 1416932                                               -0.0
#
#          DE_enaging_user_id_language_1  DE_enaging_user_id_language_-1  \
# 1971849                           -0.0                            -0.0
# 1571286                            0.0                             0.0
# 2062484                            0.0                            -0.0
# 1419726                           -0.0                             0.0
# 1416932                           -0.0                            -0.0
#
#          a_ff_rate  b_ff_rate
# 1971849   0.055111   0.846154
# 1571286   1.079592   0.198413
# 2062484   1.041152   0.792415
# 1419726   0.259175   1.592810
# 1416932   1.950249   0.424242

# %%
#label_names = ['reply_timestamp', 'retweet_timestamp', 'retweet_with_comment_timestamp', 'like_timestamp']

# %%
# %%time
# TRAIN AND VALIDATE

NROUND = 500
VERBOSE_EVAL = 50
#ESR = 50
LR = [0.1,0.03,0.07,0.01]

#Like
#xgb_parms['learning_rate'] = LR[TARGET_id]    
oof = np.zeros((len(valid),len(label_names)))
preds = []

for i in range(4):
    name = label_names[i]
    print('#'*25);print('###',name);print('#'*25)

    start = time.time(); print('Training...')
#     model[i].fit(X=train, Y=Y_train.iloc[:, i],
#          categorical_feature=set([]))
    model2[i].fit(X=train, Y=Y_train.iloc[:, i], X_val=valid, Y_val=Y_valid.iloc[:, i],
         categorical_feature=set([]))
    print('Training took %.1f seconds'%(time.time()-start))
        
    start = time.time(); print('Predicting...')
    #Y_valid[f'pred_{name}'] = xgb.dask.predict(client,model,valid)
    oof[:, i] += model2[i].get_prediction(valid)
    #preds.append(xgb.dask.predict(client,model,valid))
    print('Took %.1f seconds'%(time.time()-start))
# Out:
# #########################
# ### reply_timestamp
# #########################
# Training...
# /home/xianyang/sw/miniconda3/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/xianyang/sw/miniconda3/lib/python3.7/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's binary_logloss: 0.130751
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_logloss: 0.127487
# [3]	valid_0's binary_logloss: 0.125697
# [4]	valid_0's binary_logloss: 0.123971
# [5]	valid_0's binary_logloss: 0.12255
# [6]	valid_0's binary_logloss: 0.121293
# [7]	valid_0's binary_logloss: 0.119757
# [8]	valid_0's binary_logloss: 0.118834
# [9]	valid_0's binary_logloss: 0.118142
# [10]	valid_0's binary_logloss: 0.117543
# [11]	valid_0's binary_logloss: 0.116897
# [12]	valid_0's binary_logloss: 0.116358
# [13]	valid_0's binary_logloss: 0.11588
# [14]	valid_0's binary_logloss: 0.115477
# [15]	valid_0's binary_logloss: 0.114737
# [16]	valid_0's binary_logloss: 0.114123
# [17]	valid_0's binary_logloss: 0.113837
# [18]	valid_0's binary_logloss: 0.113549
# [19]	valid_0's binary_logloss: 0.113044
# [20]	valid_0's binary_logloss: 0.112627
# [21]	valid_0's binary_logloss: 0.112236
# [22]	valid_0's binary_logloss: 0.112046
# [23]	valid_0's binary_logloss: 0.111872
# [24]	valid_0's binary_logloss: 0.111711
# [25]	valid_0's binary_logloss: 0.111577
# [26]	valid_0's binary_logloss: 0.111291
# [27]	valid_0's binary_logloss: 0.11116
# [28]	valid_0's binary_logloss: 0.11103
# [29]	valid_0's binary_logloss: 0.110919
# [30]	valid_0's binary_logloss: 0.110818
# [31]	valid_0's binary_logloss: 0.110733
# [32]	valid_0's binary_logloss: 0.11063
# [33]	valid_0's binary_logloss: 0.110558
# [34]	valid_0's binary_logloss: 0.110473
# [35]	valid_0's binary_logloss: 0.110275
# [36]	valid_0's binary_logloss: 0.110214
# [37]	valid_0's binary_logloss: 0.110141
# [38]	valid_0's binary_logloss: 0.109974
# [39]	valid_0's binary_logloss: 0.109828
# [40]	valid_0's binary_logloss: 0.109701
# [41]	valid_0's binary_logloss: 0.109579
# [42]	valid_0's binary_logloss: 0.109477
# [43]	valid_0's binary_logloss: 0.109379
# [44]	valid_0's binary_logloss: 0.109289
# [45]	valid_0's binary_logloss: 0.109241
# [46]	valid_0's binary_logloss: 0.10916
# [47]	valid_0's binary_logloss: 0.10912
# [48]	valid_0's binary_logloss: 0.109084
# [49]	valid_0's binary_logloss: 0.109048
# [50]	valid_0's binary_logloss: 0.108984
# [51]	valid_0's binary_logloss: 0.108921
# [52]	valid_0's binary_logloss: 0.108868
# [53]	valid_0's binary_logloss: 0.108815
# [54]	valid_0's binary_logloss: 0.108783
# [55]	valid_0's binary_logloss: 0.108759
# [56]	valid_0's binary_logloss: 0.108732
# [57]	valid_0's binary_logloss: 0.108704
# [58]	valid_0's binary_logloss: 0.108675
# [59]	valid_0's binary_logloss: 0.108635
# [60]	valid_0's binary_logloss: 0.108609
# [61]	valid_0's binary_logloss: 0.108584
# [62]	valid_0's binary_logloss: 0.108551
# [63]	valid_0's binary_logloss: 0.108517
# [64]	valid_0's binary_logloss: 0.108496
# [65]	valid_0's binary_logloss: 0.108465
# [66]	valid_0's binary_logloss: 0.108434
# [67]	valid_0's binary_logloss: 0.108408
# [68]	valid_0's binary_logloss: 0.108379
# [69]	valid_0's binary_logloss: 0.108361
# [70]	valid_0's binary_logloss: 0.108336
# [71]	valid_0's binary_logloss: 0.108312
# [72]	valid_0's binary_logloss: 0.108291
# [73]	valid_0's binary_logloss: 0.10827
# [74]	valid_0's binary_logloss: 0.108246
# [75]	valid_0's binary_logloss: 0.108227
# [76]	valid_0's binary_logloss: 0.108209
# [77]	valid_0's binary_logloss: 0.108189
# [78]	valid_0's binary_logloss: 0.108168
# [79]	valid_0's binary_logloss: 0.108146
# [80]	valid_0's binary_logloss: 0.10813
# [81]	valid_0's binary_logloss: 0.108111
# [82]	valid_0's binary_logloss: 0.108093
# [83]	valid_0's binary_logloss: 0.108078
# [84]	valid_0's binary_logloss: 0.108064
# [85]	valid_0's binary_logloss: 0.108045
# [86]	valid_0's binary_logloss: 0.108031
# [87]	valid_0's binary_logloss: 0.108019
# [88]	valid_0's binary_logloss: 0.108006
# [89]	valid_0's binary_logloss: 0.107992
# [90]	valid_0's binary_logloss: 0.107979
# [91]	valid_0's binary_logloss: 0.107963
# [92]	valid_0's binary_logloss: 0.107948
# [93]	valid_0's binary_logloss: 0.107935
# [94]	valid_0's binary_logloss: 0.107921
# [95]	valid_0's binary_logloss: 0.107911
# [96]	valid_0's binary_logloss: 0.107899
# [97]	valid_0's binary_logloss: 0.107885
# [98]	valid_0's binary_logloss: 0.107871
# [99]	valid_0's binary_logloss: 0.107857
# [100]	valid_0's binary_logloss: 0.107849
# [101]	valid_0's binary_logloss: 0.107837
# [102]	valid_0's binary_logloss: 0.107828
# [103]	valid_0's binary_logloss: 0.107818
# [104]	valid_0's binary_logloss: 0.107807
# [105]	valid_0's binary_logloss: 0.107798
# [106]	valid_0's binary_logloss: 0.107787
# [107]	valid_0's binary_logloss: 0.107777
# [108]	valid_0's binary_logloss: 0.107766
# [109]	valid_0's binary_logloss: 0.107759
# [110]	valid_0's binary_logloss: 0.107748
# [111]	valid_0's binary_logloss: 0.107737
# [112]	valid_0's binary_logloss: 0.107728
# [113]	valid_0's binary_logloss: 0.107717
# [114]	valid_0's binary_logloss: 0.107707
# [115]	valid_0's binary_logloss: 0.107695
# [116]	valid_0's binary_logloss: 0.107685
# [117]	valid_0's binary_logloss: 0.107675
# [118]	valid_0's binary_logloss: 0.107666
# [119]	valid_0's binary_logloss: 0.107658
# [120]	valid_0's binary_logloss: 0.10765
# [121]	valid_0's binary_logloss: 0.107642
# [122]	valid_0's binary_logloss: 0.107632
# [123]	valid_0's binary_logloss: 0.107625
# [124]	valid_0's binary_logloss: 0.107618
# [125]	valid_0's binary_logloss: 0.107609
# [126]	valid_0's binary_logloss: 0.107603
# [127]	valid_0's binary_logloss: 0.107596
# [128]	valid_0's binary_logloss: 0.10759
# [129]	valid_0's binary_logloss: 0.107584
# [130]	valid_0's binary_logloss: 0.107576
# [131]	valid_0's binary_logloss: 0.107568
# [132]	valid_0's binary_logloss: 0.107561
# [133]	valid_0's binary_logloss: 0.107553
# [134]	valid_0's binary_logloss: 0.107543
# [135]	valid_0's binary_logloss: 0.107539
# [136]	valid_0's binary_logloss: 0.107529
# [137]	valid_0's binary_logloss: 0.10752
# [138]	valid_0's binary_logloss: 0.107515
# [139]	valid_0's binary_logloss: 0.107507
# [140]	valid_0's binary_logloss: 0.107497
# [141]	valid_0's binary_logloss: 0.107492
# [142]	valid_0's binary_logloss: 0.107483
# [143]	valid_0's binary_logloss: 0.107476
# [144]	valid_0's binary_logloss: 0.107471
# [145]	valid_0's binary_logloss: 0.107463
# [146]	valid_0's binary_logloss: 0.107459
# [147]	valid_0's binary_logloss: 0.107453
# [148]	valid_0's binary_logloss: 0.107444
# [149]	valid_0's binary_logloss: 0.107438
# [150]	valid_0's binary_logloss: 0.107434
# [151]	valid_0's binary_logloss: 0.10743
# [152]	valid_0's binary_logloss: 0.107423
# [153]	valid_0's binary_logloss: 0.10742
# [154]	valid_0's binary_logloss: 0.10741
# [155]	valid_0's binary_logloss: 0.107404
# [156]	valid_0's binary_logloss: 0.107398
# [157]	valid_0's binary_logloss: 0.107393
# [158]	valid_0's binary_logloss: 0.107387
# [159]	valid_0's binary_logloss: 0.107382
# [160]	valid_0's binary_logloss: 0.107378
# [161]	valid_0's binary_logloss: 0.107373
# [162]	valid_0's binary_logloss: 0.107368
# [163]	valid_0's binary_logloss: 0.107362
# [164]	valid_0's binary_logloss: 0.107357
# [165]	valid_0's binary_logloss: 0.10735
# [166]	valid_0's binary_logloss: 0.107347
# [167]	valid_0's binary_logloss: 0.107342
# [168]	valid_0's binary_logloss: 0.107334
# [169]	valid_0's binary_logloss: 0.10733
# [170]	valid_0's binary_logloss: 0.107326
# [171]	valid_0's binary_logloss: 0.10732
# [172]	valid_0's binary_logloss: 0.107315
# [173]	valid_0's binary_logloss: 0.107311
# [174]	valid_0's binary_logloss: 0.107307
# [175]	valid_0's binary_logloss: 0.107304
# [176]	valid_0's binary_logloss: 0.107299
# [177]	valid_0's binary_logloss: 0.107294
# [178]	valid_0's binary_logloss: 0.107289
# [179]	valid_0's binary_logloss: 0.107285
# [180]	valid_0's binary_logloss: 0.107282
# [181]	valid_0's binary_logloss: 0.10728
# [182]	valid_0's binary_logloss: 0.107277
# [183]	valid_0's binary_logloss: 0.107271
# [184]	valid_0's binary_logloss: 0.107264
# [185]	valid_0's binary_logloss: 0.10726
# [186]	valid_0's binary_logloss: 0.107253
# [187]	valid_0's binary_logloss: 0.107249
# [188]	valid_0's binary_logloss: 0.107245
# [189]	valid_0's binary_logloss: 0.107241
# [190]	valid_0's binary_logloss: 0.107238
# [191]	valid_0's binary_logloss: 0.107233
# [192]	valid_0's binary_logloss: 0.107229
# [193]	valid_0's binary_logloss: 0.107225
# [194]	valid_0's binary_logloss: 0.10722
# [195]	valid_0's binary_logloss: 0.107217
# [196]	valid_0's binary_logloss: 0.107212
# [197]	valid_0's binary_logloss: 0.107209
# [198]	valid_0's binary_logloss: 0.107206
# [199]	valid_0's binary_logloss: 0.107204
# [200]	valid_0's binary_logloss: 0.107198
# [201]	valid_0's binary_logloss: 0.107194
# [202]	valid_0's binary_logloss: 0.10719
# [203]	valid_0's binary_logloss: 0.107188
# [204]	valid_0's binary_logloss: 0.107183
# [205]	valid_0's binary_logloss: 0.10718
# [206]	valid_0's binary_logloss: 0.107177
# [207]	valid_0's binary_logloss: 0.107175
# [208]	valid_0's binary_logloss: 0.107172
# [209]	valid_0's binary_logloss: 0.107167
# [210]	valid_0's binary_logloss: 0.107164
# [211]	valid_0's binary_logloss: 0.107162
# [212]	valid_0's binary_logloss: 0.107159
# [213]	valid_0's binary_logloss: 0.107157
# [214]	valid_0's binary_logloss: 0.107155
# [215]	valid_0's binary_logloss: 0.107151
# [216]	valid_0's binary_logloss: 0.107148
# [217]	valid_0's binary_logloss: 0.107146
# [218]	valid_0's binary_logloss: 0.107143
# [219]	valid_0's binary_logloss: 0.107141
# [220]	valid_0's binary_logloss: 0.107139
# [221]	valid_0's binary_logloss: 0.107137
# [222]	valid_0's binary_logloss: 0.107134
# [223]	valid_0's binary_logloss: 0.107131
# [224]	valid_0's binary_logloss: 0.107127
# [225]	valid_0's binary_logloss: 0.107126
# [226]	valid_0's binary_logloss: 0.107122
# [227]	valid_0's binary_logloss: 0.107119
# [228]	valid_0's binary_logloss: 0.107117
# [229]	valid_0's binary_logloss: 0.107114
# [230]	valid_0's binary_logloss: 0.10711
# [231]	valid_0's binary_logloss: 0.107108
# [232]	valid_0's binary_logloss: 0.107106
# [233]	valid_0's binary_logloss: 0.107102
# [234]	valid_0's binary_logloss: 0.107099
# [235]	valid_0's binary_logloss: 0.107096
# [236]	valid_0's binary_logloss: 0.107094
# [237]	valid_0's binary_logloss: 0.10709
# [238]	valid_0's binary_logloss: 0.107088
# [239]	valid_0's binary_logloss: 0.107085
# [240]	valid_0's binary_logloss: 0.10708
# [241]	valid_0's binary_logloss: 0.107079
# [242]	valid_0's binary_logloss: 0.107074
# [243]	valid_0's binary_logloss: 0.107072
# [244]	valid_0's binary_logloss: 0.107068
# [245]	valid_0's binary_logloss: 0.107065
# [246]	valid_0's binary_logloss: 0.107061
# [247]	valid_0's binary_logloss: 0.107058
# [248]	valid_0's binary_logloss: 0.107058
# [249]	valid_0's binary_logloss: 0.107055
# [250]	valid_0's binary_logloss: 0.107054
# [251]	valid_0's binary_logloss: 0.10705
# [252]	valid_0's binary_logloss: 0.107048
# [253]	valid_0's binary_logloss: 0.107046
# [254]	valid_0's binary_logloss: 0.107045
# [255]	valid_0's binary_logloss: 0.107044
# [256]	valid_0's binary_logloss: 0.107041
# [257]	valid_0's binary_logloss: 0.107037
# [258]	valid_0's binary_logloss: 0.107035
# [259]	valid_0's binary_logloss: 0.107033
# [260]	valid_0's binary_logloss: 0.10703
# [261]	valid_0's binary_logloss: 0.107027
# [262]	valid_0's binary_logloss: 0.107026
# [263]	valid_0's binary_logloss: 0.107022
# [264]	valid_0's binary_logloss: 0.10702
# [265]	valid_0's binary_logloss: 0.107016
# [266]	valid_0's binary_logloss: 0.107014
# [267]	valid_0's binary_logloss: 0.107012
# [268]	valid_0's binary_logloss: 0.107009
# [269]	valid_0's binary_logloss: 0.107009
# [270]	valid_0's binary_logloss: 0.107008
# [271]	valid_0's binary_logloss: 0.107005
# [272]	valid_0's binary_logloss: 0.107003
# [273]	valid_0's binary_logloss: 0.107001
# [274]	valid_0's binary_logloss: 0.106999
# [275]	valid_0's binary_logloss: 0.106998
# [276]	valid_0's binary_logloss: 0.106996
# [277]	valid_0's binary_logloss: 0.106994
# [278]	valid_0's binary_logloss: 0.106991
# [279]	valid_0's binary_logloss: 0.106987
# [280]	valid_0's binary_logloss: 0.106985
# [281]	valid_0's binary_logloss: 0.106983
# [282]	valid_0's binary_logloss: 0.106981
# [283]	valid_0's binary_logloss: 0.106977
# [284]	valid_0's binary_logloss: 0.106975
# [285]	valid_0's binary_logloss: 0.106973
# [286]	valid_0's binary_logloss: 0.106971
# [287]	valid_0's binary_logloss: 0.106969
# [288]	valid_0's binary_logloss: 0.106968
# [289]	valid_0's binary_logloss: 0.106965
# [290]	valid_0's binary_logloss: 0.106963
# [291]	valid_0's binary_logloss: 0.106962
# [292]	valid_0's binary_logloss: 0.106962
# [293]	valid_0's binary_logloss: 0.106959
# [294]	valid_0's binary_logloss: 0.106956
# [295]	valid_0's binary_logloss: 0.106954
# [296]	valid_0's binary_logloss: 0.106953
# [297]	valid_0's binary_logloss: 0.106952
# [298]	valid_0's binary_logloss: 0.10695
# [299]	valid_0's binary_logloss: 0.10695
# [300]	valid_0's binary_logloss: 0.106948
# [301]	valid_0's binary_logloss: 0.106947
# [302]	valid_0's binary_logloss: 0.106943
# [303]	valid_0's binary_logloss: 0.106942
# [304]	valid_0's binary_logloss: 0.106939
# [305]	valid_0's binary_logloss: 0.106936
# [306]	valid_0's binary_logloss: 0.106934
# [307]	valid_0's binary_logloss: 0.106931
# [308]	valid_0's binary_logloss: 0.106929
# [309]	valid_0's binary_logloss: 0.106927
# [310]	valid_0's binary_logloss: 0.106925
# [311]	valid_0's binary_logloss: 0.106924
# [312]	valid_0's binary_logloss: 0.106921
# [313]	valid_0's binary_logloss: 0.106921
# [314]	valid_0's binary_logloss: 0.106919
# [315]	valid_0's binary_logloss: 0.106918
# [316]	valid_0's binary_logloss: 0.106916
# [317]	valid_0's binary_logloss: 0.106914
# [318]	valid_0's binary_logloss: 0.106912
# [319]	valid_0's binary_logloss: 0.10691
# [320]	valid_0's binary_logloss: 0.106908
# [321]	valid_0's binary_logloss: 0.106906
# [322]	valid_0's binary_logloss: 0.106904
# [323]	valid_0's binary_logloss: 0.106903
# [324]	valid_0's binary_logloss: 0.106899
# [325]	valid_0's binary_logloss: 0.106898
# [326]	valid_0's binary_logloss: 0.106896
# [327]	valid_0's binary_logloss: 0.106894
# [328]	valid_0's binary_logloss: 0.106893
# [329]	valid_0's binary_logloss: 0.106892
# [330]	valid_0's binary_logloss: 0.10689
# [331]	valid_0's binary_logloss: 0.106888
# [332]	valid_0's binary_logloss: 0.106887
# [333]	valid_0's binary_logloss: 0.106886
# [334]	valid_0's binary_logloss: 0.106886
# [335]	valid_0's binary_logloss: 0.106884
# [336]	valid_0's binary_logloss: 0.106883
# [337]	valid_0's binary_logloss: 0.106881
# [338]	valid_0's binary_logloss: 0.106879
# [339]	valid_0's binary_logloss: 0.106877
# [340]	valid_0's binary_logloss: 0.106875
# [341]	valid_0's binary_logloss: 0.106873
# [342]	valid_0's binary_logloss: 0.106871
# [343]	valid_0's binary_logloss: 0.106869
# [344]	valid_0's binary_logloss: 0.106868
# [345]	valid_0's binary_logloss: 0.106866
# [346]	valid_0's binary_logloss: 0.106864
# [347]	valid_0's binary_logloss: 0.106862
# [348]	valid_0's binary_logloss: 0.106862
# [349]	valid_0's binary_logloss: 0.106861
# [350]	valid_0's binary_logloss: 0.10686
# [351]	valid_0's binary_logloss: 0.106858
# [352]	valid_0's binary_logloss: 0.106858
# [353]	valid_0's binary_logloss: 0.106857
# [354]	valid_0's binary_logloss: 0.106857
# [355]	valid_0's binary_logloss: 0.106854
# [356]	valid_0's binary_logloss: 0.106853
# [357]	valid_0's binary_logloss: 0.106851
# [358]	valid_0's binary_logloss: 0.10685
# [359]	valid_0's binary_logloss: 0.10685
# [360]	valid_0's binary_logloss: 0.106849
# [361]	valid_0's binary_logloss: 0.106848
# [362]	valid_0's binary_logloss: 0.106848
# [363]	valid_0's binary_logloss: 0.106846
# [364]	valid_0's binary_logloss: 0.106843
# [365]	valid_0's binary_logloss: 0.106843
# [366]	valid_0's binary_logloss: 0.106841
# [367]	valid_0's binary_logloss: 0.106839
# [368]	valid_0's binary_logloss: 0.106836
# [369]	valid_0's binary_logloss: 0.106835
# [370]	valid_0's binary_logloss: 0.106836
# [371]	valid_0's binary_logloss: 0.106835
# [372]	valid_0's binary_logloss: 0.106833
# [373]	valid_0's binary_logloss: 0.106831
# [374]	valid_0's binary_logloss: 0.10683
# [375]	valid_0's binary_logloss: 0.10683
# [376]	valid_0's binary_logloss: 0.106829
# [377]	valid_0's binary_logloss: 0.106828
# [378]	valid_0's binary_logloss: 0.106827
# [379]	valid_0's binary_logloss: 0.106825
# [380]	valid_0's binary_logloss: 0.106823
# [381]	valid_0's binary_logloss: 0.106823
# [382]	valid_0's binary_logloss: 0.106821
# [383]	valid_0's binary_logloss: 0.106821
# [384]	valid_0's binary_logloss: 0.10682
# [385]	valid_0's binary_logloss: 0.106819
# [386]	valid_0's binary_logloss: 0.106816
# [387]	valid_0's binary_logloss: 0.106813
# [388]	valid_0's binary_logloss: 0.106812
# [389]	valid_0's binary_logloss: 0.10681
# [390]	valid_0's binary_logloss: 0.106809
# [391]	valid_0's binary_logloss: 0.106806
# [392]	valid_0's binary_logloss: 0.106805
# [393]	valid_0's binary_logloss: 0.106803
# [394]	valid_0's binary_logloss: 0.106801
# [395]	valid_0's binary_logloss: 0.1068
# [396]	valid_0's binary_logloss: 0.106797
# [397]	valid_0's binary_logloss: 0.106797
# [398]	valid_0's binary_logloss: 0.106795
# [399]	valid_0's binary_logloss: 0.106794
# [400]	valid_0's binary_logloss: 0.106792
# [401]	valid_0's binary_logloss: 0.106792
# [402]	valid_0's binary_logloss: 0.106792
# [403]	valid_0's binary_logloss: 0.10679
# [404]	valid_0's binary_logloss: 0.10679
# [405]	valid_0's binary_logloss: 0.10679
# [406]	valid_0's binary_logloss: 0.106789
# [407]	valid_0's binary_logloss: 0.106787
# [408]	valid_0's binary_logloss: 0.106786
# [409]	valid_0's binary_logloss: 0.106785
# [410]	valid_0's binary_logloss: 0.106784
# [411]	valid_0's binary_logloss: 0.106785
# [412]	valid_0's binary_logloss: 0.106783
# [413]	valid_0's binary_logloss: 0.106781
# [414]	valid_0's binary_logloss: 0.10678
# [415]	valid_0's binary_logloss: 0.106779
# [416]	valid_0's binary_logloss: 0.106778
# [417]	valid_0's binary_logloss: 0.106778
# [418]	valid_0's binary_logloss: 0.106777
# [419]	valid_0's binary_logloss: 0.106777
# [420]	valid_0's binary_logloss: 0.106776
# [421]	valid_0's binary_logloss: 0.106773
# [422]	valid_0's binary_logloss: 0.106773
# [423]	valid_0's binary_logloss: 0.106773
# [424]	valid_0's binary_logloss: 0.106771
# [425]	valid_0's binary_logloss: 0.10677
# [426]	valid_0's binary_logloss: 0.10677
# [427]	valid_0's binary_logloss: 0.10677
# [428]	valid_0's binary_logloss: 0.106769
# [429]	valid_0's binary_logloss: 0.106768
# [430]	valid_0's binary_logloss: 0.106766
# [431]	valid_0's binary_logloss: 0.106765
# [432]	valid_0's binary_logloss: 0.106764
# [433]	valid_0's binary_logloss: 0.106764
# [434]	valid_0's binary_logloss: 0.106762
# [435]	valid_0's binary_logloss: 0.10676
# [436]	valid_0's binary_logloss: 0.106758
# [437]	valid_0's binary_logloss: 0.106757
# [438]	valid_0's binary_logloss: 0.106757
# [439]	valid_0's binary_logloss: 0.106756
# [440]	valid_0's binary_logloss: 0.106756
# [441]	valid_0's binary_logloss: 0.106756
# [442]	valid_0's binary_logloss: 0.106754
# [443]	valid_0's binary_logloss: 0.106753
# [444]	valid_0's binary_logloss: 0.106754
# [445]	valid_0's binary_logloss: 0.106754
# [446]	valid_0's binary_logloss: 0.106753
# [447]	valid_0's binary_logloss: 0.106753
# [448]	valid_0's binary_logloss: 0.106752
# [449]	valid_0's binary_logloss: 0.106751
# [450]	valid_0's binary_logloss: 0.10675
# [451]	valid_0's binary_logloss: 0.106748
# [452]	valid_0's binary_logloss: 0.106748
# [453]	valid_0's binary_logloss: 0.106747
# [454]	valid_0's binary_logloss: 0.106747
# [455]	valid_0's binary_logloss: 0.106745
# [456]	valid_0's binary_logloss: 0.106744
# [457]	valid_0's binary_logloss: 0.106744
# [458]	valid_0's binary_logloss: 0.106743
# [459]	valid_0's binary_logloss: 0.106742
# [460]	valid_0's binary_logloss: 0.106742
# [461]	valid_0's binary_logloss: 0.106742
# [462]	valid_0's binary_logloss: 0.10674
# [463]	valid_0's binary_logloss: 0.106739
# [464]	valid_0's binary_logloss: 0.106737
# [465]	valid_0's binary_logloss: 0.106734
# [466]	valid_0's binary_logloss: 0.106733
# [467]	valid_0's binary_logloss: 0.106732
# [468]	valid_0's binary_logloss: 0.106731
# [469]	valid_0's binary_logloss: 0.106729
# [470]	valid_0's binary_logloss: 0.106728
# [471]	valid_0's binary_logloss: 0.106728
# [472]	valid_0's binary_logloss: 0.106726
# [473]	valid_0's binary_logloss: 0.106726
# [474]	valid_0's binary_logloss: 0.106726
# [475]	valid_0's binary_logloss: 0.106725
# [476]	valid_0's binary_logloss: 0.106724
# [477]	valid_0's binary_logloss: 0.106723
# [478]	valid_0's binary_logloss: 0.106722
# [479]	valid_0's binary_logloss: 0.106721
# [480]	valid_0's binary_logloss: 0.10672
# [481]	valid_0's binary_logloss: 0.106719
# [482]	valid_0's binary_logloss: 0.106719
# [483]	valid_0's binary_logloss: 0.106718
# [484]	valid_0's binary_logloss: 0.106717
# [485]	valid_0's binary_logloss: 0.106716
# [486]	valid_0's binary_logloss: 0.106715
# [487]	valid_0's binary_logloss: 0.106714
# [488]	valid_0's binary_logloss: 0.106713
# [489]	valid_0's binary_logloss: 0.106712
# [490]	valid_0's binary_logloss: 0.106713
# [491]	valid_0's binary_logloss: 0.10671
# [492]	valid_0's binary_logloss: 0.106708
# [493]	valid_0's binary_logloss: 0.106708
# [494]	valid_0's binary_logloss: 0.106706
# [495]	valid_0's binary_logloss: 0.106706
# [496]	valid_0's binary_logloss: 0.106704
# [497]	valid_0's binary_logloss: 0.106703
# [498]	valid_0's binary_logloss: 0.106703
# [499]	valid_0's binary_logloss: 0.106702
# [500]	valid_0's binary_logloss: 0.1067
# [501]	valid_0's binary_logloss: 0.106699
# [502]	valid_0's binary_logloss: 0.106698
# [503]	valid_0's binary_logloss: 0.106697
# [504]	valid_0's binary_logloss: 0.106697
# [505]	valid_0's binary_logloss: 0.106696
# [506]	valid_0's binary_logloss: 0.106696
# [507]	valid_0's binary_logloss: 0.106694
# [508]	valid_0's binary_logloss: 0.106694
# [509]	valid_0's binary_logloss: 0.106693
# [510]	valid_0's binary_logloss: 0.106693
# [511]	valid_0's binary_logloss: 0.106692
# [512]	valid_0's binary_logloss: 0.106693
# [513]	valid_0's binary_logloss: 0.106692
# [514]	valid_0's binary_logloss: 0.106691
# [515]	valid_0's binary_logloss: 0.10669
# [516]	valid_0's binary_logloss: 0.106689
# [517]	valid_0's binary_logloss: 0.106688
# [518]	valid_0's binary_logloss: 0.106688
# [519]	valid_0's binary_logloss: 0.106688
# [520]	valid_0's binary_logloss: 0.106686
# [521]	valid_0's binary_logloss: 0.106685
# [522]	valid_0's binary_logloss: 0.106684
# [523]	valid_0's binary_logloss: 0.106683
# [524]	valid_0's binary_logloss: 0.106682
# [525]	valid_0's binary_logloss: 0.106681
# [526]	valid_0's binary_logloss: 0.106681
# [527]	valid_0's binary_logloss: 0.106682
# [528]	valid_0's binary_logloss: 0.106681
# [529]	valid_0's binary_logloss: 0.10668
# [530]	valid_0's binary_logloss: 0.106679
# [531]	valid_0's binary_logloss: 0.106679
# [532]	valid_0's binary_logloss: 0.106678
# [533]	valid_0's binary_logloss: 0.106678
# [534]	valid_0's binary_logloss: 0.106678
# [535]	valid_0's binary_logloss: 0.106677
# [536]	valid_0's binary_logloss: 0.106677
# [537]	valid_0's binary_logloss: 0.106678
# [538]	valid_0's binary_logloss: 0.106677
# [539]	valid_0's binary_logloss: 0.106676
# [540]	valid_0's binary_logloss: 0.106677
# [541]	valid_0's binary_logloss: 0.106676
# [542]	valid_0's binary_logloss: 0.106675
# [543]	valid_0's binary_logloss: 0.106675
# [544]	valid_0's binary_logloss: 0.106672
# [545]	valid_0's binary_logloss: 0.106672
# [546]	valid_0's binary_logloss: 0.106671
# [547]	valid_0's binary_logloss: 0.10667
# [548]	valid_0's binary_logloss: 0.10667
# [549]	valid_0's binary_logloss: 0.106669
# [550]	valid_0's binary_logloss: 0.106669
# [551]	valid_0's binary_logloss: 0.10667
# [552]	valid_0's binary_logloss: 0.106669
# [553]	valid_0's binary_logloss: 0.106668
# [554]	valid_0's binary_logloss: 0.106668
# [555]	valid_0's binary_logloss: 0.106668
# [556]	valid_0's binary_logloss: 0.106668
# [557]	valid_0's binary_logloss: 0.106667
# [558]	valid_0's binary_logloss: 0.106666
# [559]	valid_0's binary_logloss: 0.106665
# [560]	valid_0's binary_logloss: 0.106665
# [561]	valid_0's binary_logloss: 0.106665
# [562]	valid_0's binary_logloss: 0.106663
# [563]	valid_0's binary_logloss: 0.106663
# [564]	valid_0's binary_logloss: 0.106661
# [565]	valid_0's binary_logloss: 0.106661
# [566]	valid_0's binary_logloss: 0.10666
# [567]	valid_0's binary_logloss: 0.10666
# [568]	valid_0's binary_logloss: 0.10666
# [569]	valid_0's binary_logloss: 0.106659
# [570]	valid_0's binary_logloss: 0.106658
# [571]	valid_0's binary_logloss: 0.106657
# [572]	valid_0's binary_logloss: 0.106657
# [573]	valid_0's binary_logloss: 0.106656
# [574]	valid_0's binary_logloss: 0.106655
# [575]	valid_0's binary_logloss: 0.106654
# [576]	valid_0's binary_logloss: 0.106654
# [577]	valid_0's binary_logloss: 0.106654
# [578]	valid_0's binary_logloss: 0.106653
# [579]	valid_0's binary_logloss: 0.106653
# [580]	valid_0's binary_logloss: 0.106652
# [581]	valid_0's binary_logloss: 0.106652
# [582]	valid_0's binary_logloss: 0.106652
# [583]	valid_0's binary_logloss: 0.106651
# [584]	valid_0's binary_logloss: 0.10665
# [585]	valid_0's binary_logloss: 0.10665
# [586]	valid_0's binary_logloss: 0.106648
# [587]	valid_0's binary_logloss: 0.106647
# [588]	valid_0's binary_logloss: 0.106647
# [589]	valid_0's binary_logloss: 0.106647
# [590]	valid_0's binary_logloss: 0.106646
# [591]	valid_0's binary_logloss: 0.106646
# [592]	valid_0's binary_logloss: 0.106645
# [593]	valid_0's binary_logloss: 0.106644
# [594]	valid_0's binary_logloss: 0.106643
# [595]	valid_0's binary_logloss: 0.106641
# [596]	valid_0's binary_logloss: 0.106641
# [597]	valid_0's binary_logloss: 0.106641
# [598]	valid_0's binary_logloss: 0.10664
# [599]	valid_0's binary_logloss: 0.10664
# [600]	valid_0's binary_logloss: 0.106639
# [601]	valid_0's binary_logloss: 0.106639
# [602]	valid_0's binary_logloss: 0.10664
# [603]	valid_0's binary_logloss: 0.10664
# [604]	valid_0's binary_logloss: 0.106639
# [605]	valid_0's binary_logloss: 0.106639
# [606]	valid_0's binary_logloss: 0.106639
# [607]	valid_0's binary_logloss: 0.106639
# [608]	valid_0's binary_logloss: 0.106639
# [609]	valid_0's binary_logloss: 0.106638
# [610]	valid_0's binary_logloss: 0.106638
# [611]	valid_0's binary_logloss: 0.106636
# [612]	valid_0's binary_logloss: 0.106634
# [613]	valid_0's binary_logloss: 0.106635
# [614]	valid_0's binary_logloss: 0.106634
# [615]	valid_0's binary_logloss: 0.106633
# [616]	valid_0's binary_logloss: 0.106633
# [617]	valid_0's binary_logloss: 0.106632
# [618]	valid_0's binary_logloss: 0.10663
# [619]	valid_0's binary_logloss: 0.10663
# [620]	valid_0's binary_logloss: 0.106629
# [621]	valid_0's binary_logloss: 0.10663
# [622]	valid_0's binary_logloss: 0.106629
# [623]	valid_0's binary_logloss: 0.106628
# [624]	valid_0's binary_logloss: 0.106627
# [625]	valid_0's binary_logloss: 0.106626
# [626]	valid_0's binary_logloss: 0.106626
# [627]	valid_0's binary_logloss: 0.106624
# [628]	valid_0's binary_logloss: 0.106625
# [629]	valid_0's binary_logloss: 0.106624
# [630]	valid_0's binary_logloss: 0.106623
# [631]	valid_0's binary_logloss: 0.106622
# [632]	valid_0's binary_logloss: 0.106622
# [633]	valid_0's binary_logloss: 0.106621
# [634]	valid_0's binary_logloss: 0.10662
# [635]	valid_0's binary_logloss: 0.10662
# [636]	valid_0's binary_logloss: 0.106619
# [637]	valid_0's binary_logloss: 0.106618
# [638]	valid_0's binary_logloss: 0.106617
# [639]	valid_0's binary_logloss: 0.106617
# [640]	valid_0's binary_logloss: 0.106616
# [641]	valid_0's binary_logloss: 0.106615
# [642]	valid_0's binary_logloss: 0.106615
# [643]	valid_0's binary_logloss: 0.106615
# [644]	valid_0's binary_logloss: 0.106614
# [645]	valid_0's binary_logloss: 0.106613
# [646]	valid_0's binary_logloss: 0.106612
# [647]	valid_0's binary_logloss: 0.106613
# [648]	valid_0's binary_logloss: 0.106612
# [649]	valid_0's binary_logloss: 0.106611
# [650]	valid_0's binary_logloss: 0.10661
# [651]	valid_0's binary_logloss: 0.106609
# [652]	valid_0's binary_logloss: 0.106609
# [653]	valid_0's binary_logloss: 0.106608
# [654]	valid_0's binary_logloss: 0.106608
# [655]	valid_0's binary_logloss: 0.106609
# [656]	valid_0's binary_logloss: 0.106609
# [657]	valid_0's binary_logloss: 0.106609
# [658]	valid_0's binary_logloss: 0.106608
# [659]	valid_0's binary_logloss: 0.106607
# [660]	valid_0's binary_logloss: 0.106608
# [661]	valid_0's binary_logloss: 0.106608
# [662]	valid_0's binary_logloss: 0.106608
# [663]	valid_0's binary_logloss: 0.106607
# [664]	valid_0's binary_logloss: 0.106607
# [665]	valid_0's binary_logloss: 0.106606
# [666]	valid_0's binary_logloss: 0.106606
# [667]	valid_0's binary_logloss: 0.106605
# [668]	valid_0's binary_logloss: 0.106604
# [669]	valid_0's binary_logloss: 0.106604
# [670]	valid_0's binary_logloss: 0.106604
# [671]	valid_0's binary_logloss: 0.106603
# [672]	valid_0's binary_logloss: 0.106602
# [673]	valid_0's binary_logloss: 0.106601
# [674]	valid_0's binary_logloss: 0.106601
# [675]	valid_0's binary_logloss: 0.106601
# [676]	valid_0's binary_logloss: 0.106601
# [677]	valid_0's binary_logloss: 0.1066
# [678]	valid_0's binary_logloss: 0.106598
# [679]	valid_0's binary_logloss: 0.106598
# [680]	valid_0's binary_logloss: 0.106597
# [681]	valid_0's binary_logloss: 0.106597
# [682]	valid_0's binary_logloss: 0.106597
# [683]	valid_0's binary_logloss: 0.106596
# [684]	valid_0's binary_logloss: 0.106595
# [685]	valid_0's binary_logloss: 0.106596
# [686]	valid_0's binary_logloss: 0.106595
# [687]	valid_0's binary_logloss: 0.106595
# [688]	valid_0's binary_logloss: 0.106595
# [689]	valid_0's binary_logloss: 0.106594
# [690]	valid_0's binary_logloss: 0.106592
# [691]	valid_0's binary_logloss: 0.106592
# [692]	valid_0's binary_logloss: 0.106592
# [693]	valid_0's binary_logloss: 0.106591
# [694]	valid_0's binary_logloss: 0.10659
# [695]	valid_0's binary_logloss: 0.10659
# [696]	valid_0's binary_logloss: 0.106589
# [697]	valid_0's binary_logloss: 0.10659
# [698]	valid_0's binary_logloss: 0.106589
# [699]	valid_0's binary_logloss: 0.106589
# [700]	valid_0's binary_logloss: 0.106588
# [701]	valid_0's binary_logloss: 0.106588
# [702]	valid_0's binary_logloss: 0.106587
# [703]	valid_0's binary_logloss: 0.106586
# [704]	valid_0's binary_logloss: 0.106584
# [705]	valid_0's binary_logloss: 0.106584
# [706]	valid_0's binary_logloss: 0.106584
# [707]	valid_0's binary_logloss: 0.106583
# [708]	valid_0's binary_logloss: 0.106582
# [709]	valid_0's binary_logloss: 0.106582
# [710]	valid_0's binary_logloss: 0.106582
# [711]	valid_0's binary_logloss: 0.106584
# [712]	valid_0's binary_logloss: 0.106584
# [713]	valid_0's binary_logloss: 0.106584
# [714]	valid_0's binary_logloss: 0.106583
# [715]	valid_0's binary_logloss: 0.106583
# [716]	valid_0's binary_logloss: 0.106583
# [717]	valid_0's binary_logloss: 0.106583
# [718]	valid_0's binary_logloss: 0.106584
# [719]	valid_0's binary_logloss: 0.106583
# [720]	valid_0's binary_logloss: 0.106584
# [721]	valid_0's binary_logloss: 0.106585
# [722]	valid_0's binary_logloss: 0.106583
# [723]	valid_0's binary_logloss: 0.106582
# [724]	valid_0's binary_logloss: 0.106582
# [725]	valid_0's binary_logloss: 0.106581
# [726]	valid_0's binary_logloss: 0.10658
# [727]	valid_0's binary_logloss: 0.10658
# [728]	valid_0's binary_logloss: 0.10658
# [729]	valid_0's binary_logloss: 0.10658
# [730]	valid_0's binary_logloss: 0.10658
# [731]	valid_0's binary_logloss: 0.106579
# [732]	valid_0's binary_logloss: 0.106579
# [733]	valid_0's binary_logloss: 0.106579
# [734]	valid_0's binary_logloss: 0.106578
# [735]	valid_0's binary_logloss: 0.106578
# [736]	valid_0's binary_logloss: 0.106577
# [737]	valid_0's binary_logloss: 0.106576
# [738]	valid_0's binary_logloss: 0.106576
# [739]	valid_0's binary_logloss: 0.106575
# [740]	valid_0's binary_logloss: 0.106573
# [741]	valid_0's binary_logloss: 0.106573
# [742]	valid_0's binary_logloss: 0.106572
# [743]	valid_0's binary_logloss: 0.106572
# [744]	valid_0's binary_logloss: 0.106572
# [745]	valid_0's binary_logloss: 0.106572
# [746]	valid_0's binary_logloss: 0.106573
# [747]	valid_0's binary_logloss: 0.106573
# [748]	valid_0's binary_logloss: 0.106573
# [749]	valid_0's binary_logloss: 0.106573
# [750]	valid_0's binary_logloss: 0.106572
# [751]	valid_0's binary_logloss: 0.106571
# [752]	valid_0's binary_logloss: 0.10657
# [753]	valid_0's binary_logloss: 0.10657
# [754]	valid_0's binary_logloss: 0.10657
# [755]	valid_0's binary_logloss: 0.10657
# [756]	valid_0's binary_logloss: 0.10657
# [757]	valid_0's binary_logloss: 0.10657
# [758]	valid_0's binary_logloss: 0.106569
# [759]	valid_0's binary_logloss: 0.106568
# [760]	valid_0's binary_logloss: 0.106568
# [761]	valid_0's binary_logloss: 0.106568
# [762]	valid_0's binary_logloss: 0.106567
# [763]	valid_0's binary_logloss: 0.106567
# [764]	valid_0's binary_logloss: 0.106567
# [765]	valid_0's binary_logloss: 0.106567
# [766]	valid_0's binary_logloss: 0.106566
# [767]	valid_0's binary_logloss: 0.106567
# [768]	valid_0's binary_logloss: 0.106566
# [769]	valid_0's binary_logloss: 0.106566
# [770]	valid_0's binary_logloss: 0.106566
# [771]	valid_0's binary_logloss: 0.106565
# [772]	valid_0's binary_logloss: 0.106565
# [773]	valid_0's binary_logloss: 0.106565
# [774]	valid_0's binary_logloss: 0.106564
# [775]	valid_0's binary_logloss: 0.106562
# [776]	valid_0's binary_logloss: 0.106562
# [777]	valid_0's binary_logloss: 0.106562
# [778]	valid_0's binary_logloss: 0.106561
# [779]	valid_0's binary_logloss: 0.106561
# [780]	valid_0's binary_logloss: 0.10656
# [781]	valid_0's binary_logloss: 0.10656
# [782]	valid_0's binary_logloss: 0.10656
# [783]	valid_0's binary_logloss: 0.106558
# [784]	valid_0's binary_logloss: 0.106558
# [785]	valid_0's binary_logloss: 0.106558
# [786]	valid_0's binary_logloss: 0.106556
# [787]	valid_0's binary_logloss: 0.106557
# [788]	valid_0's binary_logloss: 0.106556
# [789]	valid_0's binary_logloss: 0.106556
# [790]	valid_0's binary_logloss: 0.106556
# [791]	valid_0's binary_logloss: 0.106554
# [792]	valid_0's binary_logloss: 0.106554
# [793]	valid_0's binary_logloss: 0.106554
# [794]	valid_0's binary_logloss: 0.106553
# [795]	valid_0's binary_logloss: 0.106552
# [796]	valid_0's binary_logloss: 0.106551
# [797]	valid_0's binary_logloss: 0.10655
# [798]	valid_0's binary_logloss: 0.106548
# [799]	valid_0's binary_logloss: 0.106546
# [800]	valid_0's binary_logloss: 0.106546
# [801]	valid_0's binary_logloss: 0.106547
# [802]	valid_0's binary_logloss: 0.106546
# [803]	valid_0's binary_logloss: 0.106545
# [804]	valid_0's binary_logloss: 0.106545
# [805]	valid_0's binary_logloss: 0.106545
# [806]	valid_0's binary_logloss: 0.106545
# [807]	valid_0's binary_logloss: 0.106545
# [808]	valid_0's binary_logloss: 0.106545
# [809]	valid_0's binary_logloss: 0.106545
# [810]	valid_0's binary_logloss: 0.106545
# [811]	valid_0's binary_logloss: 0.106545
# [812]	valid_0's binary_logloss: 0.106544
# [813]	valid_0's binary_logloss: 0.106543
# [814]	valid_0's binary_logloss: 0.106543
# [815]	valid_0's binary_logloss: 0.106543
# [816]	valid_0's binary_logloss: 0.106542
# [817]	valid_0's binary_logloss: 0.106542
# [818]	valid_0's binary_logloss: 0.106542
# [819]	valid_0's binary_logloss: 0.106541
# [820]	valid_0's binary_logloss: 0.106541
# [821]	valid_0's binary_logloss: 0.106542
# [822]	valid_0's binary_logloss: 0.10654
# [823]	valid_0's binary_logloss: 0.106541
# [824]	valid_0's binary_logloss: 0.106541
# [825]	valid_0's binary_logloss: 0.106541
# [826]	valid_0's binary_logloss: 0.10654
# [827]	valid_0's binary_logloss: 0.10654
# [828]	valid_0's binary_logloss: 0.106539
# [829]	valid_0's binary_logloss: 0.106539
# [830]	valid_0's binary_logloss: 0.10654
# [831]	valid_0's binary_logloss: 0.10654
# [832]	valid_0's binary_logloss: 0.106539
# [833]	valid_0's binary_logloss: 0.106539
# [834]	valid_0's binary_logloss: 0.106538
# [835]	valid_0's binary_logloss: 0.106537
# [836]	valid_0's binary_logloss: 0.106538
# [837]	valid_0's binary_logloss: 0.106537
# [838]	valid_0's binary_logloss: 0.106538
# [839]	valid_0's binary_logloss: 0.106538
# [840]	valid_0's binary_logloss: 0.106538
# [841]	valid_0's binary_logloss: 0.106537
# [842]	valid_0's binary_logloss: 0.106537
# [843]	valid_0's binary_logloss: 0.106538
# [844]	valid_0's binary_logloss: 0.106537
# [845]	valid_0's binary_logloss: 0.106537
# [846]	valid_0's binary_logloss: 0.106537
# [847]	valid_0's binary_logloss: 0.106537
# [848]	valid_0's binary_logloss: 0.106535
# [849]	valid_0's binary_logloss: 0.106534
# [850]	valid_0's binary_logloss: 0.106535
# [851]	valid_0's binary_logloss: 0.106535
# [852]	valid_0's binary_logloss: 0.106533
# [853]	valid_0's binary_logloss: 0.106531
# [854]	valid_0's binary_logloss: 0.106531
# [855]	valid_0's binary_logloss: 0.106529
# [856]	valid_0's binary_logloss: 0.10653
# [857]	valid_0's binary_logloss: 0.106529
# [858]	valid_0's binary_logloss: 0.106528
# [859]	valid_0's binary_logloss: 0.106529
# [860]	valid_0's binary_logloss: 0.106528
# [861]	valid_0's binary_logloss: 0.106528
# [862]	valid_0's binary_logloss: 0.106527
# [863]	valid_0's binary_logloss: 0.106527
# [864]	valid_0's binary_logloss: 0.106527
# [865]	valid_0's binary_logloss: 0.106527
# [866]	valid_0's binary_logloss: 0.106527
# [867]	valid_0's binary_logloss: 0.106526
# [868]	valid_0's binary_logloss: 0.106526
# [869]	valid_0's binary_logloss: 0.106525
# [870]	valid_0's binary_logloss: 0.106525
# [871]	valid_0's binary_logloss: 0.106524
# [872]	valid_0's binary_logloss: 0.106524
# [873]	valid_0's binary_logloss: 0.106524
# [874]	valid_0's binary_logloss: 0.106524
# [875]	valid_0's binary_logloss: 0.106524
# [876]	valid_0's binary_logloss: 0.106523
# [877]	valid_0's binary_logloss: 0.106522
# [878]	valid_0's binary_logloss: 0.106521
# [879]	valid_0's binary_logloss: 0.10652
# [880]	valid_0's binary_logloss: 0.106518
# [881]	valid_0's binary_logloss: 0.106518
# [882]	valid_0's binary_logloss: 0.106518
# [883]	valid_0's binary_logloss: 0.106518
# [884]	valid_0's binary_logloss: 0.106517
# [885]	valid_0's binary_logloss: 0.106516
# [886]	valid_0's binary_logloss: 0.106516
# [887]	valid_0's binary_logloss: 0.106516
# [888]	valid_0's binary_logloss: 0.106516
# [889]	valid_0's binary_logloss: 0.106516
# [890]	valid_0's binary_logloss: 0.106516
# [891]	valid_0's binary_logloss: 0.106515
# [892]	valid_0's binary_logloss: 0.106514
# [893]	valid_0's binary_logloss: 0.106514
# [894]	valid_0's binary_logloss: 0.106513
# [895]	valid_0's binary_logloss: 0.106513
# [896]	valid_0's binary_logloss: 0.106513
# [897]	valid_0's binary_logloss: 0.106513
# [898]	valid_0's binary_logloss: 0.106514
# [899]	valid_0's binary_logloss: 0.106513
# [900]	valid_0's binary_logloss: 0.106513
# [901]	valid_0's binary_logloss: 0.106512
# [902]	valid_0's binary_logloss: 0.106512
# [903]	valid_0's binary_logloss: 0.106512
# [904]	valid_0's binary_logloss: 0.106512
# [905]	valid_0's binary_logloss: 0.106511
# [906]	valid_0's binary_logloss: 0.106511
# [907]	valid_0's binary_logloss: 0.106511
# [908]	valid_0's binary_logloss: 0.106511
# [909]	valid_0's binary_logloss: 0.106511
# [910]	valid_0's binary_logloss: 0.106511
# [911]	valid_0's binary_logloss: 0.106511
# [912]	valid_0's binary_logloss: 0.106511
# [913]	valid_0's binary_logloss: 0.106511
# [914]	valid_0's binary_logloss: 0.10651
# [915]	valid_0's binary_logloss: 0.106511
# [916]	valid_0's binary_logloss: 0.106511
# [917]	valid_0's binary_logloss: 0.10651
# [918]	valid_0's binary_logloss: 0.10651
# [919]	valid_0's binary_logloss: 0.10651
# [920]	valid_0's binary_logloss: 0.106508
# [921]	valid_0's binary_logloss: 0.106509
# [922]	valid_0's binary_logloss: 0.106509
# [923]	valid_0's binary_logloss: 0.10651
# [924]	valid_0's binary_logloss: 0.10651
# [925]	valid_0's binary_logloss: 0.106509
# [926]	valid_0's binary_logloss: 0.10651
# [927]	valid_0's binary_logloss: 0.106509
# [928]	valid_0's binary_logloss: 0.106509
# [929]	valid_0's binary_logloss: 0.106509
# [930]	valid_0's binary_logloss: 0.106509
# [931]	valid_0's binary_logloss: 0.106508
# [932]	valid_0's binary_logloss: 0.106508
# [933]	valid_0's binary_logloss: 0.106507
# [934]	valid_0's binary_logloss: 0.106507
# [935]	valid_0's binary_logloss: 0.106506
# [936]	valid_0's binary_logloss: 0.106505
# [937]	valid_0's binary_logloss: 0.106506
# [938]	valid_0's binary_logloss: 0.106506
# [939]	valid_0's binary_logloss: 0.106506
# [940]	valid_0's binary_logloss: 0.106505
# [941]	valid_0's binary_logloss: 0.106504
# [942]	valid_0's binary_logloss: 0.106503
# [943]	valid_0's binary_logloss: 0.106503
# [944]	valid_0's binary_logloss: 0.106504
# [945]	valid_0's binary_logloss: 0.106504
# [946]	valid_0's binary_logloss: 0.106503
# [947]	valid_0's binary_logloss: 0.106502
# [948]	valid_0's binary_logloss: 0.106503
# [949]	valid_0's binary_logloss: 0.106504
# [950]	valid_0's binary_logloss: 0.106504
# [951]	valid_0's binary_logloss: 0.106505
# [952]	valid_0's binary_logloss: 0.106504
# [953]	valid_0's binary_logloss: 0.106504
# [954]	valid_0's binary_logloss: 0.106504
# [955]	valid_0's binary_logloss: 0.106503
# [956]	valid_0's binary_logloss: 0.106503
# [957]	valid_0's binary_logloss: 0.106503
# [958]	valid_0's binary_logloss: 0.106502
# [959]	valid_0's binary_logloss: 0.106502
# [960]	valid_0's binary_logloss: 0.106501
# [961]	valid_0's binary_logloss: 0.106501
# [962]	valid_0's binary_logloss: 0.106501
# [963]	valid_0's binary_logloss: 0.106501
# [964]	valid_0's binary_logloss: 0.1065
# [965]	valid_0's binary_logloss: 0.106501
# [966]	valid_0's binary_logloss: 0.1065
# [967]	valid_0's binary_logloss: 0.1065
# [968]	valid_0's binary_logloss: 0.1065
# [969]	valid_0's binary_logloss: 0.1065
# [970]	valid_0's binary_logloss: 0.106499
# [971]	valid_0's binary_logloss: 0.106499
# [972]	valid_0's binary_logloss: 0.106499
# [973]	valid_0's binary_logloss: 0.1065
# [974]	valid_0's binary_logloss: 0.106499
# [975]	valid_0's binary_logloss: 0.106499
# [976]	valid_0's binary_logloss: 0.1065
# [977]	valid_0's binary_logloss: 0.106499
# [978]	valid_0's binary_logloss: 0.106499
# [979]	valid_0's binary_logloss: 0.106498
# [980]	valid_0's binary_logloss: 0.106498
# [981]	valid_0's binary_logloss: 0.106497
# [982]	valid_0's binary_logloss: 0.106497
# [983]	valid_0's binary_logloss: 0.106496
# [984]	valid_0's binary_logloss: 0.106496
# [985]	valid_0's binary_logloss: 0.106497
# [986]	valid_0's binary_logloss: 0.106497
# [987]	valid_0's binary_logloss: 0.106497
# [988]	valid_0's binary_logloss: 0.106496
# [989]	valid_0's binary_logloss: 0.106495
# [990]	valid_0's binary_logloss: 0.106495
# [991]	valid_0's binary_logloss: 0.106494
# [992]	valid_0's binary_logloss: 0.106494
# [993]	valid_0's binary_logloss: 0.106493
# [994]	valid_0's binary_logloss: 0.106494
# [995]	valid_0's binary_logloss: 0.106493
# [996]	valid_0's binary_logloss: 0.106492
# [997]	valid_0's binary_logloss: 0.106492
# [998]	valid_0's binary_logloss: 0.106492
# [999]	valid_0's binary_logloss: 0.106493
# [1000]	valid_0's binary_logloss: 0.106491
# [1001]	valid_0's binary_logloss: 0.106492
# [1002]	valid_0's binary_logloss: 0.106492
# [1003]	valid_0's binary_logloss: 0.106492
# [1004]	valid_0's binary_logloss: 0.106492
# [1005]	valid_0's binary_logloss: 0.106492
# [1006]	valid_0's binary_logloss: 0.106493
# [1007]	valid_0's binary_logloss: 0.106492
# [1008]	valid_0's binary_logloss: 0.106492
# [1009]	valid_0's binary_logloss: 0.106492
# [1010]	valid_0's binary_logloss: 0.106491
# [1011]	valid_0's binary_logloss: 0.106491
# [1012]	valid_0's binary_logloss: 0.106491
# [1013]	valid_0's binary_logloss: 0.10649
# [1014]	valid_0's binary_logloss: 0.106489
# [1015]	valid_0's binary_logloss: 0.10649
# [1016]	valid_0's binary_logloss: 0.106489
# [1017]	valid_0's binary_logloss: 0.106489
# [1018]	valid_0's binary_logloss: 0.106488
# [1019]	valid_0's binary_logloss: 0.106487
# [1020]	valid_0's binary_logloss: 0.106487
# [1021]	valid_0's binary_logloss: 0.106486
# [1022]	valid_0's binary_logloss: 0.106487
# [1023]	valid_0's binary_logloss: 0.106486
# [1024]	valid_0's binary_logloss: 0.106487
# [1025]	valid_0's binary_logloss: 0.106486
# [1026]	valid_0's binary_logloss: 0.106485
# [1027]	valid_0's binary_logloss: 0.106485
# [1028]	valid_0's binary_logloss: 0.106486
# [1029]	valid_0's binary_logloss: 0.106486
# [1030]	valid_0's binary_logloss: 0.106486
# [1031]	valid_0's binary_logloss: 0.106486
# [1032]	valid_0's binary_logloss: 0.106487
# [1033]	valid_0's binary_logloss: 0.106487
# [1034]	valid_0's binary_logloss: 0.106487
# [1035]	valid_0's binary_logloss: 0.106488
# [1036]	valid_0's binary_logloss: 0.106487
# [1037]	valid_0's binary_logloss: 0.106487
# [1038]	valid_0's binary_logloss: 0.106486
# [1039]	valid_0's binary_logloss: 0.106487
# [1040]	valid_0's binary_logloss: 0.106486
# [1041]	valid_0's binary_logloss: 0.106487
# [1042]	valid_0's binary_logloss: 0.106486
# [1043]	valid_0's binary_logloss: 0.106486
# [1044]	valid_0's binary_logloss: 0.106485
# [1045]	valid_0's binary_logloss: 0.106485
# [1046]	valid_0's binary_logloss: 0.106484
# [1047]	valid_0's binary_logloss: 0.106484
# [1048]	valid_0's binary_logloss: 0.106483
# [1049]	valid_0's binary_logloss: 0.106482
# [1050]	valid_0's binary_logloss: 0.106482
# [1051]	valid_0's binary_logloss: 0.106481
# [1052]	valid_0's binary_logloss: 0.106481
# [1053]	valid_0's binary_logloss: 0.10648
# [1054]	valid_0's binary_logloss: 0.10648
# [1055]	valid_0's binary_logloss: 0.10648
# [1056]	valid_0's binary_logloss: 0.10648
# [1057]	valid_0's binary_logloss: 0.106479
# [1058]	valid_0's binary_logloss: 0.10648
# [1059]	valid_0's binary_logloss: 0.106479
# [1060]	valid_0's binary_logloss: 0.10648
# [1061]	valid_0's binary_logloss: 0.106481
# [1062]	valid_0's binary_logloss: 0.106481
# [1063]	valid_0's binary_logloss: 0.106481
# [1064]	valid_0's binary_logloss: 0.10648
# [1065]	valid_0's binary_logloss: 0.10648
# [1066]	valid_0's binary_logloss: 0.10648
# [1067]	valid_0's binary_logloss: 0.106479
# [1068]	valid_0's binary_logloss: 0.106479
# [1069]	valid_0's binary_logloss: 0.106479
# [1070]	valid_0's binary_logloss: 0.106479
# [1071]	valid_0's binary_logloss: 0.106479
# [1072]	valid_0's binary_logloss: 0.106478
# [1073]	valid_0's binary_logloss: 0.106479
# [1074]	valid_0's binary_logloss: 0.106479
# [1075]	valid_0's binary_logloss: 0.106479
# [1076]	valid_0's binary_logloss: 0.106479
# [1077]	valid_0's binary_logloss: 0.106481
# [1078]	valid_0's binary_logloss: 0.10648
# [1079]	valid_0's binary_logloss: 0.10648
# [1080]	valid_0's binary_logloss: 0.106479
# [1081]	valid_0's binary_logloss: 0.106479
# [1082]	valid_0's binary_logloss: 0.106479
# [1083]	valid_0's binary_logloss: 0.106479
# [1084]	valid_0's binary_logloss: 0.106478
# [1085]	valid_0's binary_logloss: 0.106478
# [1086]	valid_0's binary_logloss: 0.106477
# [1087]	valid_0's binary_logloss: 0.106478
# [1088]	valid_0's binary_logloss: 0.106478
# [1089]	valid_0's binary_logloss: 0.106478
# [1090]	valid_0's binary_logloss: 0.106479
# [1091]	valid_0's binary_logloss: 0.106478
# [1092]	valid_0's binary_logloss: 0.106478
# [1093]	valid_0's binary_logloss: 0.106477
# [1094]	valid_0's binary_logloss: 0.106478
# [1095]	valid_0's binary_logloss: 0.106477
# [1096]	valid_0's binary_logloss: 0.106477
# [1097]	valid_0's binary_logloss: 0.106477
# [1098]	valid_0's binary_logloss: 0.106476
# [1099]	valid_0's binary_logloss: 0.106476
# [1100]	valid_0's binary_logloss: 0.106477
# [1101]	valid_0's binary_logloss: 0.106477
# [1102]	valid_0's binary_logloss: 0.106477
# [1103]	valid_0's binary_logloss: 0.106476
# [1104]	valid_0's binary_logloss: 0.106477
# [1105]	valid_0's binary_logloss: 0.106477
# [1106]	valid_0's binary_logloss: 0.106477
# [1107]	valid_0's binary_logloss: 0.106478
# [1108]	valid_0's binary_logloss: 0.106478
# [1109]	valid_0's binary_logloss: 0.106478
# [1110]	valid_0's binary_logloss: 0.106479
# [1111]	valid_0's binary_logloss: 0.106478
# [1112]	valid_0's binary_logloss: 0.106478
# [1113]	valid_0's binary_logloss: 0.106478
# [1114]	valid_0's binary_logloss: 0.106478
# [1115]	valid_0's binary_logloss: 0.106479
# [1116]	valid_0's binary_logloss: 0.106478
# [1117]	valid_0's binary_logloss: 0.106479
# [1118]	valid_0's binary_logloss: 0.106478
# [1119]	valid_0's binary_logloss: 0.106479
# Early stopping, best iteration is:
# [1099]	valid_0's binary_logloss: 0.106476
# Training took 477.3 seconds
# Predicting...
# Took 1.3 seconds
# #########################
# ### retweet_timestamp
# #########################
# Training...
# [1]	valid_0's binary_logloss: 0.293969
# Training until validation scores don't improve for 20 rounds
# [2]	valid_0's binary_logloss: 0.286223
# [3]	valid_0's binary_logloss: 0.279779
# [4]	valid_0's binary_logloss: 0.275252
# [5]	valid_0's binary_logloss: 0.272105
# [6]	valid_0's binary_logloss: 0.267985
# [7]	valid_0's binary_logloss: 0.265085
# [8]	valid_0's binary_logloss: 0.263243
# [9]	valid_0's binary_logloss: 0.260978
# [10]	valid_0's binary_logloss: 0.258489
# [11]	valid_0's binary_logloss: 0.256652
# [12]	valid_0's binary_logloss: 0.255161
# [13]	valid_0's binary_logloss: 0.253883
# [14]	valid_0's binary_logloss: 0.252846
# [15]	valid_0's binary_logloss: 0.251282
# [16]	valid_0's binary_logloss: 0.24995
# [17]	valid_0's binary_logloss: 0.248831
# [18]	valid_0's binary_logloss: 0.248271
# [19]	valid_0's binary_logloss: 0.247275
# [20]	valid_0's binary_logloss: 0.246458
# [21]	valid_0's binary_logloss: 0.245815
# [22]	valid_0's binary_logloss: 0.245185
# [23]	valid_0's binary_logloss: 0.244723
# [24]	valid_0's binary_logloss: 0.244082
# [25]	valid_0's binary_logloss: 0.243694
# [26]	valid_0's binary_logloss: 0.243368
# [27]	valid_0's binary_logloss: 0.243057
# [28]	valid_0's binary_logloss: 0.242611
# [29]	valid_0's binary_logloss: 0.242226
# [30]	valid_0's binary_logloss: 0.241781
# [31]	valid_0's binary_logloss: 0.24151
# [32]	valid_0's binary_logloss: 0.241258
# [33]	valid_0's binary_logloss: 0.240984
# ...
# [328]	valid_0's binary_logloss: 0.534596
# [329]	valid_0's binary_logloss: 0.534584
# [330]	valid_0's binary_logloss: 0.534572
# [331]	valid_0's binary_logloss: 0.534564
# [332]	valid_0's binary_logloss: 0.534557
# [333]	valid_0's binary_logloss: 0.534546
# [334]	valid_0's binary_logloss: 0.534539
# [335]	valid_0's binary_logloss: 0.534525
# [336]	valid_0's binary_logloss: 0.534517
# [337]	valid_0's binary_logloss: 0.534483
# [338]	valid_0's binary_logloss: 0.534475
# [339]	valid_0's binary_logloss: 0.53446
# [340]	valid_0's binary_logloss: 0.534442
# [341]	valid_0's binary_logloss: 0.534431
# [342]	valid_0's binary_logloss: 0.534477
# [343]	valid_0's binary_logloss: 0.53447
# [344]	valid_0's binary_logloss: 0.534462
# [345]	valid_0's binary_logloss: 0.534452
# [346]	valid_0's binary_logloss: 0.53444
# [347]	valid_0's binary_logloss: 0.534418
# [348]	valid_0's binary_logloss: 0.534442
# [349]	valid_0's binary_logloss: 0.534436
# [350]	valid_0's binary_logloss: 0.534426
# [351]	valid_0's binary_logloss: 0.534411
# [352]	valid_0's binary_logloss: 0.534398
# [353]	valid_0's binary_logloss: 0.534413
# [354]	valid_0's binary_logloss: 0.534399
# [355]	valid_0's binary_logloss: 0.534387
# [356]	valid_0's binary_logloss: 0.534377
# [357]	valid_0's binary_logloss: 0.53437
# [358]	valid_0's binary_logloss: 0.534355
# [359]	valid_0's binary_logloss: 0.534348
# [360]	valid_0's binary_logloss: 0.534343
# [361]	valid_0's binary_logloss: 0.534331
# [362]	valid_0's binary_logloss: 0.534285
# [363]	valid_0's binary_logloss: 0.534276
# [364]	valid_0's binary_logloss: 0.53427
# [365]	valid_0's binary_logloss: 0.534258
# [366]	valid_0's binary_logloss: 0.534251
# [367]	valid_0's binary_logloss: 0.534267
# [368]	valid_0's binary_logloss: 0.534279
# [369]	valid_0's binary_logloss: 0.53428
# [370]	valid_0's binary_logloss: 0.534272
# [371]	valid_0's binary_logloss: 0.534266
# [372]	valid_0's binary_logloss: 0.534251
# [373]	valid_0's binary_logloss: 0.534241
# [374]	valid_0's binary_logloss: 0.534233
# [375]	valid_0's binary_logloss: 0.534227
# [376]	valid_0's binary_logloss: 0.534211
# [377]	valid_0's binary_logloss: 0.534192
# [378]	valid_0's binary_logloss: 0.534181
# [379]	valid_0's binary_logloss: 0.534166
# [380]	valid_0's binary_logloss: 0.534156
# [381]	valid_0's binary_logloss: 0.534144
# [382]	valid_0's binary_logloss: 0.53413
# [383]	valid_0's binary_logloss: 0.534119
# [384]	valid_0's binary_logloss: 0.53411
# [385]	valid_0's binary_logloss: 0.534108
# [386]	valid_0's binary_logloss: 0.534092
# [387]	valid_0's binary_logloss: 0.534077
# [388]	valid_0's binary_logloss: 0.53407
# [389]	valid_0's binary_logloss: 0.534063
# [390]	valid_0's binary_logloss: 0.534048
# [391]	valid_0's binary_logloss: 0.534037
# [392]	valid_0's binary_logloss: 0.534027
# [393]	valid_0's binary_logloss: 0.534023
# [394]	valid_0's binary_logloss: 0.534014
# [395]	valid_0's binary_logloss: 0.534006
# [396]	valid_0's binary_logloss: 0.534042
# [397]	valid_0's binary_logloss: 0.534035
# [398]	valid_0's binary_logloss: 0.534024
# [399]	valid_0's binary_logloss: 0.534023
# [400]	valid_0's binary_logloss: 0.534013
# [401]	valid_0's binary_logloss: 0.534001
# [402]	valid_0's binary_logloss: 0.533982
# [403]	valid_0's binary_logloss: 0.533976
# [404]	valid_0's binary_logloss: 0.533968
# [405]	valid_0's binary_logloss: 0.533964
# [406]	valid_0's binary_logloss: 0.533958
# [407]	valid_0's binary_logloss: 0.533963
# [408]	valid_0's binary_logloss: 0.533957
# [409]	valid_0's binary_logloss: 0.533948
# [410]	valid_0's binary_logloss: 0.533943
# [411]	valid_0's binary_logloss: 0.533933
# [412]	valid_0's binary_logloss: 0.533919
# [413]	valid_0's binary_logloss: 0.533908
# [414]	valid_0's binary_logloss: 0.533899
# [415]	valid_0's binary_logloss: 0.533894
# [416]	valid_0's binary_logloss: 0.533886
# [417]	valid_0's binary_logloss: 0.533907
# [418]	valid_0's binary_logloss: 0.533904
# [419]	valid_0's binary_logloss: 0.533938
# [420]	valid_0's binary_logloss: 0.533917
# [421]	valid_0's binary_logloss: 0.533889
# [422]	valid_0's binary_logloss: 0.533854
# [423]	valid_0's binary_logloss: 0.533833
# [424]	valid_0's binary_logloss: 0.533827
# [425]	valid_0's binary_logloss: 0.533816
# [426]	valid_0's binary_logloss: 0.533809
# [427]	valid_0's binary_logloss: 0.533797
# [428]	valid_0's binary_logloss: 0.533784
# [429]	valid_0's binary_logloss: 0.533778
# [430]	valid_0's binary_logloss: 0.533771
# [431]	valid_0's binary_logloss: 0.533766
# [432]	valid_0's binary_logloss: 0.533761
# [433]	valid_0's binary_logloss: 0.533757
# [434]	valid_0's binary_logloss: 0.533749
# [435]	valid_0's binary_logloss: 0.533741
# [436]	valid_0's binary_logloss: 0.533763
# [437]	valid_0's binary_logloss: 0.533753
# [438]	valid_0's binary_logloss: 0.533743
# [439]	valid_0's binary_logloss: 0.533734
# [440]	valid_0's binary_logloss: 0.533726
# [441]	valid_0's binary_logloss: 0.533717
# [442]	valid_0's binary_logloss: 0.533706
# [443]	valid_0's binary_logloss: 0.533696
# [444]	valid_0's binary_logloss: 0.53369
# [445]	valid_0's binary_logloss: 0.533684
# [446]	valid_0's binary_logloss: 0.533679
# [447]	valid_0's binary_logloss: 0.53367
# [448]	valid_0's binary_logloss: 0.533666
# [449]	valid_0's binary_logloss: 0.53368
# [450]	valid_0's binary_logloss: 0.533672
# [451]	valid_0's binary_logloss: 0.53366
# [452]	valid_0's binary_logloss: 0.533656
# [453]	valid_0's binary_logloss: 0.533648
# [454]	valid_0's binary_logloss: 0.533641
# [455]	valid_0's binary_logloss: 0.533636
# [456]	valid_0's binary_logloss: 0.53363
# [457]	valid_0's binary_logloss: 0.533625
# [458]	valid_0's binary_logloss: 0.533609
# [459]	valid_0's binary_logloss: 0.533603
# [460]	valid_0's binary_logloss: 0.533596
# [461]	valid_0's binary_logloss: 0.533591
# [462]	valid_0's binary_logloss: 0.533581
# [463]	valid_0's binary_logloss: 0.533575
# [464]	valid_0's binary_logloss: 0.533566
# [465]	valid_0's binary_logloss: 0.533562
# [466]	valid_0's binary_logloss: 0.533554
# [467]	valid_0's binary_logloss: 0.533547
# [468]	valid_0's binary_logloss: 0.533539
# [469]	valid_0's binary_logloss: 0.533533
# [470]	valid_0's binary_logloss: 0.533528
# [471]	valid_0's binary_logloss: 0.533518
# [472]	valid_0's binary_logloss: 0.533512
# [473]	valid_0's binary_logloss: 0.533503
# [474]	valid_0's binary_logloss: 0.533496
# [475]	valid_0's binary_logloss: 0.533486
# [476]	valid_0's binary_logloss: 0.533478
# [477]	valid_0's binary_logloss: 0.533485
# [478]	valid_0's binary_logloss: 0.533475
# [479]	valid_0's binary_logloss: 0.533467
# [480]	valid_0's binary_logloss: 0.533462
# [481]	valid_0's binary_logloss: 0.533456
# [482]	valid_0's binary_logloss: 0.533447
# [483]	valid_0's binary_logloss: 0.533437
# [484]	valid_0's binary_logloss: 0.533435
# [485]	valid_0's binary_logloss: 0.53343
# [486]	valid_0's binary_logloss: 0.533428
# [487]	valid_0's binary_logloss: 0.533418
# [488]	valid_0's binary_logloss: 0.533414
# [489]	valid_0's binary_logloss: 0.53341
# [490]	valid_0's binary_logloss: 0.533402
# [491]	valid_0's binary_logloss: 0.533393
# [492]	valid_0's binary_logloss: 0.533391
# [493]	valid_0's binary_logloss: 0.533383
# [494]	valid_0's binary_logloss: 0.533379
# [495]	valid_0's binary_logloss: 0.533373
# [496]	valid_0's binary_logloss: 0.533377
# [497]	valid_0's binary_logloss: 0.533374
# [498]	valid_0's binary_logloss: 0.533368
# [499]	valid_0's binary_logloss: 0.533359
# [500]	valid_0's binary_logloss: 0.533354
# [501]	valid_0's binary_logloss: 0.53335
# [502]	valid_0's binary_logloss: 0.533344
# [503]	valid_0's binary_logloss: 0.533324
# [504]	valid_0's binary_logloss: 0.533318
# [505]	valid_0's binary_logloss: 0.533322
# [506]	valid_0's binary_logloss: 0.533314
# [507]	valid_0's binary_logloss: 0.533308
# [508]	valid_0's binary_logloss: 0.533302
# [509]	valid_0's binary_logloss: 0.533292
# [510]	valid_0's binary_logloss: 0.533279
# [511]	valid_0's binary_logloss: 0.533274
# [512]	valid_0's binary_logloss: 0.533269
# [513]	valid_0's binary_logloss: 0.533267
# [514]	valid_0's binary_logloss: 0.533264
# [515]	valid_0's binary_logloss: 0.533257
# [516]	valid_0's binary_logloss: 0.533247
# [517]	valid_0's binary_logloss: 0.533253
# [518]	valid_0's binary_logloss: 0.533249
# [519]	valid_0's binary_logloss: 0.533246
# [520]	valid_0's binary_logloss: 0.533233
# [521]	valid_0's binary_logloss: 0.533228
# [522]	valid_0's binary_logloss: 0.533218
# [523]	valid_0's binary_logloss: 0.533211
# [524]	valid_0's binary_logloss: 0.533206
# [525]	valid_0's binary_logloss: 0.533195
# [526]	valid_0's binary_logloss: 0.53319
# [527]	valid_0's binary_logloss: 0.533178
# [528]	valid_0's binary_logloss: 0.533171
# [529]	valid_0's binary_logloss: 0.533167
# [530]	valid_0's binary_logloss: 0.533158
# [531]	valid_0's binary_logloss: 0.533158
# [532]	valid_0's binary_logloss: 0.533152
# [533]	valid_0's binary_logloss: 0.533146
# [534]	valid_0's binary_logloss: 0.533134
# [535]	valid_0's binary_logloss: 0.533119
# [536]	valid_0's binary_logloss: 0.533113
# [537]	valid_0's binary_logloss: 0.533108
# [538]	valid_0's binary_logloss: 0.533098
# [539]	valid_0's binary_logloss: 0.533092
# [540]	valid_0's binary_logloss: 0.53309
# [541]	valid_0's binary_logloss: 0.533086
# [542]	valid_0's binary_logloss: 0.533083
# [543]	valid_0's binary_logloss: 0.53308
# [544]	valid_0's binary_logloss: 0.533076
# [545]	valid_0's binary_logloss: 0.533071
# [546]	valid_0's binary_logloss: 0.533074
# [547]	valid_0's binary_logloss: 0.533071
# [548]	valid_0's binary_logloss: 0.533068
# [549]	valid_0's binary_logloss: 0.533066
# [550]	valid_0's binary_logloss: 0.533054
# [551]	valid_0's binary_logloss: 0.53305
# [552]	valid_0's binary_logloss: 0.533046
# [553]	valid_0's binary_logloss: 0.533043
# [554]	valid_0's binary_logloss: 0.533037
# [555]	valid_0's binary_logloss: 0.533031
# [556]	valid_0's binary_logloss: 0.533033
# [557]	valid_0's binary_logloss: 0.533027
# [558]	valid_0's binary_logloss: 0.53302
# [559]	valid_0's binary_logloss: 0.533007
# [560]	valid_0's binary_logloss: 0.533005
# [561]	valid_0's binary_logloss: 0.533002
# [562]	valid_0's binary_logloss: 0.532996
# [563]	valid_0's binary_logloss: 0.532989
# [564]	valid_0's binary_logloss: 0.532987
# [565]	valid_0's binary_logloss: 0.532996
# [566]	valid_0's binary_logloss: 0.532991
# [567]	valid_0's binary_logloss: 0.532988
# [568]	valid_0's binary_logloss: 0.532984
# [569]	valid_0's binary_logloss: 0.532979
# [570]	valid_0's binary_logloss: 0.532976
# [571]	valid_0's binary_logloss: 0.532977
# [572]	valid_0's binary_logloss: 0.532971
# [573]	valid_0's binary_logloss: 0.532963
# [574]	valid_0's binary_logloss: 0.532957
# [575]	valid_0's binary_logloss: 0.532949
# [576]	valid_0's binary_logloss: 0.532941
# [577]	valid_0's binary_logloss: 0.532925
# [578]	valid_0's binary_logloss: 0.532907
# [579]	valid_0's binary_logloss: 0.532904
# [580]	valid_0's binary_logloss: 0.532907
# [581]	valid_0's binary_logloss: 0.532902
# [582]	valid_0's binary_logloss: 0.53292
# [583]	valid_0's binary_logloss: 0.532914
# [584]	valid_0's binary_logloss: 0.532911
# [585]	valid_0's binary_logloss: 0.532908
# [586]	valid_0's binary_logloss: 0.532903
# [587]	valid_0's binary_logloss: 0.532894
# [588]	valid_0's binary_logloss: 0.532892
# [589]	valid_0's binary_logloss: 0.532884
# [590]	valid_0's binary_logloss: 0.532879
# [591]	valid_0's binary_logloss: 0.532875
# [592]	valid_0's binary_logloss: 0.532863
# [593]	valid_0's binary_logloss: 0.532859
# [594]	valid_0's binary_logloss: 0.532855
# [595]	valid_0's binary_logloss: 0.532852
# [596]	valid_0's binary_logloss: 0.532846
# [597]	valid_0's binary_logloss: 0.532841
# [598]	valid_0's binary_logloss: 0.532843
# [599]	valid_0's binary_logloss: 0.532839
# [600]	valid_0's binary_logloss: 0.532839
# [601]	valid_0's binary_logloss: 0.532836
# [602]	valid_0's binary_logloss: 0.532843
# [603]	valid_0's binary_logloss: 0.532843
# [604]	valid_0's binary_logloss: 0.532839
# [605]	valid_0's binary_logloss: 0.532831
# [606]	valid_0's binary_logloss: 0.532828
# [607]	valid_0's binary_logloss: 0.532822
# [608]	valid_0's binary_logloss: 0.532815
# [609]	valid_0's binary_logloss: 0.532808
# [610]	valid_0's binary_logloss: 0.532804
# [611]	valid_0's binary_logloss: 0.532799
# [612]	valid_0's binary_logloss: 0.532798
# [613]	valid_0's binary_logloss: 0.532791
# [614]	valid_0's binary_logloss: 0.532783
# [615]	valid_0's binary_logloss: 0.532778
# [616]	valid_0's binary_logloss: 0.532775
# [617]	valid_0's binary_logloss: 0.532787
# [618]	valid_0's binary_logloss: 0.532767
# [619]	valid_0's binary_logloss: 0.532785
# [620]	valid_0's binary_logloss: 0.532785
# [621]	valid_0's binary_logloss: 0.532782
# [622]	valid_0's binary_logloss: 0.532778
# [623]	valid_0's binary_logloss: 0.532775
# [624]	valid_0's binary_logloss: 0.532775
# [625]	valid_0's binary_logloss: 0.53278
# [626]	valid_0's binary_logloss: 0.532776
# [627]	valid_0's binary_logloss: 0.532768
# [628]	valid_0's binary_logloss: 0.532764
# [629]	valid_0's binary_logloss: 0.53276
# [630]	valid_0's binary_logloss: 0.532784
# [631]	valid_0's binary_logloss: 0.532783
# [632]	valid_0's binary_logloss: 0.532781
# [633]	valid_0's binary_logloss: 0.532778
# [634]	valid_0's binary_logloss: 0.532773
# [635]	valid_0's binary_logloss: 0.532771
# [636]	valid_0's binary_logloss: 0.532767
# [637]	valid_0's binary_logloss: 0.532763
# [638]	valid_0's binary_logloss: 0.532758
# [639]	valid_0's binary_logloss: 0.532756
# [640]	valid_0's binary_logloss: 0.532751
# [641]	valid_0's binary_logloss: 0.532747
# [642]	valid_0's binary_logloss: 0.532743
# [643]	valid_0's binary_logloss: 0.53274
# [644]	valid_0's binary_logloss: 0.532735
# [645]	valid_0's binary_logloss: 0.532732
# [646]	valid_0's binary_logloss: 0.53273
# [647]	valid_0's binary_logloss: 0.532726
# [648]	valid_0's binary_logloss: 0.532728
# [649]	valid_0's binary_logloss: 0.532723
# [650]	valid_0's binary_logloss: 0.532721
# [651]	valid_0's binary_logloss: 0.532723
# [652]	valid_0's binary_logloss: 0.532721
# [653]	valid_0's binary_logloss: 0.532714
# [654]	valid_0's binary_logloss: 0.53271
# [655]	valid_0's binary_logloss: 0.532705
# [656]	valid_0's binary_logloss: 0.5327
# [657]	valid_0's binary_logloss: 0.532696
# [658]	valid_0's binary_logloss: 0.532697
# [659]	valid_0's binary_logloss: 0.532695
# [660]	valid_0's binary_logloss: 0.532694
# [661]	valid_0's binary_logloss: 0.532692
# [662]	valid_0's binary_logloss: 0.532688
# [663]	valid_0's binary_logloss: 0.532686
# [664]	valid_0's binary_logloss: 0.53269
# [665]	valid_0's binary_logloss: 0.532685
# [666]	valid_0's binary_logloss: 0.532681
# [667]	valid_0's binary_logloss: 0.532676
# [668]	valid_0's binary_logloss: 0.532674
# [669]	valid_0's binary_logloss: 0.532672
# [670]	valid_0's binary_logloss: 0.532667
# [671]	valid_0's binary_logloss: 0.532664
# [672]	valid_0's binary_logloss: 0.53266
# [673]	valid_0's binary_logloss: 0.532674
# [674]	valid_0's binary_logloss: 0.532671
# [675]	valid_0's binary_logloss: 0.532665
# [676]	valid_0's binary_logloss: 0.532661
# [677]	valid_0's binary_logloss: 0.53266
# [678]	valid_0's binary_logloss: 0.532658
# [679]	valid_0's binary_logloss: 0.532652
# [680]	valid_0's binary_logloss: 0.532651
# [681]	valid_0's binary_logloss: 0.532648
# [682]	valid_0's binary_logloss: 0.532644
# [683]	valid_0's binary_logloss: 0.532641
# [684]	valid_0's binary_logloss: 0.532641
# [685]	valid_0's binary_logloss: 0.532637
# [686]	valid_0's binary_logloss: 0.532634
# [687]	valid_0's binary_logloss: 0.53263
# [688]	valid_0's binary_logloss: 0.532628
# [689]	valid_0's binary_logloss: 0.532623
# [690]	valid_0's binary_logloss: 0.532621
# [691]	valid_0's binary_logloss: 0.53262
# [692]	valid_0's binary_logloss: 0.532618
# [693]	valid_0's binary_logloss: 0.532631
# [694]	valid_0's binary_logloss: 0.532645
# [695]	valid_0's binary_logloss: 0.532641
# [696]	valid_0's binary_logloss: 0.532636
# [697]	valid_0's binary_logloss: 0.532651
# [698]	valid_0's binary_logloss: 0.532649
# [699]	valid_0's binary_logloss: 0.532648
# [700]	valid_0's binary_logloss: 0.532645
# [701]	valid_0's binary_logloss: 0.532661
# [702]	valid_0's binary_logloss: 0.532676
# [703]	valid_0's binary_logloss: 0.532669
# [704]	valid_0's binary_logloss: 0.532666
# [705]	valid_0's binary_logloss: 0.53266
# [706]	valid_0's binary_logloss: 0.532656
# [707]	valid_0's binary_logloss: 0.532653
# [708]	valid_0's binary_logloss: 0.532649
# [709]	valid_0's binary_logloss: 0.532645
# [710]	valid_0's binary_logloss: 0.532654
# [711]	valid_0's binary_logloss: 0.532649
# [712]	valid_0's binary_logloss: 0.532647
# Early stopping, best iteration is:
# [692]	valid_0's binary_logloss: 0.532618
# Training took 354.4 seconds
# Predicting...
# Took 1.0 seconds
# CPU times: user 1d 12h 3min 46s, sys: 4min 1s, total: 1d 12h 7min 47s
# Wall time: 25min 1s

# %%
yvalid = Y_valid[label_names].values

# %% [markdown]
# # Compute Validation Metrics

# %%
from sklearn.metrics import precision_recall_curve, auc, log_loss
from sklearn.metrics import average_precision_score

def compute_prauc(pred, gt):
  prec, recall, thresh = precision_recall_curve(gt, pred)
  prauc = auc(recall, prec)
  return prauc

def compute_AP(pred, gt):
  return average_precision_score(gt, pred)

def calculate_ctr(gt):
  positive = len([x for x in gt if x == 1])
  ctr = positive/float(len(gt))
  return ctr

def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

# FAST METRIC FROM GIBA
def compute_rce_fast(pred, gt):
    cross_entropy = log_loss(gt, pred)
    yt = np.mean(gt)     
    strawman_cross_entropy = -(yt*np.log(yt) + (1 - yt)*np.log(1 - yt))
    return (1.0 - cross_entropy/strawman_cross_entropy)*100.0

# %%
# %%time
txt = ''
for i in range(4):
    ap = compute_AP(oof[:,i], yvalid[:, i])
    rce   = compute_rce_fast(oof[:,i], yvalid[:, i])
    txt_ = f"{label_names[i]:20} AP:{ap:.5f} RCE:{rce:.5f}"
    print(txt_)
    txt += txt_ + '\n'
# Out:
# reply_timestamp      AP:0.21591 RCE:20.68662
# retweet_timestamp    AP:0.42902 RCE:23.62521
# retweet_with_comment_timestamp AP:0.04663 RCE:10.69715
# like_timestamp       AP:0.72792 RCE:21.26861
# CPU times: user 825 ms, sys: 6.97 ms, total: 832 ms
# Wall time: 808 ms

# %%
print('This notebook took %.1f minutes'%((time.time()-very_start)/60.))
# Out:
# This notebook took 42.6 minutes

# %%
print(f'X_valid.shape {oof.shape}')
# Out:
# X_valid.shape (446420, 4)
